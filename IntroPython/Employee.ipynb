# %%
import sys
import os

os.chdir('C:\\Users\\Maurice Ling\\Desktop\\IntroPython')
print(os.getcwd())
# Out:
# C:\Users\Maurice Ling\Desktop\IntroPython

# %%
from employee_attrition import employee

print(len(employee))
print(employee[10])
# Out:
# 305
# [20367, 28539, 2516, 26, 6, 1, 5]

# %%
ren = []

count = 1
for emp in employee:
    ren.append([float(emp[1]), float(emp[2])])
    print('%s: Bonus percentage = %s' % (count, 
                                         (float(emp[2])/float(emp[1]))))
    count = count + 1
# Out:
# 1: Bonus percentage = 0.08219314890642165
# 2: Bonus percentage = 0.05535477653294784
# 3: Bonus percentage = 0.08801622275084818
# 4: Bonus percentage = 0.03316151202749141
# 5: Bonus percentage = 0.05847114108404778
# 6: Bonus percentage = 0.11893434823977164
# 7: Bonus percentage = 0.05960474865255223
# 8: Bonus percentage = 0.06708802924154736
# 9: Bonus percentage = 0.10457918976796034
# 10: Bonus percentage = 0.09093052730863324
# 11: Bonus percentage = 0.08816006166999545
# 12: Bonus percentage = 0.11384155645981689
# 13: Bonus percentage = 0.08171735241502684
# 14: Bonus percentage = 0.07952719761303649
# 15: Bonus percentage = 0.07042201564113915
# 16: Bonus percentage = 0.10021496570785136
# 17: Bonus percentage = 0.06913094286241467
# 18: Bonus percentage = 0.09440756160684145
# 19: Bonus percentage = 0.09950511114716859
# 20: Bonus percentage = 0.09733306597152597
# 21: Bonus percentage = 0.08636608288825405
# 22: Bonus percentage = 0.0641279366700715
# ...
