# %%
import pandas
# %matplotlib inline
salesDF = pandas.read_excel("SampleSalesData.xlsx")

# %% [markdown]
# # Affinity Analysis
#
# Affinity Analysis is the search for patterns of co-occurence in the dataset. <br>
# A simple co-occurence detection of what a customer has also bought within a span of time can yield a simple market basket analysis. <br>
# Note, the example below is a simple algorithm for market basket analysis; it can also be further tested rigorously with apriori algorithm to get more defined results.<br>
# The purpose of the example below is to illustrate how a quick analysis can be done<br>

# %%
weeklySalesGroup = salesDF.groupby(['Customer Name', pandas.Grouper(key='Order Date', freq='W-MON')])["Product Name"]

# %%
weeklySalesGroup.value_counts()
# Out:
# Customer Name          Order Date  Product Name
# Aaron Davies Bruce     2012-02-06  Eldon Radial Chair Mat for Low to Medium Pile Carpets                                    1
#                                    Eldon Shelf Savers™ Cubes and Bins                                                       1
#                                    Electrix Halogen Magnifier Lamp                                                          1
#                                    Storex Dura Pro™ Binders                                                                 1
# Aaron Day              2010-11-29  Trav-L-File Heavy-Duty Shuttle II, Black                                                 1
#                        2013-08-26  i270                                                                                     1
# Aaron Dillon           2010-08-16  Avery 491                                                                                1
#                                    Avery White Multi-Purpose Labels                                                         1
#                        2011-07-25  Executive Impressions 8-1/2" Career Panel/Partition Cubicle Clock                        1
#                        2013-06-10  Peel & Seel® Recycled Catalog Envelopes, Brown                                           1
# Aaron Fuller Davidson  2011-08-01  Hon 61000 Series Interactive Training Tables                                             1
# Aaron Riggs            2010-12-27  Canon MP41DH Printing Calculator                                                         1
#                                    Wirebound Message Book, 4 per Page                                                       1
#                        2011-09-05  Xerox 213                                                                                1
# Aaron Shaffer          2010-11-15  Safco Industrial Wire Shelving                                                           1
#                        2011-01-10  Crayola Colored Pencils                                                                  1
#                        2012-08-20  3M Organizer Strips                                                                      1
# Adam Barton            2011-04-04  Large Capacity Hanging Post Binders                                                      1
#                        2011-05-02  LX 677                                                                                   1
#                        2012-01-09  Eldon® Wave Desk Accessories                                                             1
#                        2013-03-04  Boston 1799 Powerhouse™ Electric Pencil Sharpener                                        1
#                        2013-08-19  Eldon Radial Chair Mat for Low to Medium Pile Carpets                                    1
#                        2013-10-07  Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4                                 1
# Adam G Sawyer          2010-03-29  2180                                                                                     1
#                        2010-08-09  Holmes Replacement Filter for HEPA Air Cleaner, Large Room                               1
#                        2011-02-07  Belkin ErgoBoard™ Keyboard                                                               1
#                        2012-04-02  Executive Impressions 14" Contract Wall Clock                                            1
#                        2013-04-22  T39m                                                                                     1
# Adam McKinney          2012-09-10  GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"                              1
# Adam Saunders Gray     2010-04-05  Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue                     1
#                                                                                                                            ..
# Yvonne Kenney          2012-01-30  Honeywell Enviracaire® Portable HEPA Air Cleaner for up to 10 x 16 Room                  1
# Yvonne Mann            2010-11-29  Economy Rollaway Files                                                                   1
#                                    Model L Table or Wall-Mount Pencil Sharpener                                             1
#                        2011-01-24  Letter Size Cart                                                                         1
#                        2013-05-27  Assorted Color Push Pins                                                                 1
#                                    Avery 497                                                                                1
#                                    Letter/Legal File Tote with Clear Snap-On Lid, Black Granite                             1
#                        2013-06-10  8860                                                                                     1
#                                    Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black    1
#                        2013-12-16  Ibico Covers for Plastic or Wire Binding Elements                                        1
#                                    Premium Writing Pencils, Soft, #2 by Central Association for the Blind                   1
# Yvonne Pearson         2011-01-10  1726 Digital Answering Machine                                                           1
#                        2013-07-22  Newell 338                                                                               1
# Yvonne Ryan            2012-05-07  8290                                                                                     1
#                                    Avoid Verbal Orders Carbonless Minifold Book                                             1
#                                    Carina Double Wide Media Storage Towers in Natural & Black                               1
#                        2013-07-29  Hon Multipurpose Stacking Arm Chairs                                                     1
#                                    Rogers® Profile Extra Capacity Storage Tub                                               1
# Yvonne Stephens        2010-10-25  DAX Copper Panel Document Frame, 5 x 7 Size                                              1
#                                    Deflect-O® Glasstique™ Clear Desk Accessories                                            1
#                                    Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags                         1
#                        2013-09-16  Avery Durable Binders                                                                    1
# Zachary House          2012-06-11  Accessory2                                                                               1
#                                    Hon Olson Stacker Stools                                                                 1
#                                    Trav-L-File Heavy-Duty Shuttle II, Black                                                 1
#                        2012-12-24  Companion Letter/Legal File, Black                                                       1
# Zachary Maynard        2010-04-19  Hon GuestStacker Chair                                                                   1
# Zachary Potter         2012-01-09  GBC Poly Designer Binding Covers                                                         1
#                                    Global High-Back Leather Tilter, Burgundy                                                1
# Zachary Wu             2012-11-12  Bevis Round Conference Table Top, X-Base                                                 1
# Name: Product Name, dtype: int64

# %%
# we are interested in what the user has bought within the same week (ignoring repeats within the week)
weeklySalesGroupProductSets = weeklySalesGroup.apply(set)

# %%
weeklySalesGroupProductSets.values
# Out:
# array([ {'Eldon Radial Chair Mat for Low to Medium Pile Carpets', 'Electrix Halogen Magnifier Lamp', 'Eldon Shelf Savers™ Cubes and Bins', 'Storex Dura Pro™ Binders'},
#        {'Trav-L-File Heavy-Duty Shuttle II, Black'}, {'i270'}, ...,
#        {'Hon GuestStacker Chair'},
#        {'GBC Poly Designer Binding Covers', 'Global High-Back Leather Tilter, Burgundy'},
#        {'Bevis Round Conference Table Top, X-Base'}], dtype=object)

# %%
numOfGroupedWeeklyTransactions = len(weeklySalesGroupProductSets.values) 
numOfGroupedWeeklyTransactions
# Out:
# 6538

# %%
# if the next line looks complicated to you, please check out list comprehensions
# https://www.pythonforbeginners.com/basics/list-comprehensions-in-python
weeklyBasketWithMultipleItems  = [aSet for aSet in weeklySalesGroupProductSets.values if len(aSet) > 2]
numOfMultipleItemBaskets = len(weeklyBasketWithMultipleItems)
numOfMultipleItemBaskets
# Out:
# 286

# %%
numOfMultipleItemBaskets/numOfGroupedWeeklyTransactions
# Out:
# 0.043744264301009486

# %% [markdown]
# Note: at this point, it would be clear to the analyst that a market basket analysis should not yield any significant results as it shows that the chance of a basket with multiple items is very low.<br>
# In addition, the ratio also indicates how much maximum impact or benefit such analysis will afford us.

# %% [markdown]
# Following section will step through more of the market basket analysis in order to find out if there are co-occurences and how much effect (support) there is

# %%
# itertools is a standard library in python to deal with some common operations across common datatypes
from itertools import combinations, groupby, chain
# Counter is a frequency counter. It will automatically update counts as new elements are updated
from collections import Counter

# %% [markdown]
# First, lets check out how many unique items frequently appear. <br>
# We will also set a threshold for minimum counts in order for it to be considered "frequent"

# %%
weeklySalesGroupProductSets.values
# Out:
# array([ {'Eldon Radial Chair Mat for Low to Medium Pile Carpets', 'Electrix Halogen Magnifier Lamp', 'Eldon Shelf Savers™ Cubes and Bins', 'Storex Dura Pro™ Binders'},
#        {'Trav-L-File Heavy-Duty Shuttle II, Black'}, {'i270'}, ...,
#        {'Hon GuestStacker Chair'},
#        {'GBC Poly Designer Binding Covers', 'Global High-Back Leather Tilter, Burgundy'},
#        {'Bevis Round Conference Table Top, X-Base'}], dtype=object)

# %%
# chain is used to flatten all the items in a nested data structure e.g. list of lists
# the return type is an iterator which is a special data object that reads through 
# large datasets through the __next__() function
allBasketProducts = chain(*weeklySalesGroupProductSets.values)
allBasketProducts

# %%
# we can also force the iterator into a list for our convenience
allBasketProducts = list(allBasketProducts)
allBasketProducts
# Out:
# ['Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#  'Electrix Halogen Magnifier Lamp',
#  'Eldon Shelf Savers™ Cubes and Bins',
#  'Storex Dura Pro™ Binders',
#  'Trav-L-File Heavy-Duty Shuttle II, Black',
#  'i270',
#  'Avery White Multi-Purpose Labels',
#  'Avery 491',
#  'Executive Impressions 8-1/2" Career Panel/Partition Cubicle Clock',
#  'Peel & Seel® Recycled Catalog Envelopes, Brown',
#  'Hon 61000 Series Interactive Training Tables',
#  'Wirebound Message Book, 4 per Page',
#  'Canon MP41DH Printing Calculator',
#  'Xerox 213',
#  'Safco Industrial Wire Shelving',
#  'Crayola Colored Pencils',
#  '3M Organizer Strips',
#  'Large Capacity Hanging Post Binders',
#  'LX 677',
#  'Eldon® Wave Desk Accessories',
#  'Boston 1799 Powerhouse™ Electric Pencil Sharpener',
#  'Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#  'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#  '2180',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Large Room',
#  'Belkin ErgoBoard™ Keyboard',
#  'Executive Impressions 14" Contract Wall Clock',
#  'T39m',
#  'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"',
#  'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue',
#  'GBC White Gloss Covers, Plain Front',
#  'Avery® Durable Plastic 1" Binders',
#  'Eldon Executive Woodline II Cherry Finish Desk Accessories',
#  'Peel & Seel® Recycled Catalog Envelopes, Brown',
#  'Xerox 1885',
#  'Seth Thomas 12" Clock w/ Goldtone Case',
#  'Staples Colored Bar Computer Paper',
#  'Staples Vinyl Coated Paper Clips',
#  'HP Office Paper (20Lb. and 87 Bright)',
#  'Presstex Flexible Ring Binders',
#  'Speediset Carbonless Redi-Letter® 7" x 8 1/2"',
#  'Fellowes Super Stor/Drawer® Files',
#  'Linden® 12" Wall Clock With Oak Frame',
#  'Avery 49',
#  'Staples 4 Outlet Surge Protector',
#  'Wausau Papers Astrobrights® Colored Envelopes',
#  'Timeport L7089',
#  'Bush Westfield Collection Bookcases, Fully Assembled',
#  'Newell 340',
#  'Avery 481',
#  'Xerox 1978',
#  'Bretford CR8500 Series Meeting Room Furniture',
#  'Deflect-o DuraMat Antistatic Studded Beveled Mat for Medium Pile Carpeting',
#  'Eldon Expressions Mahogany Wood Desk Collection',
#  'Canon MP100DHII Printing Calculator',
#  'Newell 323',
#  'Riverleaf Stik-Withit® Designer Note Cubes®',
#  'White GlueTop Scratch Pads',
#  'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"',
#  'Memorex 4.7GB DVD-RAM, 3/Pack',
#  'Stockwell Push Pins',
#  'Bevis Round Conference Table Top, X-Base',
#  'Telescoping Adjustable Floor Lamp',
#  'Ultra Door Push Plate',
#  'G.E. Longer-Life Indoor Recessed Floodlight Bulbs',
#  'Fellowes Smart Surge Ten-Outlet Protector, Platinum',
#  'Xerox 1880',
#  'Xerox 1976',
#  'Avery 481',
#  'V3682',
#  'Wilson Jones 1" Hanging DublLock® Ring Binders',
#  'StarTAC 7760',
#  'OIC Thumb-Tacks',
#  'Lexmark Z54se Color Inkjet Printer',
#  'Bevis Round Conference Table Top, X-Base',
#  'SC-3160',
#  'Wirebound Service Call Books, 5 1/2" x 4"',
#  'KF 788',
#  'Accessory29',
#  '6" Cubicle Wall Clock, Black',
#  'T60',
#  'Adesso Programmable 142-Key Keyboard',
#  'Avery 51',
#  'Xerox 1976',
#  'Office Star Flex Back Scooter Chair with Aluminum Finish Frame',
#  'Eldon Executive Woodline II Cherry Finish Desk Accessories',
#  'ACCOHIDE® Binder by Acco',
#  'Xerox 1994',
#  'GBC Laser Imprintable Binding System Covers, Desert Sand',
#  'Canon PC1060 Personal Laser Copier',
#  'Newell 312',
#  'Bretford CR8500 Series Meeting Room Furniture',
#  'Polycom VoiceStation 100',
#  'Okidata ML320 Series Turbo Dot Matrix Printers',
#  'Micro Innovations 104 Keyboard',
#  'Adesso Programmable 142-Key Keyboard',
#  'Wilson Jones Impact Binders',
#  'Lexmark Z54se Color Inkjet Printer',
#  'Advantus Employee of the Month Certificate Frame, 11 x 13-1/2',
#  'Hon Olson Stacker Stools',
#  'Pressboard Covers with Storage Hooks, 9 1/2" x 11", Light Blue',
#  'Xerox 1984',
#  'EcoTones® Memo Sheets',
#  '3395',
#  'Imation Neon Mac Format Diskettes, 10/Pack',
#  'Newell 310',
#  'GBC DocuBind 200 Manual Binding Machine',
#  'Hon 4070 Series Pagoda™ Armless Upholstered Stacking Chairs',
#  'Okidata ML591 Wide Format Dot Matrix Printer',
#  'Staples Standard Envelopes',
#  'Portable Personal File Box',
#  'Euro Pro Shark Stick Mini Vacuum',
#  'V 3600 Series',
#  'Tenex Carpeted, Granite-Look or Clear Contemporary Contour Shape Chair Mats',
#  'StarTAC ST7762',
#  'Epson LQ-570e Dot Matrix Printer',
#  'Ultra Door Pull Handle',
#  'Xerox 1966',
#  'GBC Recycled Regency Composition Covers',
#  'Xerox 1880',
#  'GBC Recycled Grain Textured Covers',
#  'Xerox 200',
#  '688',
#  'Bravo II™ Megaboss® 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack',
#  'Tyvek Interoffice Envelopes, 9 1/2" x 12 1/2", 100/Box',
#  'Avery Reinforcements for Hole-Punch Pages',
#  'DAX Value U-Channel Document Frames, Easel Back',
#  'Global High-Back Leather Tilter, Burgundy',
#  'Xerox 1906',
#  'Durable Pressboard Binders',
#  'Park Ridge™ Embossed Executive Business Envelopes',
#  'Sanford 52201 APSCO Electric Pencil Sharpener',
#  'Newell 342',
#  'Newell 343',
#  'G.E. Halogen Desk Lamp Bulbs',
#  'Gyration Ultra Cordless Optical Suite',
#  'Chromcraft Bull-Nose Wood Round Conference Table Top, Wood Base',
#  'Hon 2111 Invitation™ Series Corner Table',
#  'Bush Advantage Collection® Round Conference Table',
#  '*Staples* Highlighting Markers',
#  'StarTAC 7760',
#  'Hoover Portapower™ Portable Vacuum',
#  'Talkabout T8097',
#  '4009® Highlighters by Sanford',
#  'Accessory6',
#  'Laminate Occasional Tables',
#  'Avery Durable Poly Binders',
#  'Rediform S.O.S. Phone Message Books',
#  'GBC Standard Therm-A-Bind Covers',
#  'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"',
#  '#6 3/4 Gummed Flap White Envelopes',
#  'Xerox 1959',
#  'Avery Poly Binder Pockets',
#  'Aluminum Document Frame',
#  'Staples Pushpins',
#  'Dixon Ticonderoga Core-Lock Colored Pencils, 48-Color Set',
#  'Dixon Ticonderoga Core-Lock Colored Pencils, 48-Color Set',
#  'Eldon® Image Series Desk Accessories, Burgundy',
#  'Xerox 1905',
#  'Xerox 212',
#  'BPI Conference Tables',
#  '8290',
#  'Binding Machine Supplies',
#  'Maxell Pro 80 Minute CD-R, 10/Pack',
#  'Boston 1730 StandUp Electric Pencil Sharpener',
#  'Imation 3.5", DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack',
#  'Staples Metal Binder Clips',
#  'Avery Durable Poly Binders',
#  'Xerox 1882',
#  'Novimex Fabric Task Chair',
#  'Prang Drawing Pencil Set',
#  'Xerox 1993',
#  'Fellowes Super Stor/Drawer® Files',
#  'Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black',
#  'Xerox 1892',
#  'Array® Parchment Paper, Assorted Colors',
#  'SAFCO Optional Arm Kit for Workspace® Cribbage Stacking Chair',
#  '3390',
#  'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"',
#  'Tenex Antistatic Computer Chair Mats',
#  'Executive Impressions 14" Two-Color Numerals Wall Clock',
#  'Newell® 3-Hole Punched Plastic Slotted Magazine Holders for Binders',
#  'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#  'Cardinal Poly Pocket Divider Pockets for Ring Binders',
#  'Document Clip Frames',
#  'Multimedia Mailers',
#  'Martin-Yale Premier Letter Opener',
#  'Global High-Back Leather Tilter, Burgundy',
#  'GBC Binding covers',
#  '*Staples* Letter Opener',
#  'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#  'GBC Standard Therm-A-Bind Covers',
#  'Xerox 1963',
#  'Eldon® Wave Desk Accessories',
#  'Global Stack Chair without Arms, Black',
#  'Sanford EarthWrite® Recycled Pencils, Medium Soft, #2',
#  'SAFCO Mobile Desk Side File, Wire Frame',
#  'Newell 315',
#  'Avery Printable Repositionable Plastic Tabs',
#  'Holmes Odor Grabber',
#  'i1000plus',
#  'Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”',
#  'DAX Clear Channel Poster Frame',
#  'Belkin 8 Outlet SurgeMaster II Gold Surge Protector',
#  'Acme Kleencut® Forged Steel Scissors',
#  '*Staples* Highlighting Markers',
#  '232',
#  'Xerox 1932',
#  'Canon imageCLASS 2200 Advanced Copier',
#  'Presstex Flexible Ring Binders',
#  'Master Giant Foot® Doorstop, Safety Yellow',
#  'Stockwell Push Pins',
#  'Cardinal Holdit Business Card Pockets',
#  'Bush Westfield Collection Bookcases, Fully Assembled',
#  '3M Organizer Strips',
#  'Micro Innovations Micro 3000 Keyboard, Black',
#  'Avery Durable Binders',
#  'Memorex 4.7GB DVD+RW, 3/Pack',
#  'Pressboard Covers with Storage Hooks, 9 1/2" x 11", Light Blue',
#  'Bevis Round Bullnose 29" High Table Top',
#  '270c',
#  'Storex Dura Pro™ Binders',
#  'Logitech Access Keyboard',
#  'Crayola Colored Pencils',
#  '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes',
#  'Round Ring Binders',
#  '8860',
#  'Security-Tint Envelopes',
#  'Newell 309',
#  'Super Decoflex Portable Personal File',
#  '*Staples* Highlighting Markers',
#  'Fellowes Mighty 8 Compact Surge Protector',
#  'DS/HD IBM Formatted Diskettes, 10/Pack - Staples',
#  'Xerox 1891',
#  'Avery Self-Adhesive Photo Pockets for Polaroid Photos',
#  'Boston School Pro Electric Pencil Sharpener, 1670',
#  'Sanford 52201 APSCO Electric Pencil Sharpener',
#  'Avery White Multi-Purpose Labels',
#  'Avery 498',
#  'Xerox 1891',
#  'Fellowes Super Stor/Drawer® Files',
#  'Fellowes Stor/Drawer® Steel Plus™ Storage Drawers',
#  'Newell 312',
#  'Accessory35',
#  'Hanging Personal Folder File',
#  'Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack',
#  'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"',
#  'Crate-A-Files™',
#  'Xerox 1906',
#  'Heavy-Duty E-Z-D® Binders',
#  'Global Deluxe Stacking Chair, Gray',
#  'Howard Miller 13" Diameter Goldtone Round Wall Clock',
#  'Eldon Jumbo ProFile™ Portable File Boxes Graphite/Black',
#  'Xerox 1930',
#  'CF 888',
#  'Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers',
#  'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#  'Dana Swing-Arm Lamps',
#  'Avery 510',
#  'SouthWestern Bell FA970 Digital Answering Machine with Time/Day Stamp',
#  'Xerox 227',
#  'Hoover WindTunnel™ Plus Canister Vacuum',
#  'Howard Miller 16" Diameter Gallery Wall Clock',
#  'Memorex 80 Minute CD-R Spindle, 100/Pack',
#  'Iceberg OfficeWorks 42" Round Tables',
#  'Xerox 21',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Large Room',
#  'Maxell Pro 80 Minute CD-R, 10/Pack',
#  'Holmes Odor Grabber',
#  'GBC DocuBind 200 Manual Binding Machine',
#  'Xerox 197',
#  '8260',
#  'Global Adaptabilities™ Conference Tables',
#  'Accessory35',
#  'Hon 4070 Series Pagoda™ Round Back Stacking Chairs',
#  'Quartet Alpha® White Chalk, 12/Pack',
#  'Bell Sonecor JB700 Caller ID',
#  'Array® Memo Cubes',
#  'Fellowes Staxonsteel® Drawer Files',
#  'Xerox 1932',
#  '4009® Highlighters by Sanford',
#  'Newell 310',
#  "O'Sullivan Cherrywood Estates Traditional Barrister Bookcase",
#  'Quartet Alpha® White Chalk, 12/Pack',
#  'Avery Hi-Liter Pen Style Six-Color Fluorescent Set',
#  '5170',
#  'Premium Transparent Presentation Covers by GBC',
#  'Staples Plastic Wall Frames',
#  'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages',
#  'Avery 511',
#  'Office Star - Task Chair with Contemporary Loop Arms',
#  'TDK 4.7GB DVD+RW',
#  'Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H',
#  'Round Ring Binders',
#  'Xerox 1963',
#  'Gyration Ultra Cordless Optical Suite',
#  'Hon Every-Day® Chair Series Swivel Task Chairs',
#  'Staples Metal Binder Clips',
#  'Accessory8',
#  'Xerox 1993',
#  'Round Ring Binders',
#  'Binder Posts',
#  'Memorex 80 Minute CD-R Spindle, 100/Pack',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Medium Room',
#  'Adesso Programmable 142-Key Keyboard',
#  '2300 Heavy-Duty Transfer File Systems by Perma',
#  'Bush Westfield Collection Bookcases, Fully Assembled',
#  'Avery Flip-Chart Easel Binder, Black',
#  'GBC Instant Index™ System for Binding Systems',
#  '80 Minute CD-R Spindle, 100/Pack - Staples',
#  '"While you Were Out" Message Book, One Form per Page',
#  '1726 Digital Answering Machine',
#  'Belkin 105-Key Black Keyboard',
#  'Avery Flip-Chart Easel Binder, Black',
#  'Logitech Cordless Navigator Duo',
#  'Xerox 1917',
#  'Tenex B1-RE Series Chair Mats for Low Pile Carpets',
#  'Xerox 1932',
#  'Luxo Economy Swing Arm Lamp',
#  'Xerox 1961',
#  'Xerox 1991',
#  'Westinghouse Floor Lamp with Metal Mesh Shade, Black',
#  'Acco® Hot Clips™ Clips to Go',
#  'GBC Instant Index™ System for Binding Systems',
#  'Sterilite Officeware Hinged File Box',
#  'Avery 491',
#  'Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer',
#  'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)',
#  'Boston 16801 Nautilus™ Battery Pencil Sharpener',
#  'Safco Industrial Wire Shelving',
#  'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#  'Dixon Ticonderoga Core-Lock Colored Pencils',
#  'Global Ergonomic Managers Chair',
#  'Avery 507',
#  'Global Leather and Oak Executive Chair, Black',
#  'Polycom ViewStation™ Adapter H323 Videoconferencing Unit',
#  'Hon Olson Stacker Stools',
#  'Hon Multipurpose Stacking Arm Chairs',
#  'Xerox 1978',
#  'Avery 474',
#  'Park Ridge™ Embossed Executive Business Envelopes',
#  'Fellowes Premier Superior Surge Suppressor, 10-Outlet, With Phone and Remote',
#  'DAX Contemporary Wood Frame with Silver Metal Mat, Desktop, 11 x 14 Size',
#  'V8160',
#  'Wilson Jones Suede Grain Vinyl Binders',
#  'GBC DocuBind TL300 Electric Binding System',
#  'Gyration Ultra Cordless Optical Suite',
#  'Wilson Jones® Four-Pocket Poly Binders',
#  '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#  'Sharp AL-1530CS Digital Copier',
#  'Accessory25',
#  'Novimex Turbo Task Chair',
#  'Acco Recycled 2" Capacity Laser Printer Hanging Data Binders',
#  'Logitech Cordless Elite Duo',
#  '36X48 HARDFLOOR CHAIRMAT',
#  'U.S. Robotics 56K Internet Call Modem',
#  'Avery 05222 Permanent Self-Adhesive File Folder Labels for Typewriters, on Rolls, White, 250/Roll',
#  '3390',
#  'Xerox 1973',
#  'Howard Miller Distant Time Traveler Alarm Clock',
#  "O'Sullivan Elevations Bookcase, Cherry Finish",
#  'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#  'SC7868i',
#  'Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders',
#  'Binney & Smith inkTank™ Erasable Pocket Highlighter, Chisel Tip, Yellow',
#  '252',
#  'Riverleaf Stik-Withit® Designer Note Cubes®',
#  'Kleencut® Forged Office Shears by Acme United Corporation',
#  '2160i',
#  'CF 688',
#  'Hon iLevel™ Computer Training Table',
#  'Space Solutions Commercial Steel Shelving',
#  'Tenex Personal Self-Stacking Standard File Box, Black/Gray',
#  'Xerox 1892',
#  'Iris Project Case',
#  'Hon iLevel™ Computer Training Table',
#  'Xerox 220',
#  'Economy Binders',
#  'Carina Double Wide Media Storage Towers in Natural & Black',
#  'Advantus Map Pennant Flags and Round Head Tacks',
#  'Master Giant Foot® Doorstop, Safety Yellow',
#  'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"',
#  'Xerox 1978',
#  'Angle-D Binders with Locking Rings, Label Holders',
#  'Rogers® Profile Extra Capacity Storage Tub',
#  'Imation DVD-RAM discs',
#  'Fellowes Internet Keyboard, Platinum',
#  'DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#  'Logitech Access Keyboard',
#  'Newell 339',
#  'Deflect-o Glass Clear Studded Chair Mats',
#  'Adesso Programmable 142-Key Keyboard',
#  'White GlueTop Scratch Pads',
#  'Executive Impressions 12" Wall Clock',
#  'Microsoft Multimedia Keyboard',
#  'Smead Adjustable Mobile File Trolley with Lockable Top',
#  'Accessory4',
#  'Wilson Jones “Snap” Scratch Pad Binder Tool for Ring Binders',
#  'Avery 503',
#  'Eldon Expressions™ Desk Accessory, Wood Photo Frame, Mahogany',
#  'Advantus 10-Drawer Portable Organizer, Chrome Metal Frame, Smoke Drawers',
#  '12 Colored Short Pencils',
#  'Avery Non-Stick Binders',
#  'IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case',
#  'Xerox 1959',
#  'Global High-Back Leather Tilter, Burgundy',
#  'CF 688',
#  'Dixon Ticonderoga Core-Lock Colored Pencils',
#  'Portfile® Personal File Boxes',
#  'Xerox 1936',
#  'Martin-Yale Premier Letter Opener',
#  'Xerox 1896',
#  'Accessory2',
#  'Global Leather and Oak Executive Chair, Black',
#  'Avery Self-Adhesive Photo Pockets for Polaroid Photos',
#  'Surelock™ Post Binders',
#  'KI Conference Tables',
#  'Staples SlimLine Pencil Sharpener',
#  'Balt Solid Wood Rectangular Table',
#  'High Speed Automatic Electric Letter Opener',
#  'Post-it® “Important Message” Note Pad, Neon Colors, 50 Sheets/Pad',
#  'Accessory39',
#  'Newell 310',
#  'Xerox 1961',
#  "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#  'Ibico EB-19 Dual Function Manual Binding System',
#  'US Robotics 56K V.92 Internal PCI Faxmodem',
#  'Xerox 1941',
#  "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#  '*Staples* Highlighting Markers',
#  'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop',
#  'Iceberg OfficeWorks 42" Round Tables',
#  'Avery 48',
#  'Avery 501',
#  'Imation Neon Mac Format Diskettes, 10/Pack',
#  'TI 36X Solar Scientific Calculator',
#  'Speediset Carbonless Redi-Letter® 7" x 8 1/2"',
#  'SAFCO Commercial Wire Shelving, Black',
#  'StarTAC ST7762',
#  'XtraLife® ClearVue™ Slant-D® Ring Binders by Cardinal',
#  'Hewlett Packard LaserJet 3310 Copier',
#  'Unpadded Memo Slips',
#  'Newell 35',
#  'Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting',
#  'Xerox 210',
#  'Self-Adhesive Removable Labels',
#  '5185',
#  'Avery 474',
#  '3M Organizer Strips',
#  'Wilson Jones “Snap” Scratch Pad Binder Tool for Ring Binders',
#  'g520',
#  'Hand-Finished Solid Wood Document Frame',
#  'Master Giant Foot® Doorstop, Safety Yellow',
#  'TI 36X Solar Scientific Calculator',
#  'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS',
#  'Talkabout T8367',
#  'Avanti 4.4 Cu. Ft. Refrigerator',
#  'SAFCO Folding Chair Trolley',
#  'Xerox 1989',
#  'TOPS Money Receipt Book, Consecutively Numbered in Red,',
#  'Bevis Boat-Shaped Conference Table',
#  'Xerox 212',
#  'Executive Impressions 14" Contract Wall Clock',
#  'Memorex 4.7GB DVD+RW, 3/Pack',
#  'Newell 308',
#  'Panasonic KX-P3626 Dot Matrix Printer',
#  'Wilson Jones 1" Hanging DublLock® Ring Binders',
#  'Accessory35',
#  'Prang Drawing Pencil Set',
#  'Executive Impressions 14" Contract Wall Clock with Quartz Movement',
#  'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"',
#  'Timeport L7089',
#  'Eureka The Boss® Cordless Rechargeable Stick Vac',
#  'Bell Sonecor JB700 Caller ID',
#  'DAX Solid Wood Frames',
#  'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms',
#  'T18',
#  'Fellowes Binding Cases',
#  'Prang Drawing Pencil Set',
#  '6185',
#  'Eldon Shelf Savers™ Cubes and Bins',
#  'Riverside Furniture Stanwyck Manor Table Series',
#  'Global Deluxe Office Fabric Chairs',
#  'i1000plus',
#  'Prang Dustless Chalk Sticks',
#  'Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat',
#  'Staples® General Use 3-Ring Binders',
#  'Xerox 1978',
#  'Accessory20',
#  'Tenex Personal Filing Tote With Secure Closure Lid, Black/Frost',
#  'Carina Double Wide Media Storage Towers in Natural & Black',
#  'Quartet Alpha® White Chalk, 12/Pack',
#  'Xerox 1991',
#  '#10 White Business Envelopes,4 1/8 x 9 1/2',
#  'Xerox 1935',
#  'Avery Hi-Liter GlideStik Fluorescent Highlighter, Yellow Ink',
#  'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"',
#  'Nu-Dell Leatherette Frames',
#  'Economy Binders',
#  'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms',
#  'Novimex Swivel Fabric Task Chair',
#  'X-Rack™ File for Hanging Folders',
#  'Eldon Portable Mobile Manager',
#  'Newell 323',
#  'Global High-Back Leather Tilter, Burgundy',
#  'Xerox 1881',
#  'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#  'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#  'Eldon® 200 Class™ Desk Accessories',
#  'Newell 323',
#  'Xerox 1982',
#  'Fellowes Stor/Drawer® Steel Plus™ Storage Drawers',
#  'Acco Perma® 2700 Stacking Storage Drawers',
#  'Staples 6 Outlet Surge',
#  'Xerox 1936',
#  'Xerox 214',
#  'Computer Printout Paper with Letter-Trim Perforations',
#  'Carina Double Wide Media Storage Towers in Natural & Black',
#  'Premier Elliptical Ring Binder, Black',
#  'Xerox 1899',
#  'Xerox 1882',
#  'Imation Printable White 80 Minute CD-R Spindle, 50/Pack',
#  'Dana Halogen Swing-Arm Architect Lamp',
#  'Staples Bulldog Clip',
#  'Avery Self-Adhesive Photo Pockets for Polaroid Photos',
#  'Dixon Ticonderoga Core-Lock Colored Pencils, 48-Color Set',
#  'iDENi80s',
#  'Multimedia Mailers',
#  'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"',
#  'Staples Colored Interoffice Envelopes',
#  'Speediset Carbonless Redi-Letter® 7" x 8 1/2"',
#  '*Staples* Letter Opener',
#  'Prang Colored Pencils',
#  'i1000',
#  'Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl',
#  'Bush Westfield Collection Bookcases, Fully Assembled',
#  'Global Airflow Leather Mesh Back Chair, Black',
#  'Avery Binder Labels',
#  'Portfile® Personal File Boxes',
#  'Howard Miller 16" Diameter Gallery Wall Clock',
#  'Bush Cubix Collection Bookcases, Fully Assembled',
#  'Eldon® Expressions™ Wood and Plastic Desk Accessories, Oak',
#  'Acco Perma® 2700 Stacking Storage Drawers',
#  'Accessory41',
#  'Super Bands, 12/Pack',
#  'GBC Laser Imprintable Binding System Covers, Desert Sand',
#  'Avery 501',
#  'Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)',
#  'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge',
#  'Lexmark Z54se Color Inkjet Printer',
#  'StarTAC 7760',
#  'DIXON Oriole® Pencils',
#  'Xerox 1971',
#  '5165',
#  'Fiskars® Softgrip Scissors',
#  'DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#  'Tyvek® Side-Opening Peel & Seel® Expanding Envelopes',
#  'Newell 336',
#  'Verbatim DVD-R, 3.95GB, SR, Mitsubishi Branded, Jewel',
#  '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#  'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets',
#  'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#  'Eldon® Gobal File Keepers',
#  'Hon Non-Folding Utility Tables',
#  'Portfile® Personal File Boxes',
#  'Xerox 1923',
#  'Southworth 25% Cotton Antique Laid Paper & Envelopes',
#  '6185',
#  'Strathmore #10 Envelopes, Ultimate White',
#  'iDEN i95',
#  'Tennsco Snap-Together Open Shelving Units, Starter Sets and Add-On Units',
#  'Avery® Durable Slant Ring Binders With Label Holder',
#  'Bevis Rectangular Conference Tables',
#  'Eldon Cleatmat Plus™ Chair Mats for High Pile Carpets',
#  'GBC Imprintable Covers',
#  'Avery Round Ring Poly Binders',
#  'Verbatim DVD-R, 3.95GB, SR, Mitsubishi Branded, Jewel',
#  'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#  'Xerox 1948',
#  'X-Rack™ File for Hanging Folders',
#  'Xerox 1936',
#  'Wilson Jones Elliptical Ring 3 1/2" Capacity Binders, 800 sheets',
#  'Manila Recycled Extra-Heavyweight Clasp Envelopes, 6" x 9"',
#  'Staples 10" Round Wall Clock',
#  'Bevis 36 x 72 Conference Tables',
#  'Bagged Rubber Bands',
#  '8860',
#  'Carina Double Wide Media Storage Towers in Natural & Black',
#  'Verbatim DVD-R, 3.95GB, SR, Mitsubishi Branded, Jewel',
#  'Carina Mini System Audio Rack, Model AR050B',
#  'Xerox 1881',
#  'Nu-Dell Executive Frame',
#  'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#  'Wirebound Message Book, 4 per Page',
#  'Tennsco Regal Shelving Units',
#  'Ultra Commercial Grade Dual Valve Door Closer',
#  'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS',
#  'ACCOHIDE® Binder by Acco',
#  'Serrated Blade or Curved Handle Hand Letter Openers',
#  'Hewlett-Packard Deskjet 5550 Color Inkjet Printer',
#  'V8160',
#  'Avery 514',
#  'Eldon® Wave Desk Accessories',
#  'TDK 4.7GB DVD-R Spindle, 15/Pack',
#  'Xerox 1923',
#  'Fellowes Super Stor/Drawer® Files',
#  'Angle-D Binders with Locking Rings, Label Holders',
#  'Conquest™ 14 Commercial Heavy-Duty Upright Vacuum, Collection System, Accessory Kit',
#  'Hunt Boston® Vacuum Mount KS Pencil Sharpener',
#  'Hammermill Color Copier Paper (28Lb. and 96 Bright)',
#  'Staples Plastic Wall Frames',
#  'KF 788',
#  'Tennsco Commercial Shelving',
#  'Logitech Internet Navigator Keyboard',
#  'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets',
#  'Recycled Eldon Regeneration Jumbo File',
#  'Eldon® Image Series Desk Accessories, Burgundy',
#  'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop',
#  'Bevis 36 x 72 Conference Tables',
#  'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#  'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms',
#  'Bretford CR8500 Series Meeting Room Furniture',
#  'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#  'Avery 498',
#  'Chromcraft Bull-Nose Wood Round Conference Table Top, Wood Base',
#  'Tripp Lite Isotel 6 Outlet Surge Protector with Fax/Modem Protection',
#  'Avery 516',
#  'Sanford EarthWrite® Recycled Pencils, Medium Soft, #2',
#  'Xerox 1991',
#  'Staples 6 Outlet Surge',
#  'Xerox 217',
#  'Anderson Hickey Conga Table Tops & Accessories',
#  'Lifetime Advantage™ Folding Chairs, 4/Carton',
#  'Decoflex Hanging Personal Folder File, Blue',
#  'Master Giant Foot® Doorstop, Safety Yellow',
#  'Multicolor Computer Printout Paper',
#  'Deflect-o EconoMat Studded, No Bevel Mat for Low Pile Carpeting',
#  'Belkin 105-Key Black Keyboard',
#  'Global Leather Task Chair, Black',
#  'Prang Colored Pencils',
#  'US Robotics 56K V.92 External Faxmodem',
#  'GBC Standard Therm-A-Bind Covers',
#  'Xerox 1988',
#  'Bretford Rectangular Conference Table Tops',
#  'Avery Trapezoid Extra Heavy Duty 4" Binders',
#  'T39m',
#  'PC Concepts 116 Key Quantum 3000 Keyboard',
#  'Computer Printout Paper with Letter-Trim Perforations',
#  'Eureka Recycled Copy Paper 8 1/2" x 11", Ream',
#  '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#  'Avery Hole Reinforcements',
#  'Xerox 1894',
#  'Hon 2111 Invitation™ Series Corner Table',
#  '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes',
#  'Xerox 1948',
#  'Acco D-Ring Binder w/DublLock®',
#  'Storex DuraTech Recycled Plastic Frosted Binders',
#  'Xerox 216',
#  'Avery 487',
#  'Safco Industrial Wire Shelving',
#  'Sauder Camden County Collection Libraries, Planked Cherry Finish',
#  'Bush Advantage Collection® Round Conference Table',
#  'Tenex Personal Self-Stacking Standard File Box, Black/Gray',
#  'Acco Suede Grain Vinyl Round Ring Binder',
#  'Avery File Folder Labels',
#  'Staples #10 Colored Envelopes',
#  'Prang Drawing Pencil Set',
#  'Memorex 4.7GB DVD-RAM, 3/Pack',
#  'Eldon Advantage® Chair Mats for Low to Medium Pile Carpets',
#  'Serrated Blade or Curved Handle Hand Letter Openers',
#  'HP Office Paper (20Lb. and 87 Bright)',
#  'Xerox 1989',
#  'Office Star - Task Chair with Contemporary Loop Arms',
#  'Microsoft Internet Keyboard',
#  'Multicolor Computer Printout Paper',
#  '600 Series Flip',
#  'White Business Envelopes with Contemporary Seam, Recycled White Business Envelopes',
#  'Xerox 1882',
#  'Carina Double Wide Media Storage Towers in Natural & Black',
#  'Wilson Jones 1" Hanging DublLock® Ring Binders',
#  'A1228',
#  'T18',
#  'Xerox 1927',
#  'Global Enterprise Series Seating High-Back Swivel/Tilt Chairs',
#  'Bevis Round Conference Table Top & Single Column Base',
#  'Round Specialty Laser Printer Labels',
#  'Ibico Laser Imprintable Binding System Covers',
#  "GBC Standard Plastic Binding Systems' Combs",
#  'Xerox 197',
#  'Bretford “Just In Time” Height-Adjustable Multi-Task Work Tables',
#  'Bionaire Personal Warm Mist Humidifier/Vaporizer',
#  'Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops',
#  'Acco Suede Grain Vinyl Round Ring Binder',
#  'Eldon Image Series Black Desk Accessories',
#  'Xerox 213',
#  'Belkin 8 Outlet Surge Protector',
#  'Executive Impressions 14" Contract Wall Clock',
#  'Telescoping Adjustable Floor Lamp',
#  'Xerox 1898',
#  '3M Polarizing Light Filter Sleeves',
#  'Avery Durable Binders',
#  'Southworth Structures Collection™',
#  'Panasonic KX-P1150 Dot Matrix Printer',
#  'Electrix Halogen Magnifier Lamp',
#  'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base',
#  'iDENi80s',
#  'Wilson Jones 1" Hanging DublLock® Ring Binders',
#  'Pizazz® Global Quick File™',
#  'Xerox 1940',
#  '300 Series Non-Flip',
#  'Okidata ML184 Turbo Dot Matrix Printers',
#  'Dual Level, Single-Width Filing Carts',
#  'Staples Battery-Operated Desktop Pencil Sharpener',
#  'Boston 16765 Mini Stand Up Battery Pencil Sharpener',
#  'Dana Fluorescent Magnifying Lamp, White, 36"',
#  'Global Deluxe Stacking Chair, Gray',
#  'Tensor Computer Mounted Lamp',
#  'Global Deluxe Office Fabric Chairs',
#  '80 Minute CD-R Spindle, 100/Pack - Staples',
#  'SANFORD Major Accent™ Highlighters',
#  'Westinghouse Floor Lamp with Metal Mesh Shade, Black',
#  'Xerox 1966',
#  'Staples Bulldog Clip',
#  'Ultra Door Push Plate',
#  'Xerox 1997',
#  'Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer',
#  'Accessory36',
#  'Advantus Panel Wall Certificate Holder - 8.5x11',
#  "Memorex 'Cool' 80 Minute CD-R Spindle, 25/Pack",
#  'GE 4 Foot Flourescent Tube, 40 Watt',
#  'GBC DocuBind 200 Manual Binding Machine',
#  'Xerox 20',
#  'Canon P1-DHIII Palm Printing Calculator',
#  'Wilson Jones Hanging View Binder, White, 1"',
#  'Rubber Band Ball',
#  'Avery Hanging File Binders',
#  'Boston 1645 Deluxe Heavier-Duty Electric Pencil Sharpener',
#  '12 Colored Short Pencils',
#  'Avery Poly Binder Pockets',
#  'Hon Multipurpose Stacking Arm Chairs',
#  'Binding Machine Supplies',
#  'Avery 508',
#  'Boston 16801 Nautilus™ Battery Pencil Sharpener',
#  'Eldon® Image Series Desk Accessories, Burgundy',
#  'Tripp Lite Isotel 6 Outlet Surge Protector with Fax/Modem Protection',
#  'Avery 520',
#  'Hewlett-Packard Deskjet 3820 Color Inkjet Printer',
#  'Linden® 12" Wall Clock With Oak Frame',
#  'Brother DCP1000 Digital 3 in 1 Multifunction Machine',
#  'Accessory36',
#  'Micro Innovations 104 Keyboard',
#  'Global High-Back Leather Tilter, Burgundy',
#  'Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl',
#  'Imation Neon 80 Minute CD-R Spindle, 50/Pack',
#  'Xerox 1893',
#  'Hon Comfortask® Task/Swivel Chairs',
#  'Panasonic KX-P1131 Dot Matrix Printer',
#  "Lock-Up Easel 'Spel-Binder'",
#  'Office Star Flex Back Scooter Chair with Aluminum Finish Frame',
#  '232',
#  'Metal Folding Chairs, Beige, 4/Carton',
#  'Global Enterprise™ Series Seating Low-Back Swivel/Tilt Chairs',
#  'Telescoping Adjustable Floor Lamp',
#  'Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms',
#  'Iceberg OfficeWorks 42" Round Tables',
#  'Imation 3.5", RTS 247544 3M 3.5 DSDD, 10/Pack',
#  'US Robotics 56K V.92 External Faxmodem',
#  'Eldon® 500 Class™ Desk Accessories',
#  'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#  'Sanford Liquid Accent Highlighters',
#  'Executive Impressions 14" Contract Wall Clock',
#  'Acco D-Ring Binder w/DublLock®',
#  'X-Rack™ File for Hanging Folders',
#  '#10- 4 1/8" x 9 1/2" Recycled Envelopes',
#  'Deflect-o EconoMat Nonstudded, No Bevel Mat',
#  'Hon 4-Shelf Metal Bookcases',
#  'Avery 493',
#  'Fellowes Super Stor/Drawer®',
#  'Tripp Lite Isotel 6 Outlet Surge Protector with Fax/Modem Protection',
#  'Canon MP41DH Printing Calculator',
#  'Lexmark Z54se Color Inkjet Printer',
#  'Belkin 5 Outlet SurgeMaster™ Power Centers',
#  'Staples® General Use 3-Ring Binders',
#  'Global High-Back Leather Tilter, Burgundy',
#  'Barrel Sharpener',
#  'Adams "While You Were Out" Message Pads',
#  'Angle-D Binders with Locking Rings, Label Holders',
#  'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS',
#  'Wilson Jones Suede Grain Vinyl Binders',
#  'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#  'Smead Adjustable Mobile File Trolley with Lockable Top',
#  '3390',
#  'Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black',
#  'Eldon® Image Series Desk Accessories, Burgundy',
#  'Boston Electric Pencil Sharpener, Model 1818, Charcoal Black',
#  'Staples #10 Colored Envelopes',
#  'Acme® Elite Stainless Steel Scissors',
#  'Array® Parchment Paper, Assorted Colors',
#  'OIC Thumb-Tacks',
#  'Panasonic KP-310 Heavy-Duty Electric Pencil Sharpener',
#  'Xerox 1892',
#  'Artistic Insta-Plaque',
#  'GE 4 Foot Flourescent Tube, 40 Watt',
#  'Avery 481',
#  'Xerox 213',
#  'Bevis Round Conference Table Top & Single Column Base',
#  'Avery 474',
#  'GBC ProClick™ 150 Presentation Binding System',
#  'Xerox 1992',
#  'DAX Solid Wood Frames',
#  'U.S. Robotics 56K Internet Call Modem',
#  'Eldon Cleatmat® Chair Mats for Medium Pile Carpets',
#  'Fellowes Bases and Tops For Staxonsteel®/High-Stak® Systems',
#  'Martin-Yale Premier Letter Opener',
#  'Hon Comfortask® Task/Swivel Chairs',
#  'Xerox 204',
#  'Avery 506',
#  'While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle',
#  'Smead Adjustable Mobile File Trolley with Lockable Top',
#  'Xerox 1977',
#  'Avery 487',
#  'Ibico Presentation Index for Binding Systems',
#  'Unpadded Memo Slips',
#  'Storex DuraTech Recycled Plastic Frosted Binders',
#  'Eldon Regeneration Recycled Desk Accessories, Smoke',
#  'Avery Hi-Liter Pen Style Six-Color Fluorescent Set',
#  'Tensor "Hersey Kiss" Styled Floor Lamp',
#  'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#  'Master Giant Foot® Doorstop, Safety Yellow',
#  'Bravo II™ Megaboss® 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack',
#  'Xerox 1922',
#  'Accessory8',
#  'Tennsco Commercial Shelving',
#  'Gyration Ultra Professional Cordless Optical Suite',
#  'Eldon® 300 Class™ Desk Accessories, Black',
#  'Imation Printable White 80 Minute CD-R Spindle, 50/Pack',
#  'Xerox 1985',
#  '3285',
#  'Memorex 4.7GB DVD+RW, 3/Pack',
#  '2160i',
#  'Kensington 7 Outlet MasterPiece® HOMEOFFICE Power Control Center',
#  'Seth Thomas 13 1/2" Wall Clock',
#  'Hanging Personal Folder File',
#  'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop',
#  'Fellowes Staxonsteel® Drawer Files',
#  'Newell 31',
#  'Xerox 1898',
#  'Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders',
#  'Recycled Interoffice Envelopes with String and Button Closure, 10 x 13',
#  'Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl',
#  'Mead 1st Gear 2" Zipper Binder, Asst. Colors',
#  'Bevis Round Bullnose 29" High Table Top',
#  'Global Leather Task Chair, Black',
#  'Avanti 1.7 Cu. Ft. Refrigerator',
#  'Career Cubicle Clock, 8 1/4", Black',
#  'Xerox 1937',
#  'Hammermill Color Copier Paper (28Lb. and 96 Bright)',
#  'Xerox 1986',
#  '3M Hangers With Command Adhesive',
#  'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#  'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection',
#  'Sauder Forest Hills Library, Woodland Oak Finish',
#  'Hoover Portapower™ Portable Vacuum',
#  'Letter/Legal File Tote with Clear Snap-On Lid, Black Granite',
#  'Global Leather & Oak Executive Chair, Burgundy',
#  'Seth Thomas 12" Clock w/ Goldtone Case',
#  'Dana Halogen Swing-Arm Architect Lamp',
#  'Eldon® Expressions™ Wood Desk Accessories, Oak',
#  'Staples Plastic Wall Frames',
#  'Tenex Carpeted, Granite-Look or Clear Contemporary Contour Shape Chair Mats',
#  'Flat Face Poster Frame',
#  'SANFORD Liquid Accent™ Tank-Style Highlighters',
#  'V70',
#  'Acme® Preferred Stainless Steel Scissors',
#  'Xerox 1968',
#  'Canon S750 Color Inkjet Printer',
#  'Letter Size Cart',
#  'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish',
#  'Canon PC1080F Personal Copier',
#  'Chromcraft Rectangular Conference Tables',
#  'Newell 310',
#  'DAX Contemporary Wood Frame with Silver Metal Mat, Desktop, 11 x 14 Size',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Large Room',
#  'Global Enterprise™ Series Seating Low-Back Swivel/Tilt Chairs',
#  'Xerox 1910',
#  '8860',
#  'GBC DocuBind 300 Electric Binding Machine',
#  'Micro Innovations Micro 3000 Keyboard, Black',
#  'Self-Adhesive Address Labels for Typewriters by Universal',
#  'Fiskars® Softgrip Scissors',
#  'Micro Innovations 104 Keyboard',
#  'Fellowes PB300 Plastic Comb Binding Machine',
#  'Hewlett-Packard Deskjet 6122 Color Inkjet Printer',
#  'V70',
#  'Tuff Stuff™ Recycled Round Ring Binders',
#  'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#  'LX 788',
#  '#10 White Business Envelopes,4 1/8 x 9 1/2',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Medium Room',
#  'Xerox 199',
#  'SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black',
#  'Presstex Flexible Ring Binders',
#  'Magna Visual Magnetic Picture Hangers',
#  'Fellowes Bankers Box™ Staxonsteel® Drawer File/Stacking System',
#  'Belkin F9M820V08 8 Outlet Surge',
#  'Deluxe Rollaway Locking File with Drawer',
#  '*Staples* Highlighting Markers',
#  'Boston School Pro Electric Pencil Sharpener, 1670',
#  'Xerox 1891',
#  'Newell 309',
#  'Super Decoflex Portable Personal File',
#  'DS/HD IBM Formatted Diskettes, 10/Pack - Staples',
#  'T39m',
#  'Eldon® Wave Desk Accessories',
#  'Eldon Wave Desk Accessories',
#  'Bevis 36 x 72 Conference Tables',
#  'Southworth 25% Cotton Linen-Finish Paper & Envelopes',
#  'Lexmark Z25 Color Inkjet Printer',
#  'TDK 4.7GB DVD+RW',
#  'IBM 80 Minute CD-R Spindle, 50/Pack',
#  'Avery 478',
#  'Xerox 216',
#  '1726 Digital Answering Machine',
#  'Hon Non-Folding Utility Tables',
#  'Accessory36',
#  'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#  'Super Bands, 12/Pack',
#  'Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black',
#  'Bush Advantage Collection® Round Conference Table',
#  'Bell Sonecor JB700 Caller ID',
#  'Recycled Steel Personal File for Standard File Folders',
#  'Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock',
#  'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#  'DIXON Oriole® Pencils',
#  'StarTAC Series',
#  '#10 Self-Seal White Envelopes',
#  'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry',
#  'Xerox 1938',
#  'Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack',
#  'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins',
#  'Bevis Round Conference Table Top, X-Base',
#  'Companion Letter/Legal File, Black',
#  'TDK 4.7GB DVD-R',
#  'Binder Clips by OIC',
#  'Prismacolor Color Pencil Set',
#  'Epson DFX-8500 Dot Matrix Printer',
#  '*Staples* Letter Opener',
#  'Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle',
#  'Space Solutions Commercial Steel Shelving',
#  'Xerox 23',
#  'Acme® Elite Stainless Steel Scissors',
#  'GBC DocuBind P50 Personal Binding Machine',
#  '2160i',
#  'GBC VeloBinder Strips',
#  'Southworth 25% Cotton Linen-Finish Paper & Envelopes',
#  'Premium Writing Pencils, Soft, #2 by Central Association for the Blind',
#  'Hewlett-Packard 4.7GB DVD+R Discs',
#  'SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black',
#  'Newell 339',
#  'Global Adaptabilities™ Conference Tables',
#  '636',
#  'Avery Legal 4-Ring Binder',
#  'Acme Galleria® Hot Forged Steel Scissors with Colored Handles',
#  'Iris® 3-Drawer Stacking Bin, Black',
#  'Park Ridge™ Embossed Executive Business Envelopes',
#  'TimeportP7382',
#  'Canon MP25DIII Desktop Whisper-Quiet Printing Calculator',
#  'Canon PC940 Copier',
#  'DAX Metal Frame, Desktop, Stepped-Edge',
#  'Eldon® Expressions™ Wood and Plastic Desk Accessories, Oak',
#  'Bush Cubix Collection Bookcases, Fully Assembled',
#  'Cardinal Poly Pocket Divider Pockets for Ring Binders',
#  'Global High-Back Leather Tilter, Burgundy',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Medium Room',
#  'GE 4 Foot Flourescent Tube, 40 Watt',
#  '80 Minute CD-R Spindle, 100/Pack - Staples',
#  "O'Sullivan 2-Shelf Heavy-Duty Bookcases",
#  'Bagged Rubber Bands',
#  'Sanford Colorific Colored Pencils, 12/Box',
#  'Xerox 1891',
#  'Bagged Rubber Bands',
#  'Computer Printout Paper with Letter-Trim Perforations',
#  'Fellowes Bankers Box™ Stor/Drawer® Steel Plus™',
#  '5190',
#  'Self-Adhesive Ring Binder Labels',
#  'Bionaire Personal Warm Mist Humidifier/Vaporizer',
#  'Round Ring Binders',
#  'Fellowes EZ Multi-Media Keyboard',
#  'Avery 51',
#  'Avery Hanging File Binders',
#  'Prang Drawing Pencil Set',
#  '3M Office Air Cleaner',
#  'Bevis 36 x 72 Conference Tables',
#  'Large Capacity Hanging Post Binders',
#  'EcoTones® Memo Sheets',
#  'U.S. Robotics 56K Internet Call Modem',
#  'Staples 4 Outlet Surge Protector',
#  'Lumber Crayons',
#  'KH 688',
#  '6120',
#  ...]

# %%
# the counter data object is a convenient frequency counter
allBasketProductsCounter = Counter(allBasketProducts)
allBasketProductsCounter
# Out:
# Counter({'Xerox 1924': 4,
#          'Micro Innovations Micro 3000 Keyboard, Black': 8,
#          'Holmes Cool Mist Humidifier for the Whole House with 8-Gallon Output per Day, Extended Life Filter': 1,
#          'TDK 4.7GB DVD-R Spindle, 15/Pack': 4,
#          'Xerox 1973': 2,
#          'Career Cubicle Clock, 8 1/4", Black': 8,
#          'Avery 520': 7,
#          'Xerox 1998': 2,
#          'Safco Contoured Stacking Chairs': 2,
#          'Kensington 6 Outlet Guardian Standard Surge Protector': 4,
#          'Fellowes Premier Superior Surge Suppressor, 10-Outlet, With Phone and Remote': 2,
#          'Accessory31': 8,
#          'Computer Room Manger, 14"': 1,
#          'Xerox 1937': 8,
#          'iDENi80s': 3,
#          'Fellowes Internet Keyboard, Platinum': 8,
#          'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"': 7,
#          'Staples Wirebound Steno Books, 6" x 9", 12/Pack': 8,
#          'Avery 501': 12,
#          'Panasonic KX-P1131 Dot Matrix Printer': 6,
#          'Xerox 20': 3,
#          'DAX Wood Document Frame': 1,
#          'Phone 918': 6,
#          'Fellowes Stor/Drawer® Steel Plus™ Storage Drawers': 9,
#          'Hunt Boston® Vacuum Mount KS Pencil Sharpener': 8,
#          'Xerox 1966': 7,
#          'Sanford Pocket Accent® Highlighters': 6,
#          'Verbatim DVD Rewritable Disc, Single-Sided, 4.7GB': 1,
#          'Fellowes Smart Design 104-Key Enhanced Keyboard, PS/2 Adapter, Platinum': 4,
#          'Electrix Incandescent Magnifying Lamp, Black': 1,
#          '1/4 Fold Party Design Invitations & White Envelopes, 24 8-1/2" X 11" Cards, 25 Env./Pack': 4,
#          'IBM Active Response Keyboard, Black': 6,
#          'Imation 3.5 IBM Formatted Diskettes, 10/Box': 8,
#          'Accessory6': 9,
#          'Honeywell Enviracaire® Portable Air Cleaner for up to 8 x 10 Room': 5,
#          '6340': 6,
#          'SAFCO Arco Folding Chair': 7,
#          "O'Sullivan 2-Shelf Heavy-Duty Bookcases": 6,
#          'Avery 49': 9,
#          'GBC Poly Designer Binding Covers': 6,
#          'Airmail Envelopes': 4,
#          'Xerox 1983': 15,
#          'Avery Binding System Hidden Tab™ Executive Style Index Sets': 2,
#          'Xerox 1949': 12,
#          'Acco Perma® 2700 Stacking Storage Drawers': 9,
#          'Tenex Personal Filing Tote With Secure Closure Lid, Black/Frost': 3,
#          "O'Sullivan Living Dimensions 2-Shelf Bookcases": 5,
#          'Super Decoflex Portable Personal File': 10,
#          'Imation 3.5" Diskettes, IBM Format, DS/HD, 10/Box, Neon': 2,
#          'iDEN i550': 2,
#          'Hammermill Color Copier Paper (28Lb. and 96 Bright)': 5,
#          'Advantus Push Pins, Aluminum Head': 11,
#          'Xerox 215': 5,
#          'Wilson Jones Elliptical Ring 3 1/2" Capacity Binders, 800 sheets': 5,
#          'Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"': 15,
#          'Xerox 1947': 8,
#          'Xerox 200': 5,
#          'Satellite Sectional Post Binders': 6,
#          'Spiral Phone Message Books with Labels by Adams': 5,
#          'Hoover Portapower™ Portable Vacuum': 18,
#          'Honeywell Enviracaire® Portable HEPA Air Cleaner for up to 10 x 16 Room': 2,
#          'T60': 14,
#          'GBC DocuBind TL200 Manual Binding Machine': 3,
#          'Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators': 6,
#          'Acco® Hot Clips™ Clips to Go': 15,
#          'Bell Sonecor JB700 Caller ID': 13,
#          'Ultra Commercial Grade Dual Valve Door Closer': 5,
#          'V70': 7,
#          'SouthWestern Bell FA970 Digital Answering Machine with Time/Day Stamp': 5,
#          'Hon Olson Stacker Stools': 9,
#          'Eldon® 200 Class™ Desk Accessories, Burgundy': 4,
#          'Keytronic French Keyboard': 9,
#          'Xerox 216': 8,
#          '3285': 6,
#          'DMI Eclipse Executive Suite Bookcases': 1,
#          'Stanley Bostitch Contemporary Electric Pencil Sharpeners': 2,
#          'Global Deluxe Office Fabric Chairs': 7,
#          'Accessory41': 10,
#          'Master Caster Door Stop, Brown': 7,
#          'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages': 7,
#          'Staples File Caddy': 4,
#          'Avanti 1.7 Cu. Ft. Refrigerator': 5,
#          'Newell 329': 3,
#          'DAX Clear Channel Poster Frame': 6,
#          'Staples Premium Bright 1-Part Blank Computer Paper': 2,
#          'Avery 496': 5,
#          'Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock': 4,
#          'Memorex Slim 80 Minute CD-R, 10/Pack': 6,
#          'Atlantic Metals Mobile 5-Shelf Bookcases, Custom Colors': 2,
#          'GBC ProClick Punch Binding System': 1,
#          'Fellowes Neat Ideas® Storage Cubes': 5,
#          'Canon PC1080F Personal Copier': 8,
#          'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)': 9,
#          'Adams "While You Were Out" Message Pads': 3,
#          'Newell 321': 2,
#          'LX 788': 9,
#          'StarTAC ST7868': 3,
#          'Ibico Laser Imprintable Binding System Covers': 5,
#          'Eldon Advantage® Chair Mats for Low to Medium Pile Carpets': 1,
#          'Premium Transparent Presentation Covers by GBC': 8,
#          'Staples 10" Round Wall Clock': 2,
#          'TOPS Money Receipt Book, Consecutively Numbered in Red,': 9,
#          'Newell 333': 3,
#          'Atlantic Metals Mobile 2-Shelf Bookcases, Custom Colors': 3,
#          'C-Line Peel & Stick Add-On Filing Pockets, 8-3/4 x 5-1/8, 10/Pack': 7,
#          'Tennsco Lockers, Sand': 5,
#          'Xerox 1981': 5,
#          'Xerox 204': 3,
#          'Staples Vinyl Coated Paper Clips, 800/Box': 5,
#          'Economy Binders': 7,
#          '2300 Heavy-Duty Transfer File Systems by Perma': 4,
#          'Desktop 3-Pocket Hot File®': 3,
#          'Fellowes Super Stor/Drawer®': 4,
#          'Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer': 7,
#          'Wilson Jones Ledger-Size, Piano-Hinge Binder, 2", Blue': 5,
#          'Hunt BOSTON® Vista® Battery-Operated Pencil Sharpener, Black': 9,
#          'M70': 7,
#          'Recycled Premium Regency Composition Covers': 6,
#          'Aluminum Document Frame': 15,
#          'BASF Silver 74 Minute CD-R': 7,
#          'Newell 315': 7,
#          'Eldon Jumbo ProFile™ Portable File Boxes Graphite/Black': 9,
#          'Pizazz® Global Quick File™': 5,
#          'Acme® Box Cutter Scissors': 11,
#          'Rubber Band Ball': 3,
#          'Belkin OmniView SE Rackmount Kit': 3,
#          'Holmes 99% HEPA Air Purifier': 5,
#          'Bretford Rectangular Conference Table Tops': 11,
#          'Tenex 46" x 60" Computer Anti-Static Chairmat, Rectangular Shaped': 6,
#          'Panasonic KP-310 Heavy-Duty Electric Pencil Sharpener': 7,
#          'Avery Durable Poly Binders': 7,
#          'Recycled Eldon Regeneration Jumbo File': 12,
#          'Fellowes 8 Outlet Superior Workstation Surge Protector w/o Phone/Fax/Modem Protection': 1,
#          'Acme® Design Stainless Steel Bent Scissors': 3,
#          'Xerox 1880': 8,
#          'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish': 7,
#          'DAX Natural Wood-Tone Poster Frame': 6,
#          '2180': 11,
#          'Eldon® Image Series Desk Accessories, Burgundy': 7,
#          'Sensible Storage WireTech Storage Systems': 2,
#          'Canon P1-DHIII Palm Printing Calculator': 14,
#          'Unpadded Memo Slips': 8,
#          '6000': 4,
#          'Wausau Papers Astrobrights® Colored Envelopes': 8,
#          'Fellowes Officeware™ Wire Shelving': 2,
#          'US Robotics 56K V.92 Internal PCI Faxmodem': 9,
#          'Sterilite Officeware Hinged File Box': 3,
#          'IBM 80 Minute CD-R Spindle, 50/Pack': 7,
#          'Belkin F5C206VTEL 6 Outlet Surge': 4,
#          'Hon Rectangular Conference Tables': 5,
#          'G.E. Halogen Desk Lamp Bulbs': 6,
#          'Staples Surge Protector 6 outlet': 6,
#          'Mead 1st Gear 2" Zipper Binder, Asst. Colors': 11,
#          'Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad': 7,
#          'Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H': 7,
#          'Belkin ErgoBoard™ Keyboard': 12,
#          'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black': 11,
#          'T193': 8,
#          'Lifetime Advantage™ Folding Chairs, 4/Carton': 5,
#          "Belkin 325VA UPS Surge Protector, 6'": 3,
#          'Dana Swing-Arm Lamps': 3,
#          'Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection': 2,
#          'Nu-Dell Float Frame 11 x 14 1/2': 1,
#          'Xerox 1994': 10,
#          'Avery® Durable Slant Ring Binders With Label Holder': 3,
#          'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs': 14,
#          'Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle': 7,
#          'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"': 6,
#          'Avery Hi-Liter Comfort Grip Fluorescent Highlighter, Yellow Ink': 5,
#          'Lexmark 4227 Plus Dot Matrix Printer': 4,
#          'DS/HD IBM Formatted Diskettes, 10/Pack - Staples': 5,
#          'DAX Cubicle Frames - 8x10': 4,
#          '4009® Highlighters by Sanford': 6,
#          'Eldon Base for stackable storage shelf, platinum': 3,
#          'Panasonic KX-P1150 Dot Matrix Printer': 16,
#          '5170': 7,
#          'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate': 15,
#          'Pressboard Data Binder, Crimson, 12" X 8 1/2"': 4,
#          'Companion Letter/Legal File, Black': 6,
#          'Master Giant Foot® Doorstop, Safety Yellow': 24,
#          'Belkin 6 Outlet Metallic Surge Strip': 19,
#          'Panasonic KX-P3200 Dot Matrix Printer': 6,
#          'Xerox 1962': 4,
#          '282': 5,
#          'Fellowes Bases and Tops For Staxonsteel®/High-Stak® Systems': 5,
#          'Staples Bulldog Clip': 9,
#          'Hanging Personal Folder File': 8,
#          '7160': 2,
#          'Seth Thomas 12" Clock w/ Goldtone Case': 9,
#          'Soundgear TeleForum DX Desktop Conference Phone': 4,
#          'Executive Impressions 14"': 4,
#          'Xerox 227': 13,
#          'Prang Colored Pencils': 8,
#          'Letter/Legal File Tote with Clear Snap-On Lid, Black Granite': 6,
#          'White Business Envelopes with Contemporary Seam, Recycled White Business Envelopes': 4,
#          'Bevis Round Bullnose 29" High Table Top': 10,
#          'Panasonic All Digital Answering System with Caller ID*, KX-TM150B': 3,
#          'Acme Galleria® Hot Forged Steel Scissors with Colored Handles': 4,
#          'Eldon® Executive Woodline II Desk Accessories, Mahogany': 1,
#          'Adesso Programmable 142-Key Keyboard': 10,
#          'Hon 61000 Series Interactive Training Tables': 7,
#          'Filing/Storage Totes and Swivel Casters': 12,
#          'Fellowes Personal Hanging Folder Files, Navy': 8,
#          'Xerox 214': 7,
#          'Global Deluxe Stacking Chair, Gray': 10,
#          'Ampad #10 Peel & Seel® Holiday Envelopes': 4,
#          'Bravo II™ Megaboss® 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack': 5,
#          'Serrated Blade or Curved Handle Hand Letter Openers': 14,
#          'Logitech Access Keyboard': 12,
#          'Xerox 1979': 7,
#          'DAX Charcoal/Nickel-Tone Document Frame, 5 x 7': 2,
#          'GBC Laser Imprintable Binding System Covers, Desert Sand': 11,
#          'Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting': 8,
#          'Eldon Expressions Mahogany Wood Desk Collection': 12,
#          'Panasonic KX-P2130 Dot Matrix Printer': 1,
#          'Sanford Colorific Colored Pencils, 12/Box': 6,
#          'Xerox 1988': 2,
#          'DAX Copper Panel Document Frame, 5 x 7 Size': 6,
#          'Boston 19500 Mighty Mite Electric Pencil Sharpener': 4,
#          'Blue String-Tie & Button Interoffice Envelopes, 10 x 13': 8,
#          'Dixon Ticonderoga Core-Lock Colored Pencils, 48-Color Set': 7,
#          'Accessory2': 6,
#          'Imation 3.5" IBM-Formatted Diskettes, 10/Pack': 2,
#          '5165': 8,
#          'Global High-Back Leather Tilter, Burgundy': 27,
#          'Computer Printout Index Tabs': 1,
#          'Barricks 18" x 48" Non-Folding Utility Table with Bottom Storage Shelf': 4,
#          'Xerox 1995': 4,
#          'Global Commerce™ Series High-Back Swivel/Tilt Chairs': 10,
#          'Newell 340': 17,
#          'Iceberg OfficeWorks 42" Round Tables': 16,
#          'Sharp EL500L Fraction Calculator': 9,
#          'Staples Colored Interoffice Envelopes': 7,
#          'Newell 307': 3,
#          'Newell® 3-Hole Punched Plastic Slotted Magazine Holders for Binders': 5,
#          'Xerox 1896': 6,
#          'Imation Neon 80 Minute CD-R Spindle, 50/Pack': 6,
#          'Imation 3.5" Unformatted DS/HD Diskettes, 10/Box': 7,
#          'UniKeep™ View Case Binders': 1,
#          'Eureka Recycled Copy Paper 8 1/2" x 11", Ream': 8,
#          'Xerox 1919': 3,
#          'Westinghouse Clip-On Gooseneck Lamps': 7,
#          'TIMEPORT P8767': 3,
#          '6" Cubicle Wall Clock, Black': 5,
#          'Belkin F9M820V08 8 Outlet Surge': 9,
#          'Sauder Forest Hills Library, Woodland Oak Finish': 15,
#          'Portfile® Personal File Boxes': 11,
#          'Xerox 1984': 10,
#          'Brother DCP1000 Digital 3 in 1 Multifunction Machine': 4,
#          'Global Leather & Oak Executive Chair, Burgundy': 7,
#          'Accessory25': 8,
#          'Epson FX-980 Dot Matrix Printer': 1,
#          'Avery Flip-Chart Easel Binder, Black': 20,
#          'Xerox 1903': 4,
#          'Staples Standard Envelopes': 12,
#          'Hewlett-Packard Deskjet 6122 Color Inkjet Printer': 7,
#          'Imation 5.2GB DVD-RAM': 2,
#          'Imation DVD-RAM discs': 10,
#          'Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers': 9,
#          'DAX Metal Frame, Desktop, Stepped-Edge': 5,
#          'Epson C82 Color Inkjet Printer': 4,
#          'Xerox 1916': 3,
#          'Dana Fluorescent Magnifying Lamp, White, 36"': 5,
#          'Imation Neon Mac Format Diskettes, 10/Pack': 11,
#          'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables': 24,
#          '8290': 4,
#          'Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders': 12,
#          'Imation 3.5" DS/HD IBM Formatted Diskettes, 10/Pack': 4,
#          'Iris® 3-Drawer Stacking Bin, Black': 7,
#          'Avery Hi-Liter® Fluorescent Desk Style Markers': 7,
#          'Fellowes Mighty 8 Compact Surge Protector': 3,
#          '3M Office Air Cleaner': 8,
#          'Quartet Omega® Colored Chalk, 12/Pack': 10,
#          'Acco 3-Hole Punch': 4,
#          'Alliance Rubber Bands': 1,
#          'Newell 314': 5,
#          'Hon Every-Day® Chair Series Swivel Task Chairs': 8,
#          'Sanford Liquid Accent Highlighters': 9,
#          'Bionaire 99.97% HEPA Air Cleaner': 3,
#          'Eldon Wave Desk Accessories': 5,
#          'Home/Office Personal File Carts': 5,
#          'Chromcraft Rectangular Conference Tables': 5,
#          'Eldon Cleatmat Plus™ Chair Mats for High Pile Carpets': 5,
#          'Xerox 1977': 10,
#          'Turquoise Lead Holder with Pocket Clip': 5,
#          'Hon 5100 Series Wood Tables': 2,
#          'Xerox 1899': 9,
#          'Tensor "Hersey Kiss" Styled Floor Lamp': 8,
#          'Dana Halogen Swing-Arm Architect Lamp': 9,
#          'Hewlett-Packard Business Color Inkjet 3000 [N, DTN] Series Printers': 6,
#          'Ibico EPK-21 Electric Binding System': 3,
#          'Avery 51': 14,
#          'Xerox 1948': 4,
#          'Xerox 217': 13,
#          'Xerox 190': 6,
#          'Newell 327': 5,
#          'Xerox 220': 10,
#          'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins': 9,
#          'Avery® Durable Plastic 1" Binders': 6,
#          'Rediform S.O.S. Phone Message Books': 11,
#          'Accessory17': 4,
#          'Eldon Delta Triangular Chair Mat, 52" x 58", Clear': 3,
#          'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back': 6,
#          'Large Capacity Hanging Post Binders': 11,
#          'OIC Thumb-Tacks': 13,
#          'V 3600 Series': 5,
#          'Avery 506': 17,
#          'Staples Plastic Wall Frames': 12,
#          'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Executive Red': 1,
#          'ELITE Series': 2,
#          'Holmes Odor Grabber': 15,
#          'Timeport L7089': 13,
#          'Quality Park Security Envelopes': 2,
#          'Panasonic KP-150 Electric Pencil Sharpener': 2,
#          'Xerox 213': 11,
#          'DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7': 8,
#          'Economy Rollaway Files': 5,
#          'Avery Self-Adhesive Photo Pockets for Polaroid Photos': 12,
#          'Pressboard Covers with Storage Hooks, 9 1/2" x 11", Light Blue': 8,
#          'Personal Creations™ Ink Jet Cards and Labels': 5,
#          'Logitech Internet Navigator Keyboard': 9,
#          'Avery Poly Binder Pockets': 13,
#          'Lexmark Z25 Color Inkjet Printer': 4,
#          'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry': 11,
#          'i270': 6,
#          'Eldon Portable Mobile Manager': 6,
#          'Xerox 1936': 10,
#          'US Robotics 56K V.92 External Faxmodem': 19,
#          'Plastic Binding Combs': 1,
#          '3M Organizer Strips': 13,
#          'Executive Impressions 13-1/2" Indoor/Outdoor Wall Clock': 3,
#          'Accohide Poly Flexible Ring Binders': 3,
#          'Laser & Ink Jet Business Envelopes': 2,
#          'Avery 481': 18,
#          'Wilson Jones Easy Flow II™ Sheet Lifters': 3,
#          'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Dark Blue': 6,
#          'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb': 11,
#          '12-1/2 Diameter Round Wall Clock': 11,
#          'Artistic Insta-Plaque': 6,
#          'Decoflex Hanging Personal Folder File, Blue': 8,
#          'V8160': 3,
#          'Binney & Smith inkTank™ Erasable Desk Highlighter, Chisel Tip, Yellow, 12/Box': 6,
#          'Strathmore #10 Envelopes, Ultimate White': 1,
#          'T65': 5,
#          'R289LX': 1,
#          'Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5-1/4d x 20-1/2h, Black': 2,
#          'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac': 17,
#          'BOSTON® Ranger® #55 Pencil Sharpener, Black': 3,
#          'Xerox 1905': 11,
#          'Xerox 1964': 5,
#          'Sauder Facets Collection Locker/File Cabinet, Sky Alder Finish': 6,
#          'IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case': 7,
#          'StarTAC 7760': 18,
#          'Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 300/Messages': 5,
#          'Accessory9': 8,
#          'Acco D-Ring Binder w/DublLock®': 5,
#          'Bevis Boat-Shaped Conference Table': 6,
#          'Newell 308': 3,
#          'Global Troy™ Executive Leather Low-Back Tilter': 4,
#          'Polycom ViewStation™ ISDN Videoconferencing Unit': 3,
#          'GBC VeloBinder Strips': 10,
#          'Hon GuestStacker Chair': 4,
#          'Conquest™ 14 Commercial Heavy-Duty Upright Vacuum, Collection System, Accessory Kit': 9,
#          'Poly Designer Cover & Back': 4,
#          'Canon BP1200DH 12-Digit Bubble Jet Printing Calculator': 6,
#          'Avery White Multi-Purpose Labels': 11,
#          'Fellowes 17-key keypad for PS/2 interface': 9,
#          'Bevis Steel Folding Chairs': 9,
#          'Imation 3.5" DS-HD Macintosh Formatted Diskettes, 10/Pack': 3,
#          'Seth Thomas 13 1/2" Wall Clock': 5,
#          '36X48 HARDFLOOR CHAIRMAT': 2,
#          'Microsoft Internet Keyboard': 12,
#          'Xerox 221': 2,
#          'Memorex 4.7GB DVD-RAM, 3/Pack': 12,
#          'Tensor Computer Mounted Lamp': 4,
#          'TDK 4.7GB DVD-R': 7,
#          'Newell 31': 6,
#          'Elite 5" Scissors': 5,
#          '9-3/4 Diameter Round Wall Clock': 7,
#          'Linden® 12" Wall Clock With Oak Frame': 9,
#          'Tennsco Industrial Shelving': 7,
#          'Xerox 1991': 6,
#          'Xerox 188': 13,
#          'T28 WORLD': 9,
#          'Sharp 1540cs Digital Laser Copier': 1,
#          'TDK 4.7GB DVD+RW': 7,
#          'Safco Industrial Wire Shelving': 10,
#          'Staples 4 Outlet Surge Protector': 8,
#          'Master Caster Door Stop, Large Neon Orange': 4,
#          'Southworth 25% Cotton Antique Laid Paper & Envelopes': 6,
#          'Sauder Camden County Collection Library': 2,
#          'Xerox 1881': 17,
#          'Avery Heavy-Duty EZD ™ Binder With Locking Rings': 3,
#          'DIXON Oriole® Pencils': 3,
#          'Avery 516': 1,
#          'Xerox 1989': 6,
#          'KH 688': 4,
#          'Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat': 4,
#          'Canon PC940 Copier': 14,
#          'GBC White Gloss Covers, Plain Front': 8,
#          'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book': 9,
#          'Flexible Leather- Look Classic Collection Ring Binder': 6,
#          'Accessory24': 4,
#          'Office Star Flex Back Scooter Chair with White Frame': 7,
#          'Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops': 4,
#          'Snap-A-Way® Black Print Carbonless Speed Message, No Reply Area, Duplicate': 3,
#          'Imation 3.5, DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack': 5,
#          'Crate-A-Files™': 5,
#          'DMI Arturo Collection Mission-style Design Wood Chair': 1,
#          'GBC Standard Plastic Binding Systems Combs': 16,
#          'Office Star Flex Back Scooter Chair with Aluminum Finish Frame': 5,
#          'Acco Recycled 2" Capacity Laser Printer Hanging Data Binders': 9,
#          'Letter or Legal Size Expandable Poly String Tie Envelopes': 3,
#          'REDIFORM Incoming/Outgoing Call Register, 11" X 8 1/2", 100 Messages': 5,
#          'SANFORD Liquid Accent™ Tank-Style Highlighters': 10,
#          '2160i': 11,
#          'Eldon Expressions™ Desk Accessory, Wood Photo Frame, Mahogany': 2,
#          'TI 30X Scientific Calculator': 3,
#          'Xerox 1907': 3,
#          'Rush Hierlooms Collection 1" Thick Stackable Bookcases': 5,
#          'Eldon Antistatic Chair Mats for Low to Medium Pile Carpets': 5,
#          'Xerox 209': 1,
#          '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes': 9,
#          'Chromcraft Bull-Nose Wood Oval Conference Tables & Bases': 6,
#          'Xerox 1986': 4,
#          'Canon imageCLASS 2200 Advanced Copier': 4,
#          '3M Polarizing Task Lamp with Clamp Arm, Light Gray': 10,
#          'Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand': 2,
#          'Xerox 23': 14,
#          'Epson C62 Color Inkjet Printer': 1,
#          'Fuji Slim Jewel Case CD-R': 4,
#          'Newell 338': 7,
#          'Eldon® Expressions™ Wood Desk Accessories, Oak': 11,
#          'Colorific® Watercolor Pencils': 1,
#          'Acme® Forged Steel Scissors with Black Enamel Handles': 5,
#          'Howard Miller 16" Diameter Gallery Wall Clock': 6,
#          'Newell 325': 4,
#          'Xerox 1923': 10,
#          'Contemporary Wood/Metal Frame': 2,
#          'Wilson Jones 1" Hanging DublLock® Ring Binders': 15,
#          '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples': 13,
#          'Xerox 1971': 6,
#          'Fellowes High-Stak® Drawer Files': 1,
#          'Logitech Cordless Navigator Duo': 4,
#          'Imation 3.5", RTS 247544 3M 3.5 DSDD, 10/Pack': 9,
#          'Avery Durable Binders': 10,
#          'iDEN i95': 3,
#          'Xerox 1930': 9,
#          'Premier Elliptical Ring Binder, Black': 2,
#          'Magna Visual Magnetic Picture Hangers': 6,
#          'Bevis Round Conference Table Top, X-Base': 13,
#          'Eldon Regeneration Recycled Desk Accessories, Smoke': 10,
#          'Wilson Jones Standard D-Ring Binders': 2,
#          'White Dual Perf Computer Printout Paper, 2700 Sheets, 1 Part, Heavyweight, 20 lbs., 14 7/8 x 11': 9,
#          '6185': 4,
#          'CF 888': 4,
#          'StarTAC ST7762': 7,
#          'Adams Telephone Message Books, 5 1/4” x 11”': 2,
#          'Avery 504': 2,
#          'Okidata ML520 Series Dot Matrix Printers': 1,
#          'Model L Table or Wall-Mount Pencil Sharpener': 4,
#          'Project Tote Personal File': 7,
#          'Executive Impressions 13" Clairmont Wall Clock': 7,
#          'DIXON Ticonderoga® Erasable Checking Pencils': 3,
#          'Canon PC1060 Personal Laser Copier': 9,
#          '6162m': 3,
#          'Xerox 1982': 8,
#          'Fellowes Strictly Business® Drawer File, Letter/Legal Size': 10,
#          'Xerox 1894': 16,
#          'Hoover Replacement Belt for Commercial Guardsman Heavy-Duty Upright Vacuum': 3,
#          'SAFCO Optional Arm Kit for Workspace® Cribbage Stacking Chair': 5,
#          'Newell 332': 1,
#          'Belkin 5 Outlet SurgeMaster™ Power Centers': 5,
#          'CF 688': 8,
#          'Bretford “Just In Time” Height-Adjustable Multi-Task Work Tables': 5,
#          'EcoTones® Memo Sheets': 13,
#          'Xerox 1972': 1,
#          'Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut': 10,
#          'Howard Miller 13" Diameter Goldtone Round Wall Clock': 7,
#          'High Speed Automatic Electric Letter Opener': 2,
#          'Belkin 8 Outlet SurgeMaster II Gold Surge Protector': 8,
#          'i1000plus': 5,
#          'Dual Level, Single-Width Filing Carts': 8,
#          'GBC ProClick Spines for 32-Hole Punch': 5,
#          'Boston KS Multi-Size Manual Pencil Sharpener': 9,
#          'Riverside Furniture Stanwyck Manor Table Series': 9,
#          'AT&T Black Trimline Phone, Model 210': 6,
#          'Hon Valutask™ Swivel Chairs': 6,
#          'Fellowes Super Stor/Drawer® Files': 12,
#          'Tyvek® Side-Opening Peel & Seel® Expanding Envelopes': 8,
#          '300 Series Non-Flip': 4,
#          'Fellowes EZ Multi-Media Keyboard': 3,
#          'Office Star - Task Chair with Contemporary Loop Arms': 6,
#          'Anderson Hickey Conga Table Tops & Accessories': 11,
#          'Newell 342': 13,
#          'Xerox 1938': 6,
#          '600 Series Flip': 5,
#          'Recycled Interoffice Envelopes with Re-Use-A-Seal® Closure, 10 x 13': 3,
#          'Tennsco Double-Tier Lockers': 4,
#          'StarTAC 8000': 4,
#          'Telephone Message Books with Fax/Mobile Section, 4 1/4" x 6"': 5,
#          'Panasonic KX-P3626 Dot Matrix Printer': 5,
#          'Sanford Uni-Blazer™ View Highlighters, Chisel Tip, Yellow': 2,
#          'Catalog Binders with Expanding Posts': 9,
#          'Ibico Covers for Plastic or Wire Binding Elements': 11,
#          'T61': 3,
#          'Canon MP41DH Printing Calculator': 16,
#          'Iceberg Mobile Mega Data/Printer Cart ®': 4,
#          'AT&T 2230 Dual Handset Phone With Caller ID/Call Waiting': 8,
#          'KI Conference Tables': 13,
#          'Letter Size Cart': 7,
#          'Advantus Employee of the Month Certificate Frame, 11 x 13-1/2': 7,
#          '5170i': 3,
#          'StarTAC 3000': 5,
#          'Canon PC-428 Personal Copier': 9,
#          'Xerox 231': 4,
#          'Novimex High-Tech Fabric Mesh Task Chair': 1,
#          'Nu-Form 106-Key Ergonomic Keyboard w/ Touchpad': 6,
#          'Self-Adhesive Removable Labels': 5,
#          'Eureka The Boss® Plus 12-Amp Hard Box Upright Vacuum, Red': 1,
#          'Xerox 1935': 3,
#          'Xerox 1932': 8,
#          'Southworth Structures Collection™': 4,
#          'Fellowes Twister Kit, Gray/Clear, 3/pkg': 13,
#          'Metal Folding Chairs, Beige, 4/Carton': 8,
#          'R280': 6,
#          'Xerox 1954': 3,
#          'Carina Mini System Audio Rack, Model AR050B': 4,
#          'OIC Colored Binder Clips, Assorted Sizes': 5,
#          'Avery Premier Heavy-Duty Binder with Round Locking Rings': 2,
#          'Dixon Ticonderoga® Erasable Colored Pencil Set, 12-Color': 4,
#          'Surelock™ Post Binders': 8,
#          'C-Line Cubicle Keepers Polyproplyene Holder w/Velcro® Back, 8-1/2x11, 25/Bx': 3,
#          'StarTAC 7797': 8,
#          'Avery Printable Repositionable Plastic Tabs': 14,
#          'Lexmark Z55se Color Inkjet Printer': 4,
#          'Ibico EB-19 Dual Function Manual Binding System': 8,
#          'Howard Miller Distant Time Traveler Alarm Clock': 4,
#          'Xerox 1993': 12,
#          'Xerox 196': 9,
#          'Hon Multipurpose Stacking Arm Chairs': 8,
#          'Canon S750 Color Inkjet Printer': 4,
#          'Epson DFX-8500 Dot Matrix Printer': 1,
#          'Accessory29': 5,
#          "Global Push Button Manager's Chair, Indigo": 5,
#          'Staples Brown Kraft Recycled Clasp Envelopes': 14,
#          'Belkin 8 Outlet Surge Protector': 10,
#          'DPC 650 Piper': 1,
#          'Advantus Panel Wall Certificate Holder - 8.5x11': 5,
#          'Self-Adhesive Address Labels for Typewriters by Universal': 11,
#          'Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables': 8,
#          'Gyration Ultra Cordless Optical Suite': 8,
#          'Binney & Smith Crayola® Metallic Colored Pencils, 8-Color Set': 3,
#          'Array® Memo Cubes': 14,
#          'Hoover Upright Vacuum With Dirt Cup': 3,
#          'Xerox 1980': 3,
#          'SAFCO Mobile Desk Side File, Wire Frame': 6,
#          'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS': 17,
#          'Eldon Expressions Punched Metal & Wood Desk Accessories, Black & Cherry': 4,
#          'Message Book, Standard Line "While You Were Out", 5 1/2" X 4", 200 Sets/Book': 3,
#          'Accessory4': 6,
#          'Eldon Executive Woodline II Cherry Finish Desk Accessories': 7,
#          'Maxell DVD-RAM Discs': 7,
#          'Eldon® 400 Class™ Desk Accessories, Black Carbon': 5,
#          "O'Sullivan Elevations Bookcase, Cherry Finish": 15,
#          'Epson Stylus 1520 Color Inkjet Printer': 5,
#          'Canon MP100DHII Printing Calculator': 6,
#          'Deflect-o EconoMat Nonstudded, No Bevel Mat': 5,
#          'Avery Reinforcements for Hole-Punch Pages': 6,
#          'Okidata ML591 Wide Format Dot Matrix Printer': 4,
#          'Astroparche® Fine Business Paper': 4,
#          'Fellowes Smart Surge Ten-Outlet Protector, Platinum': 5,
#          'Stacking Tray, Side-Loading, Legal, Smoke': 2,
#          'Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”': 12,
#          'Hon Non-Folding Utility Tables': 10,
#          'Wilson Jones “Snap” Scratch Pad Binder Tool for Ring Binders': 7,
#          'Tuff Stuff™ Recycled Round Ring Binders': 6,
#          'Xerox 191': 4,
#          'Cardinal Holdit Business Card Pockets': 10,
#          'Boston 1645 Deluxe Heavier-Duty Electric Pencil Sharpener': 6,
#          'Avery Non-Stick Binders': 4,
#          'Acme® Preferred Stainless Steel Scissors': 7,
#          '688': 8,
#          'Xerox 1927': 13,
#          'Hand-Finished Solid Wood Document Frame': 4,
#          'Multimedia Mailers': 9,
#          'Xerox 1997': 11,
#          'Hon Metal Bookcases, Black': 9,
#          'Bevis Round Conference Table Top & Single Column Base': 11,
#          'Avery 487': 14,
#          'Wirebound Message Books, 2 7/8" x 5", 3 Forms per Page': 6,
#          'Zoom V.92 V.44 PCI Internal Controllerless FaxModem': 5,
#          'GBC ProClick™ 150 Presentation Binding System': 5,
#          'Staples Paper Clips': 2,
#          'Accessory34': 12,
#          'Boston 16765 Mini Stand Up Battery Pencil Sharpener': 9,
#          'Staples Metal Binder Clips': 13,
#          'Acme Kleencut® Forged Steel Scissors': 2,
#          'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”': 8,
#          'Martin-Yale Premier Letter Opener': 7,
#          'Multicolor Computer Printout Paper': 3,
#          'Xerox 1908': 6,
#          'Avery Hi-Liter® Smear-Safe Highlighters': 5,
#          'Advantus Push Pins': 4,
#          'Eldon Simplefile® Box Office®': 13,
#          "O'Sullivan 5-Shelf Heavy-Duty Bookcases": 6,
#          'SAFCO Folding Chair Trolley': 7,
#          'Kleencut® Forged Office Shears by Acme United Corporation': 12,
#          'Executive Impressions 13" Chairman Wall Clock': 7,
#          'Imation Primaris 3.5" 2HD Unformatted Diskettes, 10/Pack': 5,
#          'Ibico Recycled Linen-Style Covers': 3,
#          'Prang Dustless Chalk Sticks': 5,
#          'Avery Arch Ring Binders': 3,
#          'Boston School Pro Electric Pencil Sharpener, 1670': 6,
#          'Executive Impressions 14" Contract Wall Clock': 8,
#          'Wilson Jones Impact Binders': 12,
#          'Round Ring Binders': 10,
#          'GBC Instant Index™ System for Binding Systems': 3,
#          'DAX Solid Wood Frames': 14,
#          'Hon 4070 Series Pagoda™ Armless Upholstered Stacking Chairs': 7,
#          'Fellowes Basic 104-Key Keyboard, Platinum': 15,
#          'Barrel Sharpener': 8,
#          'Dixon Prang® Watercolor Pencils, 10-Color Set with Brush': 9,
#          'SC-3160': 5,
#          'Peel & Seel® Recycled Catalog Envelopes, Brown': 22,
#          'ACCOHIDE® Binder by Acco': 7,
#          'Sanford Colorific® Eraseable Coloring Pencils, 12 Count': 1,
#          'Xerox 226': 7,
#          'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags': 12,
#          'Imation Printable White 80 Minute CD-R Spindle, 50/Pack': 12,
#          '6162': 1,
#          'Eldon® 500 Class™ Desk Accessories': 6,
#          'Eureka Hand Vacuum, Bagless': 6,
#          'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms': 11,
#          'Black Print Carbonless 8 1/2" x 8 1/4" Rapid Memo Book': 3,
#          'Strathmore Photo Mount Cards': 6,
#          'Staples Colored Bar Computer Paper': 3,
#          'Xerox 1929': 7,
#          'Staples Pushpins': 3,
#          '8260': 8,
#          'Xerox 212': 12,
#          'Kensington 6 Outlet SmartSocket Surge Protector': 3,
#          'i500plus': 2,
#          'Crayola Colored Pencils': 2,
#          'Wilson Jones Turn Tabs Binder Tool for Ring Binders': 4,
#          'Imation IBM Formatted Diskettes, 100/Pack': 1,
#          'Acco PRESSTEX® Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"': 1,
#          'Belkin 107-key enhanced keyboard, USB/PS/2 interface': 4,
#          'Avery 508': 18,
#          'Accessory27': 6,
#          'T39m': 8,
#          'Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers': 10,
#          'Iris Project Case': 6,
#          'Deflect-o EconoMat Studded, No Bevel Mat for Low Pile Carpeting': 5,
#          'Staples 1 Part Blank Computer Paper': 4,
#          'Carina 42"Hx23 3/4"W Media Storage Unit': 5,
#          'Verbatim DVD-R, 3.95GB, SR, Mitsubishi Branded, Jewel': 10,
#          'Avery Hole Reinforcements': 4,
#          'Situations Contoured Folding Chairs, 4/Set': 4,
#          'Xerox 1893': 12,
#          'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets': 5,
#          'Talkabout T8367': 13,
#          'Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box': 8,
#          'Global Airflow Leather Mesh Back Chair, Black': 3,
#          'Global Stack Chair without Arms, Black': 13,
#          'HP Office Recycled Paper (20Lb. and 87 Bright)': 6,
#          'Xerox 1951': 4,
#          'Stockwell Push Pins': 8,
#          'Fellowes Recycled Storage Drawers': 7,
#          'Hewlett-Packard Deskjet 5550 Color Inkjet Printer': 5,
#          'Storex Dura Pro™ Binders': 5,
#          '3M Polarizing Light Filter Sleeves': 5,
#          '232': 4,
#          'Sony IBM Color Diskettes, 25/Pack': 1,
#          '3.6 Cubic Foot Counter Height Office Refrigerator': 3,
#          '5185': 5,
#          "Jet-Pak Recycled Peel 'N' Seal Padded Mailers": 9,
#          'Acco Keyboard-In-A-Box®': 1,
#          'Xerox 1963': 5,
#          'Newell 312': 15,
#          'Novimex Turbo Task Chair': 4,
#          'Bush Heritage Pine Collection 5-Shelf Bookcase, Albany Pine Finish, *Special Order': 5,
#          'Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 200/Messages': 2,
#          'Accessory21': 16,
#          'Xerox 2': 2,
#          'SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black': 9,
#          'g520': 4,
#          'Prang Drawing Pencil Set': 14,
#          'Newell 337': 15,
#          'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind': 2,
#          'Xerox 1976': 4,
#          'Deflect-o Glass Clear Studded Chair Mats': 4,
#          'Newell 339': 7,
#          'Okidata ML390 Turbo Dot Matrix Printers': 7,
#          'Xerox 1882': 5,
#          'Dot Matrix Printer Tape Reel Labels, White, 5000/Box': 2,
#          'Hoover Replacement Belts For Soft Guard™ & Commercial Ltweight Upright Vacs, 2/Pk': 6,
#          'Revere Boxed Rubber Bands by Revere': 5,
#          'Southworth 25% Cotton Premium Laser Paper and Envelopes': 14,
#          'Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black': 4,
#          'Gyration RF Keyboard': 4,
#          'Eldon® Wave Desk Accessories': 16,
#          'Tennsco Snap-Together Open Shelving Units, Starter Sets and Add-On Units': 10,
#          '8860': 10,
#          'Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)': 6,
#          'GE 4 Foot Flourescent Tube, 40 Watt': 9,
#          'Newell 343': 14,
#          'Staples #10 Colored Envelopes': 5,
#          'Newell 326': 10,
#          'Bretford CR4500 Series Slim Rectangular Table': 14,
#          'Angle-D Binders with Locking Rings, Label Holders': 12,
#          'Xerox 1917': 3,
#          'Xerox 1941': 3,
#          "O'Sullivan Manor Hill 2-Door Library in Brianna Oak": 1,
#          'Xerox 1952': 12,
#          'Colored Push Pins': 4,
#          'Heavy-Duty E-Z-D® Binders': 8,
#          'Newell 318': 6,
#          'Wirebound Message Books, 5-1/2 x 4 Forms, 2 or 4 Forms per Page': 4,
#          'T18': 7,
#          'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection': 6,
#          'Boston 16701 Slimline Battery Pencil Sharpener': 5,
#          'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4': 18,
#          'Bush Advantage Collection® Racetrack Conference Table': 5,
#          'Avery 494': 19,
#          'Global Leather Executive Chair': 3,
#          'Staples Battery-Operated Desktop Pencil Sharpener': 9,
#          'Wilson Jones Hanging View Binder, White, 1"': 23,
#          'Tennsco Commercial Shelving': 10,
#          'Global Leather Task Chair, Black': 15,
#          'Luxo Adjustable Task Clamp Lamp': 2,
#          'It\'s Hot Message Books with Stickers, 2 3/4" x 5"': 9,
#          'Novimex Fabric Task Chair': 8,
#          'Xerox 1897': 10,
#          'Xerox 1885': 8,
#          'Manila Recycled Extra-Heavyweight Clasp Envelopes, 6" x 9"': 5,
#          'Fellowes Staxonsteel® Drawer Files': 10,
#          'Logitech Cordless Keyboard': 1,
#          'Fellowes Black Plastic Comb Bindings': 7,
#          'Hon Pagoda™ Stacking Chairs': 1,
#          'PC Concepts 116 Key Quantum 3000 Keyboard': 6,
#          'Canon Image Class D660 Copier': 1,
#          'Verbatim DVD-RAM, 9.4GB, Rewritable, Type 1, DS, DataLife Plus': 8,
#          'Executive Impressions 8-1/2" Career Panel/Partition Cubicle Clock': 5,
#          'Binding Machine Supplies': 5,
#          'Newell 346': 5,
#          'Document Clip Frames': 10,
#          'Advantus Map Pennant Flags and Round Head Tacks': 8,
#          '#10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes': 5,
#          'Sauder Facets Collection Library, Sky Alder Finish': 1,
#          'i2000': 8,
#          '3395': 5,
#          '*Staples* Highlighting Markers': 15,
#          'Fluorescent Highlighters by Dixon': 5,
#          'Sanford Prismacolor® Professional Thick Lead Art Pencils, 36-Color Set': 3,
#          'Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack': 7,
#          'Trav-L-File Heavy-Duty Shuttle II, Black': 4,
#          "O'Sullivan 4-Shelf Bookcase in Odessa Pine": 1,
#          'I888 World Phone': 4,
#          'Xerox 207': 4,
#          'Martin Yale Chadless Opener Electric Letter Opener': 2,
#          'Accessory39': 4,
#          'GBC Wire Binding Strips': 8,
#          'SimpliFile™ Personal File, Black Granite, 15w x 6-15/16d x 11-1/4h': 3,
#          'Memorex 80 Minute CD-R Spindle, 100/Pack': 8,
#          'Brites Rubber Bands, 1 1/2 oz. Box': 5,
#          'Smead Adjustable Mobile File Trolley with Lockable Top': 8,
#          'Fellowes Bankers Box™ Staxonsteel® Drawer File/Stacking System': 8,
#          'Imation 3.5 IBM Diskettes, 10/Box': 2,
#          'Xerox 1985': 2,
#          '80 Minute CD-R Spindle, 100/Pack - Staples': 20,
#          'Accessory37': 6,
#          'Geographics Note Cards, Blank, White, 8 1/2" x 11"': 3,
#          'Hewlett-Packard 4.7GB DVD+R Discs': 6,
#          'Ultra Door Push Plate': 4,
#          'Boston 1799 Powerhouse™ Electric Pencil Sharpener': 2,
#          'Acco 6 Outlet Guardian Premium Surge Suppressor': 5,
#          'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue': 10,
#          'Newell 320': 6,
#          'Newell 309': 12,
#          'Hon 94000 Series Round Tables': 15,
#          'Xerox 210': 21,
#          'Assorted Color Push Pins': 7,
#          'GBC Recycled Grain Textured Covers': 5,
#          'Kensington 7 Outlet MasterPiece® HOMEOFFICE Power Control Center': 3,
#          '3390': 10,
#          'Epson DFX5000+ Dot Matrix Printer': 1,
#          'Acme® Office Executive Series Stainless Steel Trimmers': 3,
#          'Howard Miller 12-3/4 Diameter Accuwave DS ™ Wall Clock': 6,
#          'Fellowes 8 Outlet Superior Workstation Surge Protector': 2,
#          '*Staples* Letter Opener': 5,
#          'Newell 336': 14,
#          'Xerox 229': 2,
#          'Microsoft Office Keyboard': 1,
#          'Avery Binder Labels': 8,
#          'Microsoft Natural Multimedia Keyboard': 7,
#          'Staples® General Use 3-Ring Binders': 20,
#          'Hewlett-Packard 2600DN Business Color Inkjet Printer': 9,
#          'SANFORD Major Accent™ Highlighters': 14,
#          'Avery 498': 14,
#          'Kensington 4 Outlet MasterPiece® Compact Power Control Center': 3,
#          '#10- 4 1/8" x 9 1/2" Recycled Envelopes': 18,
#          'Tyvek Interoffice Envelopes, 9 1/2" x 12 1/2", 100/Box': 5,
#          'Eldon Pizzaz™ Desk Accessories': 6,
#          'White GlueTop Scratch Pads': 11,
#          'Staples 6 Outlet Surge': 20,
#          '5190': 5,
#          'Dixon My First Ticonderoga Pencil, #2': 14,
#          'Bush Westfield Collection Bookcases, Fully Assembled': 20,
#          'DS/HD IBM Formatted Diskettes, 200/Pack - Staples': 6,
#          'Ibico Hi-Tech Manual Binding System': 1,
#          'Wirebound Message Forms, Four 2 3/4 x 5 Forms per Page, Pink Paper': 3,
#          'Avery 4027 File Folder Labels for Dot Matrix Printers, 5000 Labels per Box, White': 3,
#          'Lexmark Z54se Color Inkjet Printer': 10,
#          'Hon Deluxe Fabric Upholstered Stacking Chairs': 5,
#          'Newell 35': 9,
#          'Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table': 14,
#          '1726 Digital Answering Machine': 15,
#          'Binney & Smith inkTank™ Erasable Pocket Highlighter, Chisel Tip, Yellow': 4,
#          'Tenex File Box, Personal Filing Tote with Lid, Black': 5,
#          'Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags': 8,
#          'Hon iLevel™ Computer Training Table': 13,
#          'Advantus Rolling Storage Box': 4,
#          'Tyvek ® Top-Opening Peel & Seel ® Envelopes, Gray': 6,
#          'Eureka The Boss® Cordless Rechargeable Stick Vac': 4,
#          'Executive Impressions 12" Wall Clock': 16,
#          'Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book': 3,
#          'Tennsco Lockers, Gray': 12,
#          'Premium Writing Pencils, Soft, #2 by Central Association for the Blind': 8,
#          'GBC VeloBinder Electric Binding Machine': 9,
#          'Wirebound Four 2-3/4 x 5 Forms per Page, 400 Sets per Book': 5,
#          'Maxell 4.7GB DVD-R': 2,
#          'Verbatim 4.7GB DVD-R': 2,
#          'Luxo Professional Combination Clamp-On Lamps': 2,
#          '600 Series Non-Flip': 5,
#          '5125': 8,
#          'Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black': 8,
#          'Array® Parchment Paper, Assorted Colors': 14,
#          'Avery 510': 15,
#          'Tripp Lite Isotel 6 Outlet Surge Protector with Fax/Modem Protection': 10,
#          'Bush Advantage Collection® Round Conference Table': 14,
#          'Gyration Ultra Professional Cordless Optical Suite': 8,
#          '252': 9,
#          'Luxo Economy Swing Arm Lamp': 5,
#          "O'Sullivan Living Dimensions 3-Shelf Bookcases": 4,
#          'Recycled Interoffice Envelopes with String and Button Closure, 10 x 13': 5,
#          'Durable Pressboard Binders': 16,
#          'Holmes Harmony HEPA Air Purifier for 17 x 20 Room': 4,
#          'Boston Electric Pencil Sharpener, Model 1818, Charcoal Black': 4,
#          'Euro Pro Shark Stick Mini Vacuum': 13,
#          'Wilson Jones Custom Binder Spines & Labels': 3,
#          'Xerox 1922': 16,
#          'Avery 492': 4,
#          'Presstex Flexible Ring Binders': 9,
#          'Acco Clips to Go™ Binder Clips, 24 Clips in Two Sizes': 4,
#          'Binder Posts': 12,
#          'Polycom VoiceStation 100': 4,
#          'Hewlett-Packard Deskjet 1220Cse Color Inkjet Printer': 9,
#          'Global Deluxe High-Back Office Chair in Storm': 6,
#          'Portable Personal File Box': 9,
#          'Col-Erase® Pencils with Erasers': 2,
#          "Electrix Architect's Clamp-On Swing Arm Lamp, Black": 2,
#          'Sauder Camden County Barrister Bookcase, Planked Cherry Finish': 1,
#          'Carina Double Wide Media Storage Towers in Natural & Black': 14,
#          'Avery 482': 1,
#          "O'Sullivan 3-Shelf Heavy-Duty Bookcases": 19,
#          'Xerox 1978': 8,
#          'Fellowes Mobile Numeric Keypad, Graphite': 4,
#          'Kensington 7 Outlet MasterPiece Power Center': 2,
#          'Sharp AL-1530CS Digital Copier': 8,
#          'Talkabout T8097': 5,
#          'Accessory20': 5,
#          '12 Colored Short Pencils': 15,
#          'SAFCO Commercial Wire Shelving, Black': 5,
#          'StarTAC Analog': 6,
#          'Global Ergonomic Managers Chair': 7,
#          'Speediset Carbonless Redi-Letter® 7" x 8 1/2"': 8,
#          'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum': 17,
#          'Eldon Shelf Savers™ Cubes and Bins': 7,
#          'Fellowes Mobile File Cart, Black': 1,
#          'TimeportP7382': 10,
#          'V66': 1,
#          'Avery 484': 4,
#          'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop': 11,
#          'Advantus Plastic Paper Clips': 2,
#          'Accessory35': 14,
#          'Sanford 52201 APSCO Electric Pencil Sharpener': 9,
#          'Ampad® Evidence® Wirebond Steno Books, 6" x 9"': 5,
#          'While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle': 5,
#          'Xerox 1953': 5,
#          'U.S. Robotics 56K Internet Call Modem': 9,
#          'Xerox 1887': 5,
#          'Balt Solid Wood Rectangular Table': 4,
#          'Xerox 223': 1,
#          '*Staples* vLetter Openers, 2/Pack': 7,
#          '210 Trimline Phone, White': 2,
#          'Avery 511': 5,
#          'Hon 4-Shelf Metal Bookcases': 5,
#          'Global Enterprise™ Series Seating Low-Back Swivel/Tilt Chairs': 4,
#          'Microsoft Natural Keyboard Elite': 7,
#          'Lumber Crayons': 6,
#          'Xerox 1959': 6,
#          'Avery Trapezoid Extra Heavy Duty 4" Binders': 7,
#          'Advantus Panel Wall Acrylic Frame': 1,
#          'GBC Twin Loop™ Wire Binding Elements, 9/16" Spine, Black': 3,
#          'Micro Innovations Media Access Pro Keyboard': 2,
#          'Deflect-o SuperTray™ Unbreakable Stackable Tray, Letter, Black': 5,
#          '6190': 6,
#          'Harmony HEPA Quiet Air Purifiers': 7,
#          'Bush Cubix Collection Bookcases, Fully Assembled': 5,
#          'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"': 7,
#          'Micro Innovations Micro Digital Wireless Keyboard and Mouse, Gray': 10,
#          'Wirebound Service Call Books, 5 1/2" x 4"': 6,
#          'Xerox 1934': 3,
#          'GBC DocuBind TL300 Electric Binding System': 1,
#          'Fiskars® Softgrip Scissors': 22,
#          'Xerox 1883': 1,
#          'Logitech Cordless Access Keyboard': 7,
#          'Holmes Replacement Filter for HEPA Air Cleaner, Large Room': 9,
#          'Rush Hierlooms Collection Rich Wood Bookcases': 5,
#          'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors': 3,
#          'Eldon® 300 Class™ Desk Accessories, Black': 6,
#          'Hoover Commercial Lightweight Upright Vacuum with E-Z Empty™ Dirt Cup': 2,
#          'Holmes HEPA Air Purifier': 7,
#          "O'Sullivan Cherrywood Estates Traditional Barrister Bookcase": 3,
#          'Xerox 1906': 4,
#          'Tenex Antistatic Computer Chair Mats': 3,
#          'Avery Hanging File Binders': 13,
#          'Verbatim DVD-R 4.7GB authoring disc': 5,
#          'Security-Tint Envelopes': 6,
#          'Ames Color-File® Green Diamond Border X-ray Mailers': 6,
#          'Hon 4060 Series Tables': 5,
#          'IBM 3.5" DS/HD IBM Formatted Diskettes, 50/Pack': 1,
#          'Avery File Folder Labels': 3,
#          'Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms': 7,
#          'Xerox 195': 4,
#          'Eldon® Gobal File Keepers': 14,
#          'StarTAC Series': 6,
#          'Accessory13': 8,
#          'X-Rack™ File for Hanging Folders': 6,
#          'Tenex Carpeted, Granite-Look or Clear Contemporary Contour Shape Chair Mats': 8,
#          '8890': 8,
#          'Acco Suede Grain Vinyl Round Ring Binder': 4,
#          'Tennsco Regal Shelving Units': 7,
#          'Fellowes PB300 Plastic Comb Binding Machine': 7,
#          'Bush Westfield Collection Bookcases, Dark Cherry Finish, Fully Assembled': 9,
#          'Belkin Premiere Surge Master II 8-outlet surge protector': 7,
#          'Peel-Off® China Markers': 9,
#          'Xerox 197': 11,
#          'Staples Gold Paper Clips': 5,
#          'M3682': 12,
#          'Computer Printout Paper with Letter-Trim Perforations': 20,
#          'Eldon Econocleat® Chair Mats for Low Pile Carpets': 7,
#          'Eldon Advantage® Foldable Chair Mats for Low Pile Carpets': 4,
#          'Avery Hi-Liter GlideStik Fluorescent Highlighter, Yellow Ink': 5,
#          'G.E. Longer-Life Indoor Recessed Floodlight Bulbs': 8,
#          'Accessory28': 3,
#          'Xerox 1939': 11,
#          'V2397': 3,
#          'Global Adaptabilities™ Conference Tables': 11,
#          'Bretford CR8500 Series Meeting Room Furniture': 15,
#          '6120': 8,
#          'Avery 479': 11,
#          'Xerox 1891': 9,
#          'Space Solutions Commercial Steel Shelving': 15,
#          'Coloredge Poster Frame': 11,
#          'Super Bands, 12/Pack': 8,
#          'Wilson Jones Suede Grain Vinyl Binders': 5,
#          'Xerox 1996': 8,
#          'Xerox 1992': 6,
#          'Sony MFD2HD Formatted Diskettes, 10/Pack': 5,
#          'Eldon® Expressions™ Wood and Plastic Desk Accessories, Oak': 8,
#          'Hoover WindTunnel™ Plus Canister Vacuum': 10,
#          'Polycom Soundstation EX Audio-Conferencing Telephone, Black': 3,
#          'Deflect-O® Glasstique™ Clear Desk Accessories': 7,
#          'Xerox 1895': 6,
#          'Avery Round Ring Poly Binders': 3,
#          'GBC Clear Cover, 8-1/2 x 11, unpunched, 25 covers per pack': 3,
#          'Standard Line™ “While You Were Out” Hardbound Telephone Message Book': 6,
#          'Memorex 80 Minute CD-R, 30/Pack': 8,
#          'Logitech Cordless Elite Duo': 8,
#          '#10 Self-Seal White Envelopes': 5,
#          'Park Ridge™ Embossed Executive Business Envelopes': 12,
#          'Peel & Stick Add-On Corner Pockets': 9,
#          'Staples Copy Paper (20Lb. and 84 Bright)': 13,
#          'Memo Book, 100 Message Capacity, 5 3/8” x 11”': 1,
#          'Hewlett-Packard Deskjet 3820 Color Inkjet Printer': 4,
#          '2160': 6,
#          'GBC DocuBind P50 Personal Binding Machine': 2,
#          'R380': 4,
#          '*Staples* Packaging Labels': 2,
#          'GBC DocuBind P100 Manual Binding Machine': 6,
#          'i470': 8,
#          'Avoid Verbal Orders Carbonless Minifold Book': 3,
#          'Colored Envelopes': 9,
#          'Canon Imageclass D680 Copier / Fax': 3,
#          'Eldon Image Series Black Desk Accessories': 5,
#          'Hoover® Commercial Lightweight Upright Vacuum': 5,
#          'Accessory23': 4,
#          'Hon Metal Bookcases, Putty': 5,
#          ...})

# %%
allBasketProductsCounter.most_common()
# Out:
# [('Global High-Back Leather Tilter, Burgundy', 27),
#  ('Bevis 36 x 72 Conference Tables', 25),
#  ('Master Giant Foot® Doorstop, Safety Yellow', 24),
#  ('BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables', 24),
#  ('Wilson Jones Hanging View Binder, White, 1"', 23),
#  ('Fiskars® Softgrip Scissors', 22),
#  ('Peel & Seel® Recycled Catalog Envelopes, Brown', 22),
#  ('Xerox 210', 21),
#  ('80 Minute CD-R Spindle, 100/Pack - Staples', 20),
#  ('Staples® General Use 3-Ring Binders', 20),
#  ('Staples 6 Outlet Surge', 20),
#  ('Bush Westfield Collection Bookcases, Fully Assembled', 20),
#  ('Avery Flip-Chart Easel Binder, Black', 20),
#  ('Computer Printout Paper with Letter-Trim Perforations', 20),
#  ('Avery 494', 19),
#  ('Belkin 6 Outlet Metallic Surge Strip', 19),
#  ('US Robotics 56K V.92 External Faxmodem', 19),
#  ("O'Sullivan 3-Shelf Heavy-Duty Bookcases", 19),
#  ('Storex DuraTech Recycled Plastic Frosted Binders', 19),
#  ('Boston 1730 StandUp Electric Pencil Sharpener', 19),
#  ('Avery 508', 18),
#  ('Hoover Portapower™ Portable Vacuum', 18),
#  ('Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 18),
#  ('#10- 4 1/8" x 9 1/2" Recycled Envelopes', 18),
#  ('Avery 481', 18),
#  ('StarTAC 7760', 18),
#  ('Newell 340', 17),
#  ('Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#   17),
#  ('Avery 506', 17),
#  ('Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac', 17),
#  ('Xerox 1881', 17),
#  ('Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"', 17),
#  ('Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS', 17),
#  ('Xerox 21', 17),
#  ('Newell 310', 17),
#  ('Accessory21', 16),
#  ('Eldon® Wave Desk Accessories', 16),
#  ('Panasonic KX-P1150 Dot Matrix Printer', 16),
#  ('Executive Impressions 12" Wall Clock', 16),
#  ('Durable Pressboard Binders', 16),
#  ('Xerox 1922', 16),
#  ('Iceberg OfficeWorks 42" Round Tables', 16),
#  ('Tenex Personal Project File with Scoop Front Design, Black', 16),
#  ('GBC Standard Plastic Binding Systems Combs', 16),
#  ('Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms',
#   16),
#  ('Bush Mission Pointe Library', 16),
#  ('Xerox 1894', 16),
#  ('Canon MP41DH Printing Calculator', 16),
#  ('GBC Standard Therm-A-Bind Covers', 16),
#  ('Newell 312', 15),
#  ('Newell 337', 15),
#  ('Xerox 1983', 15),
#  ('Global Leather Task Chair, Black', 15),
#  ('*Staples* Highlighting Markers', 15),
#  ('Hon 94000 Series Round Tables', 15),
#  ('Bretford CR8500 Series Meeting Room Furniture', 15),
#  ('1726 Digital Answering Machine', 15),
#  ('Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate', 15),
#  ('Avery 510', 15),
#  ('Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter',
#   15),
#  ('Sauder Forest Hills Library, Woodland Oak Finish', 15),
#  ('12 Colored Short Pencils', 15),
#  ('Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"',
#   15),
#  ('Holmes Odor Grabber', 15),
#  ('Space Solutions Commercial Steel Shelving', 15),
#  ('Acco® Hot Clips™ Clips to Go', 15),
#  ('Wilson Jones 1" Hanging DublLock® Ring Binders', 15),
#  ('Avery 491', 15),
#  ('Ibico Presentation Index for Binding Systems', 15),
#  ('GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"', 15),
#  ('Aluminum Document Frame', 15),
#  ("O'Sullivan Elevations Bookcase, Cherry Finish", 15),
#  ('Fellowes Basic 104-Key Keyboard, Platinum', 15),
#  ('Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table',
#   14),
#  ('Prang Drawing Pencil Set', 14),
#  ('Southworth 25% Cotton Premium Laser Paper and Envelopes', 14),
#  ('Newell 343', 14),
#  ('T60', 14),
#  ('Canon P1-DHIII Palm Printing Calculator', 14),
#  ('SANFORD Major Accent™ Highlighters', 14),
#  ('Avery 498', 14),
#  ('Bagged Rubber Bands', 14),
#  ('Dixon My First Ticonderoga Pencil, #2', 14),
#  ('Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs', 14),
#  ('Array® Parchment Paper, Assorted Colors', 14),
#  ('Bush Advantage Collection® Round Conference Table', 14),
#  ('Serrated Blade or Curved Handle Hand Letter Openers', 14),
#  ('Avery Printable Repositionable Plastic Tabs', 14),
#  ('Carina Double Wide Media Storage Towers in Natural & Black', 14),
#  ('Accessory35', 14),
#  ('Avery 51', 14),
#  ('Eldon® Gobal File Keepers', 14),
#  ('Newell 336', 14),
#  ('Bretford CR4500 Series Slim Rectangular Table', 14),
#  ("Lock-Up Easel 'Spel-Binder'", 14),
#  ('Avery 474', 14),
#  ('Cardinal Poly Pocket Divider Pockets for Ring Binders', 14),
#  ('Canon PC940 Copier', 14),
#  ('Xerox 23', 14),
#  ('Avery 493', 14),
#  ('DAX Solid Wood Frames', 14),
#  ('Staples Brown Kraft Recycled Clasp Envelopes', 14),
#  ('Array® Memo Cubes', 14),
#  ('Acme® 8" Straight Scissors', 14),
#  ('Avery 487', 14),
#  ('Global Stack Chair without Arms, Black', 13),
#  ('Hon iLevel™ Computer Training Table', 13),
#  ('Xerox 227', 13),
#  ('Euro Pro Shark Stick Mini Vacuum', 13),
#  ('Xerox 217', 13),
#  ('Avery Hanging File Binders', 13),
#  ('OIC Thumb-Tacks', 13),
#  ('Timeport L7089', 13),
#  ('Avery Poly Binder Pockets', 13),
#  ('3M Organizer Strips', 13),
#  ('KI Conference Tables', 13),
#  ('Staples Copy Paper (20Lb. and 84 Bright)', 13),
#  ('Xerox 188', 13),
#  ('EcoTones® Memo Sheets', 13),
#  ('Newell 323', 13),
#  ('80 Minute Slim Jewel Case CD-R , 10/Pack - Staples', 13),
#  ('Bell Sonecor JB700 Caller ID', 13),
#  ('Bevis Round Conference Table Top, X-Base', 13),
#  ('Newell 342', 13),
#  ('Fellowes Twister Kit, Gray/Clear, 3/pkg', 13),
#  ('Talkabout T8367', 13),
#  ('Xerox 1927', 13),
#  ('Staples Metal Binder Clips', 13),
#  ('Binder Clips by OIC', 13),
#  ('Eldon Simplefile® Box Office®', 13),
#  ('Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl', 13),
#  ('Xerox 212', 12),
#  ('Xerox 1893', 12),
#  ('Avery 501', 12),
#  ('Xerox 1949', 12),
#  ('Xerox 1920', 12),
#  ('Angle-D Binders with Locking Rings, Label Holders', 12),
#  ('Xerox 1952', 12),
#  ('M3682', 12),
#  ('Newell 309', 12),
#  ('Recycled Eldon Regeneration Jumbo File', 12),
#  ('Staples SlimLine Pencil Sharpener', 12),
#  ('Filing/Storage Totes and Swivel Casters', 12),
#  ('Logitech Access Keyboard', 12),
#  ('Eldon Expressions Mahogany Wood Desk Collection', 12),
#  ('Binder Posts', 12),
#  ('Staples Standard Envelopes', 12),
#  ('Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders', 12),
#  ('Park Ridge™ Embossed Executive Business Envelopes', 12),
#  ('Microsoft Internet Keyboard', 12),
#  ('Avery Self-Adhesive Photo Pockets for Polaroid Photos', 12),
#  ('Fellowes Super Stor/Drawer® Files', 12),
#  ('Memorex 4.7GB DVD-RAM, 3/Pack', 12),
#  ('Nu-Dell Executive Frame', 12),
#  ('Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge', 12),
#  ('Tenex Personal Self-Stacking Standard File Box, Black/Gray', 12),
#  ('Tennsco Lockers, Gray', 12),
#  ('Kleencut® Forged Office Shears by Acme United Corporation', 12),
#  ('Xerox 1993', 12),
#  ('Belkin ErgoBoard™ Keyboard', 12),
#  ('Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”', 12),
#  ('Accessory34', 12),
#  ('Staples Plastic Wall Frames', 12),
#  ('Global Leather and Oak Executive Chair, Black', 12),
#  ('Wilson Jones Impact Binders', 12),
#  ('Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#   12),
#  ('Imation Printable White 80 Minute CD-R Spindle, 50/Pack', 12),
#  ('Advantus Push Pins, Aluminum Head', 11),
#  ('Bretford Rectangular Conference Table Tops', 11),
#  ('Self-Adhesive Address Labels for Typewriters by Universal', 11),
#  ('2180', 11),
#  ('Mead 1st Gear 2" Zipper Binder, Asst. Colors', 11),
#  ('Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#   11),
#  ('GBC Laser Imprintable Binding System Covers, Desert Sand', 11),
#  ('Portfile® Personal File Boxes', 11),
#  ('Acme® Box Cutter Scissors', 11),
#  ('Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop', 11),
#  ('Imation Neon Mac Format Diskettes, 10/Pack', 11),
#  ('Global Adaptabilities™ Conference Tables', 11),
#  ('Rediform S.O.S. Phone Message Books', 11),
#  ('Large Capacity Hanging Post Binders', 11),
#  ('Xerox 197', 11),
#  ('Boston 16801 Nautilus™ Battery Pencil Sharpener', 11),
#  ('GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb', 11),
#  ('Xerox 1939', 11),
#  ('12-1/2 Diameter Round Wall Clock', 11),
#  ('White GlueTop Scratch Pads', 11),
#  ('Avery 479', 11),
#  ('Coloredge Poster Frame', 11),
#  ('Xerox 1905', 11),
#  ('Avery White Multi-Purpose Labels', 11),
#  ('2160i', 11),
#  ('Eldon® Expressions™ Wood Desk Accessories, Oak', 11),
#  ('Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry',
#   11),
#  ('Anderson Hickey Conga Table Tops & Accessories', 11),
#  ('Xerox 213', 11),
#  ('Ibico Covers for Plastic or Wire Binding Elements', 11),
#  ('Eldon Expressions™ Desk Accessory, Wood Pencil Holder, Oak', 11),
#  ('Hon Comfortask® Task/Swivel Chairs', 11),
#  ('Memorex 4.7GB DVD+RW, 3/Pack', 11),
#  ('Xerox 1997', 11),
#  ('Bevis Round Conference Table Top & Single Column Base', 11),
#  ('Wilson Jones DublLock® D-Ring Binders', 11),
#  ('Hon 4070 Series Pagoda™ Round Back Stacking Chairs', 11),
#  ('Accessory36', 11),
#  ('Nu-Dell Leatherette Frames', 11),
#  ('#10 White Business Envelopes,4 1/8 x 9 1/2', 11),
#  ('Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms', 11),
#  ('Maxell Pro 80 Minute CD-R, 10/Pack', 11),
#  ('Accessory8', 10),
#  ('Xerox Blank Computer Paper', 10),
#  ('Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers', 10),
#  ('Verbatim DVD-R, 3.95GB, SR, Mitsubishi Branded, Jewel', 10),
#  ('Xerox 1936', 10),
#  ('Tennsco Snap-Together Open Shelving Units, Starter Sets and Add-On Units',
#   10),
#  ('8860', 10),
#  ('Tennsco Commercial Shelving', 10),
#  ('Accessory41', 10),
#  ('Xerox 1897', 10),
#  ('Document Clip Frames', 10),
#  ('Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue', 10),
#  ('Quartet Alpha® White Chalk, 12/Pack', 10),
#  ('3390', 10),
#  ('Global Commerce™ Series High-Back Swivel/Tilt Chairs', 10),
#  ('Lexmark Z54se Color Inkjet Printer', 10),
#  ('Bevis Round Bullnose 29" High Table Top', 10),
#  ('Tripp Lite Isotel 6 Outlet Surge Protector with Fax/Modem Protection', 10),
#  ('Global Deluxe Stacking Chair, Gray', 10),
#  ('Fellowes Strictly Business® Drawer File, Letter/Legal Size', 10),
#  ('TimeportP7382', 10),
#  ('Xerox 1984', 10),
#  ('Imation DVD-RAM discs', 10),
#  ('Cardinal Holdit Business Card Pockets', 10),
#  ('Quartet Omega® Colored Chalk, 12/Pack', 10),
#  ('Xerox 1977', 10),
#  ('Micro Innovations Micro Digital Wireless Keyboard and Mouse, Gray', 10),
#  ('Xerox 220', 10),
#  ('Hoover WindTunnel™ Plus Canister Vacuum', 10),
#  ('GBC VeloBinder Strips', 10),
#  ('Safco Industrial Wire Shelving', 10),
#  ('GBC DocuBind 200 Manual Binding Machine', 10),
#  ('Hon 2111 Invitation™ Series Corner Table', 10),
#  ('SANFORD Liquid Accent™ Tank-Style Highlighters', 10),
#  ('3M Polarizing Task Lamp with Clamp Arm, Light Gray', 10),
#  ('Xerox 1923', 10),
#  ('Executive Impressions 14" Two-Color Numerals Wall Clock', 10),
#  ('Avery Durable Binders', 10),
#  ('Eldon Regeneration Recycled Desk Accessories, Smoke', 10),
#  ('Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut',
#   10),
#  ('Wirebound Voice Message Log Book', 10),
#  ('Belkin 105-Key Black Keyboard', 10),
#  ('Belkin 8 Outlet Surge Protector', 10),
#  ('Imation 3.5", DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack', 10),
#  ('Telescoping Adjustable Floor Lamp', 10),
#  ('Newell 326', 10),
#  ('Hon Non-Folding Utility Tables', 10),
#  ('Adesso Programmable 142-Key Keyboard', 10),
#  ('Fellowes Staxonsteel® Drawer Files', 10),
#  ('Super Decoflex Portable Personal File', 10),
#  ('StarTAC 6500', 10),
#  ('Xerox 1994', 10),
#  ('Round Ring Binders', 10),
#  ('Bevis Rectangular Conference Tables', 10),
#  ('Fellowes Stor/Drawer® Steel Plus™ Storage Drawers', 9),
#  ("Jet-Pak Recycled Peel 'N' Seal Padded Mailers", 9),
#  ('Peel-Off® China Markers', 9),
#  ('Accessory6', 9),
#  ('SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black',
#   9),
#  ('Avery 49', 9),
#  ('Xerox 194', 9),
#  ('Acco Perma® 2700 Stacking Storage Drawers', 9),
#  ('GE 4 Foot Flourescent Tube, 40 Watt', 9),
#  ('Keytronic French Keyboard', 9),
#  ('Staples Battery-Operated Desktop Pencil Sharpener', 9),
#  ('Hunt BOSTON® Vista® Battery-Operated Pencil Sharpener, Black', 9),
#  ('Fellowes 17-key keypad for PS/2 interface', 9),
#  ('Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)', 9),
#  ('TOPS Money Receipt Book, Consecutively Numbered in Red,', 9),
#  ('Eldon Jumbo ProFile™ Portable File Boxes Graphite/Black', 9),
#  ('Hewlett-Packard 2600DN Business Color Inkjet Printer', 9),
#  ('It\'s Hot Message Books with Stickers, 2 3/4" x 5"', 9),
#  ('White Dual Perf Computer Printout Paper, 2700 Sheets, 1 Part, Heavyweight, 20 lbs., 14 7/8 x 11',
#   9),
#  ('Newell 35', 9),
#  ('Self-Adhesive Ring Binder Labels', 9),
#  ('Staples Bulldog Clip', 9),
#  ('DAX Contemporary Wood Frame with Silver Metal Mat, Desktop, 11 x 14 Size',
#   9),
#  ('Seth Thomas 12" Clock w/ Goldtone Case', 9),
#  ('252', 9),
#  ('Hewlett-Packard Deskjet 1220Cse Color Inkjet Printer', 9),
#  ('Portable Personal File Box', 9),
#  ('Sharp EL500L Fraction Calculator', 9),
#  ('Belkin F9M820V08 8 Outlet Surge', 9),
#  ('Xerox 1899', 9),
#  ('U.S. Robotics 56K Internet Call Modem', 9),
#  ('Sanford Liquid Accent Highlighters', 9),
#  ('Sanford 52201 APSCO Electric Pencil Sharpener', 9),
#  ('Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers',
#   9),
#  ('Logitech Internet Navigator Keyboard', 9),
#  ('Xerox 1891', 9),
#  ('Conquest™ 14 Commercial Heavy-Duty Upright Vacuum, Collection System, Accessory Kit',
#   9),
#  ('Bevis Steel Folding Chairs', 9),
#  ('Peel & Stick Add-On Corner Pockets', 9),
#  ('Colored Envelopes', 9),
#  ('US Robotics 56K V.92 Internal PCI Faxmodem', 9),
#  ('Linden® 12" Wall Clock With Oak Frame', 9),
#  ('Sanford EarthWrite® Recycled Pencils, Medium Soft, #2', 9),
#  ('Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book',
#   9),
#  ('Acco Recycled 2" Capacity Laser Printer Hanging Data Binders', 9),
#  ('i1000', 9),
#  ('#10- 4 1/8" x 9 1/2" Security-Tint Envelopes', 9),
#  ('Eaton Premium Continuous-Feed Paper, 25% Cotton, Letter Size, White, 1000 Shts/Box',
#   9),
#  ('Hon Olson Stacker Stools', 9),
#  ('Imation 3.5", RTS 247544 3M 3.5 DSDD, 10/Pack', 9),
#  ('Xerox 1930', 9),
#  ('GE 48" Fluorescent Tube, Cool White Energy Saver, 34 Watts, 30/Box', 9),
#  ('Bush Westfield Collection Bookcases, Dark Cherry Finish, Fully Assembled',
#   9),
#  ('Canon PC1060 Personal Laser Copier', 9),
#  ('Southworth 25% Cotton Linen-Finish Paper & Envelopes', 9),
#  ('Hot File® 7-Pocket, Floor Stand', 9),
#  ('Boston KS Multi-Size Manual Pencil Sharpener', 9),
#  ('Riverside Furniture Stanwyck Manor Table Series', 9),
#  ('Holmes Replacement Filter for HEPA Air Cleaner, Large Room', 9),
#  ('Catalog Binders with Expanding Posts', 9),
#  ('GBC VeloBinder Electric Binding Machine', 9),
#  ('Okidata ML184 Turbo Dot Matrix Printers', 9),
#  ('Xerox 1940', 9),
#  ('Canon PC-428 Personal Copier', 9),
#  ('Multi-Use Personal File Cart and Caster Set, Three Stacking Bins', 9),
#  ('Prismacolor Color Pencil Set', 9),
#  ('Hewlett Packard LaserJet 3310 Copier', 9),
#  ('Xerox 196', 9),
#  ('Dixon Prang® Watercolor Pencils, 10-Color Set with Brush', 9),
#  ('Presstex Flexible Ring Binders', 9),
#  ('T28 WORLD', 9),
#  ('Multimedia Mailers', 9),
#  ('Hon Metal Bookcases, Black', 9),
#  ('Boston 16765 Mini Stand Up Battery Pencil Sharpener', 9),
#  ('Micro Innovations 104 Keyboard', 9),
#  ('Dana Halogen Swing-Arm Architect Lamp', 9),
#  ('LX 788', 9),
#  ('Riverleaf Stik-Withit® Designer Note Cubes®', 9),
#  ('8260', 8),
#  ('Micro Innovations Micro 3000 Keyboard, Black', 8),
#  ('Career Cubicle Clock, 8 1/4", Black', 8),
#  ('Pressboard Covers with Storage Hooks, 9 1/2" x 11", Light Blue', 8),
#  ('Xerox 1937', 8),
#  ('TI 36X Solar Scientific Calculator', 8),
#  ('Fellowes Internet Keyboard, Platinum', 8),
#  ('Staples Wirebound Steno Books, 6" x 9", 12/Pack', 8),
#  ('Surelock™ Post Binders', 8),
#  ('Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box', 8),
#  ('Stockwell Push Pins', 8),
#  ('Xerox 1978', 8),
#  ('Westinghouse Floor Lamp with Metal Mesh Shade, Black', 8),
#  ('Accessory31', 8),
#  ('Xerox 1947', 8),
#  ('Heavy-Duty E-Z-D® Binders', 8),
#  ('Xerox 216', 8),
#  ('Novimex Fabric Task Chair', 8),
#  ('Xerox 1885', 8),
#  ('Verbatim DVD-RAM, 9.4GB, Rewritable, Type 1, DS, DataLife Plus', 8),
#  ('Canon PC1080F Personal Copier', 8),
#  ('Advantus Map Pennant Flags and Round Head Tacks', 8),
#  ('i2000', 8),
#  ('Premium Transparent Presentation Covers by GBC', 8),
#  ('Memorex 80 Minute CD-R Spindle, 100/Pack', 8),
#  ('Smead Adjustable Mobile File Trolley with Lockable Top', 8),
#  ('Fellowes Bankers Box™ Staxonsteel® Drawer File/Stacking System', 8),
#  ('Xerox 1928', 8),
#  ('Xerox 1880', 8),
#  ('6120', 8),
#  ('Avery Binder Labels', 8),
#  ('Unpadded Memo Slips', 8),
#  ('T193', 8),
#  ('Xerox 193', 8),
#  ('Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags', 8),
#  ('Premium Writing Pencils, Soft, #2 by Central Association for the Blind', 8),
#  ('Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black',
#   8),
#  ('Prang Colored Pencils', 8),
#  ('Gyration Ultra Professional Cordless Optical Suite', 8),
#  ('Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting', 8),
#  ('5165', 8),
#  ('Tenex Carpeted, Granite-Look or Clear Contemporary Contour Shape Chair Mats',
#   8),
#  ('Sharp AL-1530CS Digital Copier', 8),
#  ('Eureka Recycled Copy Paper 8 1/2" x 11", Ream', 8),
#  ('Speediset Carbonless Redi-Letter® 7" x 8 1/2"', 8),
#  ('Accessory25', 8),
#  ('GBC Wire Binding Strips', 8),
#  ('3M Office Air Cleaner', 8),
#  ('Hon Every-Day® Chair Series Swivel Task Chairs', 8),
#  ('Tensor "Hersey Kiss" Styled Floor Lamp', 8),
#  ('Avery Hi-Liter Pen Style Six-Color Fluorescent Set', 8),
#  ('Accessory13', 8),
#  ('8890', 8),
#  ('DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7', 8),
#  ('Executive Impressions 14" Contract Wall Clock', 8),
#  ('Dual Level, Single-Width Filing Carts', 8),
#  ('G.E. Longer-Life Indoor Recessed Floodlight Bulbs', 8),
#  ('Decoflex Hanging Personal Folder File, Blue', 8),
#  ('Super Bands, 12/Pack', 8),
#  ('5125', 8),
#  ('Xerox 1996', 8),
#  ('Accessory9', 8),
#  ('Eldon® Expressions™ Wood and Plastic Desk Accessories, Oak', 8),
#  ('Memorex 80 Minute CD-R, 30/Pack', 8),
#  ('Logitech Cordless Elite Duo', 8),
#  ('i470', 8),
#  ('Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”',
#   8),
#  ('Wirebound Message Book, 4 per Page', 8),
#  ('Xerox 1961', 8),
#  ('Eldon Radial Chair Mat for Low to Medium Pile Carpets', 8),
#  ('Hunt Boston® Vacuum Mount KS Pencil Sharpener', 8),
#  ('Brown Kraft Recycled Envelopes', 8),
#  ('Wausau Papers Astrobrights® Colored Envelopes', 8),
#  ('Fellowes Binding Cases', 8),
#  ('AT&T 2230 Dual Handset Phone With Caller ID/Call Waiting', 8),
#  ('Hanging Personal Folder File', 8),
#  ('Xerox 1982', 8),
#  ('T39m', 8),
#  ('LX 677', 8),
#  ('HP Office Paper (20Lb. and 87 Bright)', 8),
#  ('CF 688', 8),
#  ('Belkin 8 Outlet SurgeMaster II Gold Surge Protector', 8),
#  ('Blue String-Tie & Button Interoffice Envelopes, 10 x 13', 8),
#  ('Tyvek® Side-Opening Peel & Seel® Expanding Envelopes', 8),
#  ('GBC White Gloss Covers, Plain Front', 8),
#  ('Vinyl Sectional Post Binders', 8),
#  ('Eldon ClusterMat Chair Mat with Cordless Antistatic Protection', 8),
#  ('Xerox 1932', 8),
#  ('Acme® Elite Stainless Steel Scissors', 8),
#  ('Metal Folding Chairs, Beige, 4/Carton', 8),
#  ('StarTAC 7797', 8),
#  ('Staples 4 Outlet Surge Protector', 8),
#  ('Ibico EB-19 Dual Function Manual Binding System', 8),
#  ('Hon Multipurpose Stacking Arm Chairs', 8),
#  ('Imation 3.5 IBM Formatted Diskettes, 10/Box', 8),
#  ('Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables', 8),
#  ('Gyration Ultra Cordless Optical Suite', 8),
#  ('Plymouth Boxed Rubber Bands by Plymouth', 8),
#  ('688', 8),
#  ('Fellowes Personal Hanging Folder Files, Navy', 8),
#  ('Bionaire Personal Warm Mist Humidifier/Vaporizer', 8),
#  ('Deflect-o DuraMat Antistatic Studded Beveled Mat for Medium Pile Carpeting',
#   8),
#  ('Barrel Sharpener', 8),
#  ('Xerox 1898', 8),
#  ('Avery 48', 8),
#  ('Avery 520', 7),
#  ('Project Tote Personal File', 7),
#  ('Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"', 7),
#  ('Global Ergonomic Managers Chair', 7),
#  ('Newell 339', 7),
#  ('Okidata ML390 Turbo Dot Matrix Printers', 7),
#  ('Eldon Executive Woodline II Cherry Finish Desk Accessories', 7),
#  ('Imation 3.5" Unformatted DS/HD Diskettes, 10/Box', 7),
#  ('V70', 7),
#  ('T18', 7),
#  ('Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad', 7),
#  ('Global Deluxe Office Fabric Chairs', 7),
#  ('Master Caster Door Stop, Brown', 7),
#  ('Fellowes Black Plastic Comb Bindings', 7),
#  ('M70', 7),
#  ('Newell 338', 7),
#  ('Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack', 7),
#  ('Economy Binders', 7),
#  ('Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer', 7),
#  ('BASF Silver 74 Minute CD-R', 7),
#  ('Newell 315', 7),
#  ('Assorted Color Push Pins', 7),
#  ('Panasonic KP-310 Heavy-Duty Electric Pencil Sharpener', 7),
#  ('Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 7),
#  ('Eldon® Image Series Desk Accessories, Burgundy', 7),
#  ('IBM 80 Minute CD-R Spindle, 50/Pack', 7),
#  ('Xerox 1966', 7),
#  ('Acme® Preferred Stainless Steel Scissors', 7),
#  ('Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle',
#   7),
#  ('5170', 7),
#  ('Hon 61000 Series Interactive Training Tables', 7),
#  ('IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case', 7),
#  ('Xerox 1979', 7),
#  ('Dixon Ticonderoga Core-Lock Colored Pencils, 48-Color Set', 7),
#  ('Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages', 7),
#  ('Avery Durable Poly Binders', 7),
#  ('SAFCO Arco Folding Chair', 7),
#  ('Microsoft Natural Multimedia Keyboard', 7),
#  ('Eldon Shelf Savers™ Cubes and Bins', 7),
#  ('Westinghouse Clip-On Gooseneck Lamps', 7),
#  ('Global Leather & Oak Executive Chair, Burgundy', 7),
#  ('Hewlett-Packard Deskjet 6122 Color Inkjet Printer', 7),
#  ('Wilson Jones “Snap” Scratch Pad Binder Tool for Ring Binders', 7),
#  ('Iris® 3-Drawer Stacking Bin, Black', 7),
#  ('Avery Hi-Liter® Fluorescent Desk Style Markers', 7),
#  ('Microsoft Natural Keyboard Elite', 7),
#  ('Avery Trapezoid Extra Heavy Duty 4" Binders', 7),
#  ('Logitech Cordless Access Keyboard', 7),
#  ('Holmes HEPA Air Purifier', 7),
#  ('Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms', 7),
#  ('Tennsco Regal Shelving Units', 7),
#  ('Fellowes PB300 Plastic Comb Binding Machine', 7),
#  ('Belkin Premiere Surge Master II 8-outlet surge protector', 7),
#  ('Eldon Econocleat® Chair Mats for Low Pile Carpets', 7),
#  ('*Staples* vLetter Openers, 2/Pack', 7),
#  ('Xerox 1929', 7),
#  ('9-3/4 Diameter Round Wall Clock', 7),
#  ('Deflect-O® Glasstique™ Clear Desk Accessories', 7),
#  ('C-Line Peel & Stick Add-On Filing Pockets, 8-3/4 x 5-1/8, 10/Pack', 7),
#  ('TDK 4.7GB DVD-R', 7),
#  ('Tennsco Industrial Shelving', 7),
#  ('TDK 4.7GB DVD+RW', 7),
#  ('Eldon Cleatmat® Chair Mats for Medium Pile Carpets', 7),
#  ('Harmony HEPA Quiet Air Purifiers', 7),
#  ('Office Star Flex Back Scooter Chair with White Frame', 7),
#  ('Master Caster Door Stop, Gray', 7),
#  ('GBC Binding covers', 7),
#  ('GBC Plastic Binding Combs', 7),
#  ('Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H', 7),
#  ('StarTAC ST7762', 7),
#  ('Executive Impressions 13" Clairmont Wall Clock', 7),
#  ('Staples Colored Interoffice Envelopes', 7),
#  ('Howard Miller 13" Diameter Goldtone Round Wall Clock', 7),
#  ('Letter Size Cart', 7),
#  ('Regeneration Desk Collection', 7),
#  ('Advantus Employee of the Month Certificate Frame, 11 x 13-1/2', 7),
#  ('KF 788', 7),
#  ('Fellowes Recycled Storage Drawers', 7),
#  ('GBC Imprintable Covers', 7),
#  ('Epson LQ-570e Dot Matrix Printer', 7),
#  ('Wilson Jones® Four-Pocket Poly Binders', 7),
#  ('Maxell DVD-RAM Discs', 7),
#  ('XtraLife® ClearVue™ Slant-D® Ring Binders by Cardinal', 7),
#  ('Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"', 7),
#  ('Xerox 214', 7),
#  ('Martin-Yale Premier Letter Opener', 7),
#  ('Newell 335', 7),
#  ('SAFCO Folding Chair Trolley', 7),
#  ('Executive Impressions 13" Chairman Wall Clock', 7),
#  ('Hon 4070 Series Pagoda™ Armless Upholstered Stacking Chairs', 7),
#  ('ACCOHIDE® Binder by Acco', 7),
#  ('Xerox 226', 7),
#  ('Accessory27', 6),
#  ('Iris Project Case', 6),
#  ('Panasonic KX-P1131 Dot Matrix Printer', 6),
#  ('Phone 918', 6),
#  ('HP Office Recycled Paper (20Lb. and 87 Bright)', 6),
#  ('Sanford Pocket Accent® Highlighters', 6),
#  ('Xerox 190', 6),
#  ('IBM Active Response Keyboard, Black', 6),
#  ('6340', 6),
#  ("O'Sullivan 2-Shelf Heavy-Duty Bookcases", 6),
#  ('6190', 6),
#  ('Avery 52', 6),
#  ('Hoover Replacement Belts For Soft Guard™ & Commercial Ltweight Upright Vacs, 2/Pk',
#   6),
#  ('Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)', 6),
#  ('StarTAC Analog', 6),
#  ('Satellite Sectional Post Binders', 6),
#  ('Xerox 1971', 6),
#  ('Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators', 6),
#  ('Newell 318', 6),
#  ('Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection',
#   6),
#  ('Global Deluxe High-Back Office Chair in Storm', 6),
#  ('DAX Clear Channel Poster Frame', 6),
#  ('Memorex Slim 80 Minute CD-R, 10/Pack', 6),
#  ('PC Concepts 116 Key Quantum 3000 Keyboard', 6),
#  ('Recycled Premium Regency Composition Covers', 6),
#  ('Boston School Pro Electric Pencil Sharpener, 1670', 6),
#  ('Accessory37', 6),
#  ("Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room", 6),
#  ('Howard Miller 12-3/4 Diameter Accuwave DS ™ Wall Clock', 6),
#  ('DAX Natural Wood-Tone Poster Frame', 6),
#  ('G.E. Halogen Desk Lamp Bulbs', 6),
#  ('Staples Surge Protector 6 outlet', 6),
#  ('Eldon Pizzaz™ Desk Accessories', 6),
#  ('DS/HD IBM Formatted Diskettes, 200/Pack - Staples', 6),
#  ('4009® Highlighters by Sanford', 6),
#  ('Tyvek ® Top-Opening Peel & Seel ® Envelopes, Gray', 6),
#  ('Canon MP100DHII Printing Calculator', 6),
#  ('Companion Letter/Legal File, Black', 6),
#  ('Panasonic KX-P3200 Dot Matrix Printer', 6),
#  ('Letter/Legal File Tote with Clear Snap-On Lid, Black Granite', 6),
#  ('Sanford Colorific Colored Pencils, 12/Box', 6),
#  ('DAX Copper Panel Document Frame, 5 x 7 Size', 6),
#  ('Accessory2', 6),
#  ('Xerox 1896', 6),
#  ('Imation Neon 80 Minute CD-R Spindle, 50/Pack', 6),
#  ('Boston Model 1800 Electric Pencil Sharpener, Gray', 6),
#  ('Xerox 1989', 6),
#  ('Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"',
#   6),
#  ('Hewlett-Packard Business Color Inkjet 3000 [N, DTN] Series Printers', 6),
#  ('Wirebound Service Call Books, 5 1/2" x 4"', 6),
#  ('Eldon® 300 Class™ Desk Accessories, Black', 6),
#  ('Sauder Facets Collection Locker/File Cabinet, Sky Alder Finish', 6),
#  ('Security-Tint Envelopes', 6),
#  ('Ames Color-File® Green Diamond Border X-ray Mailers', 6),
#  ('StarTAC Series', 6),
#  ('i270', 6),
#  ('Eldon Portable Mobile Manager', 6),
#  ('Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Dark Blue', 6),
#  ('Artistic Insta-Plaque', 6),
#  ('Binney & Smith inkTank™ Erasable Desk Highlighter, Chisel Tip, Yellow, 12/Box',
#   6),
#  ('Hon Valutask™ Swivel Chairs', 6),
#  ('Xerox 1992', 6),
#  ('Xerox 1895', 6),
#  ('Standard Line™ “While You Were Out” Hardbound Telephone Message Book', 6),
#  ('Xerox 1959', 6),
#  ('Canon BP1200DH 12-Digit Bubble Jet Printing Calculator', 6),
#  ('X-Rack™ File for Hanging Folders', 6),
#  ('2160', 6),
#  ('Newell 31', 6),
#  ('Keytronic 105-Key Spanish Keyboard', 6),
#  ('Tuff Stuff™ Recycled Round Ring Binders', 6),
#  ('Xerox 1991', 6),
#  ('Hammermill CopyPlus Copy Paper (20Lb. and 84 Bright)', 6),
#  ('Southworth 25% Cotton Antique Laid Paper & Envelopes', 6),
#  ('Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base', 6),
#  ('Flexible Leather- Look Classic Collection Ring Binder', 6),
#  ('Avanti 4.4 Cu. Ft. Refrigerator', 6),
#  ('Okidata ML320 Series Turbo Dot Matrix Printers', 6),
#  ('AT&T Black Trimline Phone, Model 210', 6),
#  ('Holmes Replacement Filter for HEPA Air Cleaner, Medium Room', 6),
#  ('Chromcraft Bull-Nose Wood Oval Conference Tables & Bases', 6),
#  ('Howard Miller 16" Diameter Gallery Wall Clock', 6),
#  ('Xerox 199', 6),
#  ('Newell 320', 6),
#  ('Magna Visual Magnetic Picture Hangers', 6),
#  ('"While you Were Out" Message Book, One Form per Page', 6),
#  ('GBC Recycled Regency Composition Covers', 6),
#  ('Chromcraft Bull-Nose Wood Round Conference Table Top, Wood Base', 6),
#  ('Xerox 1933', 6),
#  ('Belkin MediaBoard 104- Keyboard', 6),
#  ('3285', 6),
#  ('Bevis Boat-Shaped Conference Table', 6),
#  ('Office Star - Task Chair with Contemporary Loop Arms', 6),
#  ('Xerox 1938', 6),
#  ('Lumber Crayons', 6),
#  ('Deluxe Rollaway Locking File with Drawer', 6),
#  ('#6 3/4 Gummed Flap White Envelopes', 6),
#  ('5180', 6),
#  ('Nu-Form 106-Key Ergonomic Keyboard w/ Touchpad', 6),
#  ('Accessory4', 6),
#  ('R280', 6),
#  ('Chromcraft 48" x 96" Racetrack Double Pedestal Table', 6),
#  ('GBC DocuBind P100 Manual Binding Machine', 6),
#  ('Tenex 46" x 60" Computer Anti-Static Chairmat, Rectangular Shaped', 6),
#  ('Avery 485', 6),
#  ('BPI Conference Tables', 6),
#  ('SAFCO Mobile Desk Side File, Wire Frame', 6),
#  ('Hewlett-Packard 4.7GB DVD+R Discs', 6),
#  ('GBC Poly Designer Binding Covers', 6),
#  ('Avery Reinforcements for Hole-Punch Pages', 6),
#  ('Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 6),
#  ('Avery® Durable Plastic 1" Binders', 6),
#  ('Rogers® Profile Extra Capacity Storage Tub', 6),
#  ('Boston 1645 Deluxe Heavier-Duty Electric Pencil Sharpener', 6),
#  ('Wirebound Message Books, 2 7/8" x 5", 3 Forms per Page', 6),
#  ('Xerox 1908', 6),
#  ("O'Sullivan 5-Shelf Heavy-Duty Bookcases", 6),
#  ('Eureka Hand Vacuum, Bagless', 6),
#  ('DAX Wood Document Frame.', 6),
#  ('Electrix Halogen Magnifier Lamp', 6),
#  ('Eldon® 500 Class™ Desk Accessories', 6),
#  ('Strathmore Photo Mount Cards', 6),
#  ('Telephone Message Books with Fax/Mobile Section, 4 1/4" x 6"', 5),
#  ('Accessory32', 5),
#  ('Deflect-o EconoMat Studded, No Bevel Mat for Low Pile Carpeting', 5),
#  ('Carina 42"Hx23 3/4"W Media Storage Unit', 5),
#  ('Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets', 5),
#  ('Hewlett-Packard Deskjet 5550 Color Inkjet Printer', 5),
#  ("O'Sullivan Living Dimensions 2-Shelf Bookcases", 5),
#  ('Storex Dura Pro™ Binders', 5),
#  ('3M Polarizing Light Filter Sleeves', 5),
#  ('5185', 5),
#  ('Xerox 1963', 5),
#  ('Global Enterprise Series Seating High-Back Swivel/Tilt Chairs', 5),
#  ('Honeywell Enviracaire® Portable Air Cleaner for up to 8 x 10 Room', 5),
#  ('Honeywell Quietcare HEPA Air Cleaner', 5),
#  ('Staples Gold Paper Clips', 5),
#  ('Xerox 1882', 5),
#  ('Revere Boxed Rubber Bands by Revere', 5),
#  ('Hammermill Color Copier Paper (28Lb. and 96 Bright)', 5),
#  ('Xerox 215', 5),
#  ('Staples #10 Colored Envelopes', 5),
#  ('Ultra Commercial Grade Dual Valve Door Closer', 5),
#  ('SouthWestern Bell FA970 Digital Answering Machine with Time/Day Stamp', 5),
#  ('Sony MFD2HD Formatted Diskettes, 10/Pack', 5),
#  ('Bush Advantage Collection® Racetrack Conference Table', 5),
#  ('Avanti 1.7 Cu. Ft. Refrigerator', 5),
#  ('Manila Recycled Extra-Heavyweight Clasp Envelopes, 6" x 9"', 5),
#  ('Avery 496', 5),
#  ('Fellowes Neat Ideas® Storage Cubes', 5),
#  ('Executive Impressions 8-1/2" Career Panel/Partition Cubicle Clock', 5),
#  ('Binding Machine Supplies', 5),
#  ('Newell 346', 5),
#  ('#10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes', 5),
#  ('Fluorescent Highlighters by Dixon', 5),
#  ('Ibico Laser Imprintable Binding System Covers', 5),
#  ('Staples Vinyl Coated Paper Clips, 800/Box', 5),
#  ('Wilson Jones Ledger-Size, Piano-Hinge Binder, 2", Blue', 5),
#  ('Brites Rubber Bands, 1 1/2 oz. Box', 5),
#  ('3395', 5),
#  ('Acco 6 Outlet Guardian Premium Surge Suppressor', 5),
#  ('Pizazz® Global Quick File™', 5),
#  ('GBC Recycled Grain Textured Covers', 5),
#  ('Holmes 99% HEPA Air Purifier', 5),
#  ('*Staples* Letter Opener', 5),
#  ('Newell 314', 5),
#  ('5190', 5),
#  ('Lifetime Advantage™ Folding Chairs, 4/Carton', 5),
#  ('Talkabout T8097', 5),
#  ('Hon Deluxe Fabric Upholstered Stacking Chairs', 5),
#  ('Avery Hi-Liter Comfort Grip Fluorescent Highlighter, Yellow Ink', 5),
#  ('DS/HD IBM Formatted Diskettes, 10/Pack - Staples', 5),
#  ('282', 5),
#  ('Fellowes Bases and Tops For Staxonsteel®/High-Stak® Systems', 5),
#  ('Wirebound Four 2-3/4 x 5 Forms per Page, 400 Sets per Book', 5),
#  ('600 Series Non-Flip', 5),
#  ('GBC Therma-A-Bind 250T Electric Binding System', 5),
#  ('GBC ProClick™ 150 Presentation Binding System', 5),
#  ('Recycled Interoffice Envelopes with String and Button Closure, 10 x 13', 5),
#  ('Bravo II™ Megaboss® 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack',
#   5),
#  ('ACCOHIDE® 3-Ring Binder, Blue, 1"', 5),
#  ('Bush Heritage Pine Collection 5-Shelf Bookcase, Albany Pine Finish, *Special Order',
#   5),
#  ('Acco D-Ring Binder w/DublLock®', 5),
#  ('Newell® 3-Hole Punched Plastic Slotted Magazine Holders for Binders', 5),
#  ('Accessory20', 5),
#  ('Xerox 19', 5),
#  ('SAFCO Commercial Wire Shelving, Black', 5),
#  ('6" Cubicle Wall Clock, Black', 5),
#  ('Ampad® Evidence® Wirebond Steno Books, 6" x 9"', 5),
#  ('While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle', 5),
#  ('DAX Metal Frame, Desktop, Stepped-Edge', 5),
#  ('SAFCO Optional Arm Kit for Workspace® Cribbage Stacking Chair', 5),
#  ('Avery 511', 5),
#  ('Hon 4-Shelf Metal Bookcases', 5),
#  ('#10 Self-Seal White Envelopes', 5),
#  ('Eldon Wave Desk Accessories', 5),
#  ('Home/Office Personal File Carts', 5),
#  ('Chromcraft Rectangular Conference Tables', 5),
#  ('Eldon Cleatmat Plus™ Chair Mats for High Pile Carpets', 5),
#  ('Turquoise Lead Holder with Pocket Clip', 5),
#  ('Deflect-o SuperTray™ Unbreakable Stackable Tray, Letter, Black', 5),
#  ('270c', 5),
#  ('Newell 327', 5),
#  ('Rush Hierlooms Collection Rich Wood Bookcases', 5),
#  ('Verbatim DVD-R 4.7GB authoring disc', 5),
#  ('Hon 4060 Series Tables', 5),
#  ('V 3600 Series', 5),
#  ('Xerox 1887', 5),
#  ('T65', 5),
#  ('Personal Creations™ Ink Jet Cards and Labels', 5),
#  ('Tyvek Interoffice Envelopes, 9 1/2" x 12 1/2", 100/Box', 5),
#  ('6160', 5),
#  ('GBC ProClick Spines for 32-Hole Punch', 5),
#  ('Avery Hi-Liter GlideStik Fluorescent Highlighter, Yellow Ink', 5),
#  ('VTech VT20-2481 2.4GHz Two-Line Phone System w/Answering Machine', 5),
#  ('Zoom V.92 V.44 PCI Internal Controllerless FaxModem', 5),
#  ('Wilson Jones Elliptical Ring 3 1/2" Capacity Binders, 800 sheets', 5),
#  ('Xerox 1964', 5),
#  ('Xerox 1968', 5),
#  ('Wilson Jones Suede Grain Vinyl Binders', 5),
#  ('Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 300/Messages',
#   5),
#  ('Elite 5" Scissors', 5),
#  ('Bush Cubix Collection Bookcases, Fully Assembled', 5),
#  ('Seth Thomas 13 1/2" Wall Clock', 5),
#  ('TOPS Voice Message Log Book, Flash Format', 5),
#  ('Eldon Image Series Black Desk Accessories', 5),
#  ('Hoover® Commercial Lightweight Upright Vacuum', 5),
#  ('Hon Metal Bookcases, Putty', 5),
#  ('Xerox 198', 5),
#  ('Boston 16701 Slimline Battery Pencil Sharpener', 5),
#  ('Crate-A-Files™', 5),
#  ('Office Star Flex Back Scooter Chair with Aluminum Finish Frame', 5),
#  ('Hon Rectangular Conference Tables', 5),
#  ('REDIFORM Incoming/Outgoing Call Register, 11" X 8 1/2", 100 Messages', 5),
#  ('Rush Hierlooms Collection 1" Thick Stackable Bookcases', 5),
#  ('Eldon Antistatic Chair Mats for Low to Medium Pile Carpets', 5),
#  ('Tenex File Box, Personal Filing Tote with Lid, Black', 5),
#  ('Acme® Forged Steel Scissors with Black Enamel Handles', 5),
#  ('Xerox 200', 5),
#  ('Tennsco Lockers, Sand', 5),
#  ('Xerox 1892', 5),
#  ('Sterling Rubber Bands by Alliance', 5),
#  ('Seth Thomas 14" Putty-Colored Wall Clock', 5),
#  ('Crayola Anti Dust Chalk, 12/Pack', 5),
#  ('Staples Vinyl Coated Paper Clips', 5),
#  ('Dana Fluorescent Magnifying Lamp, White, 36"', 5),
#  ('Belkin 5 Outlet SurgeMaster™ Power Centers', 5),
#  ('Bretford “Just In Time” Height-Adjustable Multi-Task Work Tables', 5),
#  ('i1000plus', 5),
#  ('OIC Colored Binder Clips, Assorted Sizes', 5),
#  ('600 Series Flip', 5),
#  ('Panasonic KX-P3626 Dot Matrix Printer', 5),
#  ('Imation Primaris 3.5" 2HD Unformatted Diskettes, 10/Pack', 5),
#  ('Luxo Economy Swing Arm Lamp', 5),
#  ('Economy Rollaway Files', 5),
#  ('Recycled Steel Personal File for Standard File Folders', 5),
#  ('Self-Adhesive Removable Labels', 5),
#  ('Laminate Occasional Tables', 5),
#  ('Advantus 10-Drawer Portable Organizer, Chrome Metal Frame, Smoke Drawers',
#   5),
#  ('StarTAC 3000', 5),
#  ('Hayes Optima 56K V.90 Internal Voice Modem', 5),
#  ('SC-3160', 5),
#  ('Imation 3.5, DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack', 5),
#  ('Accessory29', 5),
#  ("Global Push Button Manager's Chair, Indigo", 5),
#  ('Advantus Panel Wall Certificate Holder - 8.5x11', 5),
#  ('Xerox 1904', 5),
#  ('Zebra Zazzle Fluorescent Highlighters', 5),
#  ('Eldon® 400 Class™ Desk Accessories, Black Carbon', 5),
#  ('Flat Face Poster Frame', 5),
#  ('Epson Stylus 1520 Color Inkjet Printer', 5),
#  ('Xerox 1953', 5),
#  ('Deflect-o EconoMat Nonstudded, No Bevel Mat', 5),
#  ('Staples Pen Style Liquid Stix; Assorted (yellow, pink, green, blue, orange), 5/Pack',
#   5),
#  ('Fellowes Smart Surge Ten-Outlet Protector, Platinum', 5),
#  ('Spiral Phone Message Books with Labels by Adams', 5),
#  ('Tenex B1-RE Series Chair Mats for Low Pile Carpets', 5),
#  ('Dixon Ticonderoga Core-Lock Colored Pencils', 5),
#  ('Avery 05222 Permanent Self-Adhesive File Folder Labels for Typewriters, on Rolls, White, 250/Roll',
#   5),
#  ('Avery Hi-Liter® Smear-Safe Highlighters', 5),
#  ('Prang Dustless Chalk Sticks', 5),
#  ('Xerox 1981', 5),
#  ('Avery 503', 5),
#  ('Ultra Door Pull Handle', 5),
#  ('Avery 507', 5),
#  ("O'Sullivan Living Dimensions 3-Shelf Bookcases", 4),
#  ('Xerox 1924', 4),
#  ('TDK 4.7GB DVD-R Spindle, 15/Pack', 4),
#  ('Wilson Jones Turn Tabs Binder Tool for Ring Binders', 4),
#  ('Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops', 4),
#  ('Avery Hole Reinforcements', 4),
#  ('Fuji Slim Jewel Case CD-R', 4),
#  ('232', 4),
#  ('Fellowes Smart Design 104-Key Enhanced Keyboard, PS/2 Adapter, Platinum',
#   4),
#  ('1/4 Fold Party Design Invitations & White Envelopes, 24 8-1/2" X 11" Cards, 25 Env./Pack',
#   4),
#  ('Novimex Turbo Task Chair', 4),
#  ('g520', 4),
#  ('Airmail Envelopes', 4),
#  ('Deflect-o Glass Clear Studded Chair Mats', 4),
#  ('Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black', 4),
#  ('Xerox 207', 4),
#  ('Accessory39', 4),
#  ('Wirebound Message Books, 5-1/2 x 4 Forms, 2 or 4 Forms per Page', 4),
#  ('Acco Clips to Go™ Binder Clips, 24 Clips in Two Sizes', 4),
#  ('Polycom VoiceStation 100', 4),
#  ('Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock', 4),
#  ('Staples 1 Part Blank Computer Paper', 4),
#  ('Ultra Door Push Plate', 4),
#  ('Trav-L-File Heavy-Duty Shuttle II, Black', 4),
#  ('I888 World Phone', 4),
#  ('Advantus Rolling Storage Box', 4),
#  ('2300 Heavy-Duty Transfer File Systems by Perma', 4),
#  ('Fellowes Super Stor/Drawer®', 4),
#  ('Colored Push Pins', 4),
#  ('Fellowes Mobile Numeric Keypad, Graphite', 4),
#  ('6000', 4),
#  ('Xerox 1951', 4),
#  ('Belkin F5C206VTEL 6 Outlet Surge', 4),
#  ('3M Hangers With Command Adhesive', 4),
#  ('Eldon Expressions Punched Metal & Wood Desk Accessories, Black & Cherry',
#   4),
#  ('DAX Cubicle Frames - 8x10', 4),
#  ('Pressboard Data Binder, Crimson, 12" X 8 1/2"', 4),
#  ('Fellowes Bankers Box™ Stor/Drawer® Steel Plus™', 4),
#  ('Eureka The Boss® Cordless Rechargeable Stick Vac', 4),
#  ('Xerox 1962', 4),
#  ('Verbatim DVD-R, 4.7GB, Spindle, WE, Blank, Ink Jet/Thermal, 20/Spindle', 4),
#  ('Executive Impressions 14"', 4),
#  ('Avery 497', 4),
#  ('White Business Envelopes with Contemporary Seam, Recycled White Business Envelopes',
#   4),
#  ('Acme Galleria® Hot Forged Steel Scissors with Colored Handles', 4),
#  ('Ampad #10 Peel & Seel® Holiday Envelopes', 4),
#  ('Holmes Harmony HEPA Air Purifier for 17 x 20 Room', 4),
#  ('Gyration RF Keyboard', 4),
#  ('Boston Electric Pencil Sharpener, Model 1818, Charcoal Black', 4),
#  ('Kensington 6 Outlet Guardian Standard Surge Protector', 4),
#  ('Boston 19500 Mighty Mite Electric Pencil Sharpener', 4),
#  ('Eldon® 200 Class™ Desk Accessories, Burgundy', 4),
#  ('Barricks 18" x 48" Non-Folding Utility Table with Bottom Storage Shelf', 4),
#  ('Avery 484', 4),
#  ('Global Troy™ Executive Leather Low-Back Tilter', 4),
#  ('Brother DCP1000 Digital 3 in 1 Multifunction Machine', 4),
#  ('Xerox 1903', 4),
#  ('Balt Solid Wood Rectangular Table', 4),
#  ('Epson C82 Color Inkjet Printer', 4),
#  ('8290', 4),
#  ('Imation 3.5" DS/HD IBM Formatted Diskettes, 10/Pack', 4),
#  ('Poly Designer Cover & Back', 4),
#  ('Hand-Finished Solid Wood Document Frame', 4),
#  ('Xerox 1948', 4),
#  ('Acco Four Pocket Poly Ring Binder with Label Holder, Smoke, 1"', 4),
#  ('Xerox 1906', 4),
#  ('Master Caster Door Stop, Large Neon Orange', 4),
#  ('Accessory17', 4),
#  ('Electrix 20W Halogen Replacement Bulb for Zoom-In Desk Lamp', 4),
#  ('Xerox 195', 4),
#  ('Acco Suede Grain Vinyl Round Ring Binder', 4),
#  ('Lexmark Z25 Color Inkjet Printer', 4),
#  ('Eldon® 200 Class™ Desk Accessories', 4),
#  ('Xerox 1976', 4),
#  ('Eldon Advantage® Foldable Chair Mats for Low Pile Carpets', 4),
#  ('Binney & Smith inkTank™ Erasable Pocket Highlighter, Chisel Tip, Yellow',
#   4),
#  ('Accessory24', 4),
#  ('Advantus Push Pins', 4),
#  ('Hon GuestStacker Chair', 4),
#  ('Belkin 107-key enhanced keyboard, USB/PS/2 interface', 4),
#  ('Hewlett-Packard Deskjet 3820 Color Inkjet Printer', 4),
#  ('Tensor Computer Mounted Lamp', 4),
#  ('R380', 4),
#  ('Astroparche® Fine Business Paper', 4),
#  ('Acco 3-Hole Punch', 4),
#  ('Acco Smartsocket® Color-Coded Six-Outlet AC Adapter Model Surge Protectors',
#   4),
#  ('KH 688', 4),
#  ('Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat',
#   4),
#  ('Staples Bulk Pack Metal Binder Clips', 4),
#  ('2190', 4),
#  ('Situations Contoured Folding Chairs, 4/Set', 4),
#  ('Motorola SB4200 Cable Modem', 4),
#  ('V3682', 4),
#  ('StarTAC 8000', 4),
#  ('Xerox 1986', 4),
#  ('Canon imageCLASS 2200 Advanced Copier', 4),
#  ('Targus USB Numeric Keypad', 4),
#  ('Newell 325', 4),
#  ('Logitech Cordless Navigator Duo', 4),
#  ('Acme Hot Forged Carbon Steel Scissors with Nickel-Plated Handles, 3 7/8" Cut, 8"L',
#   4),
#  ('24 Capacity Maxi Data Binder Racks, Pearl', 4),
#  ('Berol Giant Pencil Sharpener', 4),
#  ('6185', 4),
#  ('CF 888', 4),
#  ('Model L Table or Wall-Mount Pencil Sharpener', 4),
#  ('Acco PRESSTEX® Data Binder with Storage Hooks, Dark Blue, 9 1/2" X 11"', 4),
#  ('Xerox 1995', 4),
#  ('GBC Linen Binding Covers', 4),
#  ('Canon S750 Color Inkjet Printer', 4),
#  ('Avery 514', 4),
#  ('300 Series Non-Flip', 4),
#  ('Eldon Spacemaker® Box, Quick-Snap Lid, Clear', 4),
#  ('Lexmark 4227 Plus Dot Matrix Printer', 4),
#  ('Tennsco Double-Tier Lockers', 4),
#  ("GBC Standard Plastic Binding Systems' Combs", 4),
#  ('Iceberg Mobile Mega Data/Printer Cart ®', 4),
#  ('Staples File Caddy', 4),
#  ('Grip Seal Envelopes', 4),
#  ('Soundgear Copyboard Conference Phone, Optional Battery', 4),
#  ('Avery Legal 4-Ring Binder', 4),
#  ('Carina Mini System Audio Rack, Model AR050B', 4),
#  ('DAX Value U-Channel Document Frames, Easel Back', 4),
#  ('Dixon Ticonderoga® Erasable Colored Pencil Set, 12-Color', 4),
#  ('Soundgear TeleForum DX Desktop Conference Phone', 4),
#  ('Lexmark Z55se Color Inkjet Printer', 4),
#  ('Howard Miller Distant Time Traveler Alarm Clock', 4),
#  ('Avery 492', 4),
#  ('Xerox 231', 4),
#  ('Seth Thomas 8 1/2" Cubicle Clock', 4),
#  ('Okidata ML591 Wide Format Dot Matrix Printer', 4),
#  ('MicroTAC 650', 4),
#  ('Southworth Structures Collection™', 4),
#  ('Sauder Camden County Collection Libraries, Planked Cherry Finish', 4),
#  ('Xerox 191', 4),
#  ('Global Enterprise™ Series Seating Low-Back Swivel/Tilt Chairs', 4),
#  ('Avery Non-Stick Binders', 4),
#  ('Microsoft Multimedia Keyboard', 4),
#  ('Acco Perma® 3000 Stacking Storage Drawers', 4),
#  ('Avery 478', 4),
#  ('SC7868i', 4),
#  ('Balt Split Level Computer Training Table', 4),
#  ('Round Specialty Laser Printer Labels', 4),
#  ('Accessory23', 4),
#  ('Canon MP25DIII Desktop Whisper-Quiet Printing Calculator', 4),
#  ('Staples Pushpins', 3),
#  ('Kensington 6 Outlet SmartSocket Surge Protector', 3),
#  ('Xerox 20', 3),
#  ('Global Airflow Leather Mesh Back Chair, Black', 3),
#  ('Acme® Office Executive Series Stainless Steel Trimmers', 3),
#  ('C-Line Cubicle Keepers Polyproplyene Holder w/Velcro® Back, 8-1/2x11, 25/Bx',
#   3),
#  ('Sanford Prismacolor® Professional Thick Lead Art Pencils, 36-Color Set', 3),
#  ('Tenex Personal Filing Tote With Secure Closure Lid, Black/Frost', 3),
#  ('Panasonic All Digital Answering System with Caller ID*, KX-TM150B', 3),
#  ('Xerox 1917', 3),
#  ('Global Leather Executive Chair', 3),
#  ('Xerox 1907', 3),
#  ('Newell 329', 3),
#  ('3.6 Cubic Foot Counter Height Office Refrigerator', 3),
#  ('Adams "While You Were Out" Message Pads', 3),
#  ('StarTAC ST7868', 3),
#  ('Newell 333', 3),
#  ('Atlantic Metals Mobile 2-Shelf Bookcases, Custom Colors', 3),
#  ('Accessory28', 3),
#  ('Xerox 204', 3),
#  ('Desktop 3-Pocket Hot File®', 3),
#  ('SimpliFile™ Personal File, Black Granite, 15w x 6-15/16d x 11-1/4h', 3),
#  ('Rubber Band Ball', 3),
#  ('Kensington 7 Outlet MasterPiece® HOMEOFFICE Power Control Center', 3),
#  ('GBC DocuBind TL200 Manual Binding Machine', 3),
#  ('Electrix Fluorescent Magnifier Lamps & Weighted Base', 3),
#  ('Accessory15', 3),
#  ('Sterilite Officeware Hinged File Box', 3),
#  ('Kensington 4 Outlet MasterPiece® Compact Power Control Center', 3),
#  ('Dana Swing-Arm Lamps', 3),
#  ('Wirebound Message Forms, Four 2 3/4 x 5 Forms per Page, Pink Paper', 3),
#  ('Avery 4027 File Folder Labels for Dot Matrix Printers, 5000 Labels per Box, White',
#   3),
#  ('Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book',
#   3),
#  ...]

# %%
# extract a set of frequently bought items 
# arbitrarily we will set a threshold of 10
frequentItemSets = set()
for productName, count in allBasketProductsCounter.most_common():
    if count > 10:
        frequentItemSets.add(productName)
frequentItemSets

# for the programmers: try changing this into a list comprehension
# Out:
# {'#10 White Business Envelopes,4 1/8 x 9 1/2',
#  '#10- 4 1/8" x 9 1/2" Recycled Envelopes',
#  '*Staples* Highlighting Markers',
#  '12 Colored Short Pencils',
#  '12-1/2 Diameter Round Wall Clock',
#  '1726 Digital Answering Machine',
#  '2160i',
#  '2180',
#  '3M Organizer Strips',
#  '80 Minute CD-R Spindle, 100/Pack - Staples',
#  '80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#  'Accessory21',
#  'Accessory34',
#  'Accessory35',
#  'Accessory36',
#  'Acco® Hot Clips™ Clips to Go',
#  'Acme® 8" Straight Scissors',
#  'Acme® Box Cutter Scissors',
#  'Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”',
#  'Advantus Push Pins, Aluminum Head',
#  'Aluminum Document Frame',
#  'Anderson Hickey Conga Table Tops & Accessories',
#  'Angle-D Binders with Locking Rings, Label Holders',
#  'Array® Memo Cubes',
#  'Array® Parchment Paper, Assorted Colors',
#  'Avery 474',
#  'Avery 479',
#  'Avery 481',
#  'Avery 487',
#  'Avery 491',
#  'Avery 493',
#  'Avery 494',
#  'Avery 498',
#  'Avery 501',
#  'Avery 506',
#  'Avery 508',
#  'Avery 51',
#  'Avery 510',
#  'Avery Flip-Chart Easel Binder, Black',
#  'Avery Hanging File Binders',
#  'Avery Poly Binder Pockets',
#  'Avery Printable Repositionable Plastic Tabs',
#  'Avery Self-Adhesive Photo Pockets for Polaroid Photos',
#  'Avery White Multi-Purpose Labels',
#  'Bagged Rubber Bands',
#  'Belkin 6 Outlet Metallic Surge Strip',
#  'Belkin ErgoBoard™ Keyboard',
#  'Bell Sonecor JB700 Caller ID',
#  'Bevis 36 x 72 Conference Tables',
#  'Bevis Round Conference Table Top & Single Column Base',
#  'Bevis Round Conference Table Top, X-Base',
#  'Binder Clips by OIC',
#  'Binder Posts',
#  'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"',
#  'Boston 16801 Nautilus™ Battery Pencil Sharpener',
#  'Boston 1730 StandUp Electric Pencil Sharpener',
#  'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#  'Bretford CR4500 Series Slim Rectangular Table',
#  'Bretford CR8500 Series Meeting Room Furniture',
#  'Bretford Rectangular Conference Table Tops',
#  'Bush Advantage Collection® Round Conference Table',
#  'Bush Mission Pointe Library',
#  'Bush Westfield Collection Bookcases, Fully Assembled',
#  'Canon MP41DH Printing Calculator',
#  'Canon P1-DHIII Palm Printing Calculator',
#  'Canon PC940 Copier',
#  'Cardinal Poly Pocket Divider Pockets for Ring Binders',
#  'Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl',
#  'Carina Double Wide Media Storage Towers in Natural & Black',
#  'Coloredge Poster Frame',
#  'Computer Printout Paper with Letter-Trim Perforations',
#  'DAX Solid Wood Frames',
#  'Dixon My First Ticonderoga Pencil, #2',
#  'Durable Pressboard Binders',
#  'EcoTones® Memo Sheets',
#  'Eldon Expressions Mahogany Wood Desk Collection',
#  'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry',
#  'Eldon Expressions™ Desk Accessory, Wood Pencil Holder, Oak',
#  'Eldon Simplefile® Box Office®',
#  'Eldon® Expressions™ Wood Desk Accessories, Oak',
#  'Eldon® Gobal File Keepers',
#  'Eldon® Wave Desk Accessories',
#  'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#  'Euro Pro Shark Stick Mini Vacuum',
#  'Executive Impressions 12" Wall Clock',
#  'Fellowes Basic 104-Key Keyboard, Platinum',
#  'Fellowes Super Stor/Drawer® Files',
#  'Fellowes Twister Kit, Gray/Clear, 3/pkg',
#  'Filing/Storage Totes and Swivel Casters',
#  'Fiskars® Softgrip Scissors',
#  'GBC Laser Imprintable Binding System Covers, Desert Sand',
#  'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"',
#  'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb',
#  'GBC Standard Plastic Binding Systems Combs',
#  'GBC Standard Therm-A-Bind Covers',
#  'Global Adaptabilities™ Conference Tables',
#  'Global High-Back Leather Tilter, Burgundy',
#  'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#  'Global Leather Task Chair, Black',
#  'Global Leather and Oak Executive Chair, Black',
#  'Global Stack Chair without Arms, Black',
#  'Holmes Odor Grabber',
#  'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter',
#  'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#  'Hon 4070 Series Pagoda™ Round Back Stacking Chairs',
#  'Hon 94000 Series Round Tables',
#  'Hon Comfortask® Task/Swivel Chairs',
#  'Hon iLevel™ Computer Training Table',
#  'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#  'Hoover Portapower™ Portable Vacuum',
#  'Ibico Covers for Plastic or Wire Binding Elements',
#  'Ibico Presentation Index for Binding Systems',
#  'Iceberg OfficeWorks 42" Round Tables',
#  'Imation Neon Mac Format Diskettes, 10/Pack',
#  'Imation Printable White 80 Minute CD-R Spindle, 50/Pack',
#  'KI Conference Tables',
#  'Kleencut® Forged Office Shears by Acme United Corporation',
#  'Large Capacity Hanging Post Binders',
#  'Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table',
#  "Lock-Up Easel 'Spel-Binder'",
#  'Logitech Access Keyboard',
#  'M3682',
#  'Master Giant Foot® Doorstop, Safety Yellow',
#  'Maxell Pro 80 Minute CD-R, 10/Pack',
#  'Mead 1st Gear 2" Zipper Binder, Asst. Colors',
#  'Memorex 4.7GB DVD+RW, 3/Pack',
#  'Memorex 4.7GB DVD-RAM, 3/Pack',
#  'Microsoft Internet Keyboard',
#  'Newell 309',
#  'Newell 310',
#  'Newell 312',
#  'Newell 323',
#  'Newell 336',
#  'Newell 337',
#  'Newell 340',
#  'Newell 342',
#  'Newell 343',
#  'Nu-Dell Executive Frame',
#  'Nu-Dell Leatherette Frames',
#  "O'Sullivan 3-Shelf Heavy-Duty Bookcases",
#  "O'Sullivan Elevations Bookcase, Cherry Finish",
#  'OIC Thumb-Tacks',
#  'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#  'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms',
#  'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms',
#  'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop',
#  'Panasonic KX-P1150 Dot Matrix Printer',
#  'Park Ridge™ Embossed Executive Business Envelopes',
#  'Peel & Seel® Recycled Catalog Envelopes, Brown',
#  'Portfile® Personal File Boxes',
#  'Prang Drawing Pencil Set',
#  'Recycled Eldon Regeneration Jumbo File',
#  'Rediform S.O.S. Phone Message Books',
#  'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#  'SANFORD Major Accent™ Highlighters',
#  'Sauder Forest Hills Library, Woodland Oak Finish',
#  'Self-Adhesive Address Labels for Typewriters by Universal',
#  'Serrated Blade or Curved Handle Hand Letter Openers',
#  'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate',
#  'Southworth 25% Cotton Premium Laser Paper and Envelopes',
#  'Space Solutions Commercial Steel Shelving',
#  'Staples 6 Outlet Surge',
#  'Staples Brown Kraft Recycled Clasp Envelopes',
#  'Staples Copy Paper (20Lb. and 84 Bright)',
#  'Staples Metal Binder Clips',
#  'Staples Plastic Wall Frames',
#  'Staples SlimLine Pencil Sharpener',
#  'Staples Standard Envelopes',
#  'Staples® General Use 3-Ring Binders',
#  'StarTAC 7760',
#  'Storex DuraTech Recycled Plastic Frosted Binders',
#  'T60',
#  'Talkabout T8367',
#  'Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"',
#  'Tenex Personal Project File with Scoop Front Design, Black',
#  'Tenex Personal Self-Stacking Standard File Box, Black/Gray',
#  'Tennsco Lockers, Gray',
#  'Timeport L7089',
#  'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge',
#  'US Robotics 56K V.92 External Faxmodem',
#  'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS',
#  'White GlueTop Scratch Pads',
#  'Wilson Jones 1" Hanging DublLock® Ring Binders',
#  'Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders',
#  'Wilson Jones DublLock® D-Ring Binders',
#  'Wilson Jones Hanging View Binder, White, 1"',
#  'Wilson Jones Impact Binders',
#  'Xerox 188',
#  'Xerox 1881',
#  'Xerox 1893',
#  'Xerox 1894',
#  'Xerox 1905',
#  'Xerox 1920',
#  'Xerox 1922',
#  'Xerox 1927',
#  'Xerox 1939',
#  'Xerox 1949',
#  'Xerox 1952',
#  'Xerox 197',
#  'Xerox 1983',
#  'Xerox 1993',
#  'Xerox 1997',
#  'Xerox 21',
#  'Xerox 210',
#  'Xerox 212',
#  'Xerox 213',
#  'Xerox 217',
#  'Xerox 227',
#  'Xerox 23'}

# %%
len(frequentItemSets), len(allBasketProductsCounter)
# Out:
# (209, 1255)

# %% [markdown]
# Here, see that only 200+ purchases are bought frequently. That limits us to any combinations of these 200 products
# across all weekly purchases. <br>
# In other words, out of 1200 products, only 200 have a slightly higher chance of appearing in the same basket<br>
# Let's continue on with the analysis to further illustrate this point

# %%
# iter through all basket sets with only the filtered items.

# %%
exampleWeeklyBasket = weeklySalesGroupProductSets.values[0]
exampleWeeklyBasket
# Out:
# {'Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#  'Eldon Shelf Savers™ Cubes and Bins',
#  'Electrix Halogen Magnifier Lamp',
#  'Storex Dura Pro™ Binders'}

# %%
# if we are interested in only the frequent items, we can filter the weekly basket to only those items
# we make use of the sets operation here
# set operations are & for intersect, | for union, - for difference, ^ for symmetric difference
exampleWeeklyBasket & frequentItemSets
# Out:
# set()

# %%
# show examples of the weekly basket items; only those with more than 1 item
for weeklyBasket in weeklySalesGroupProductSets.values:
    frequentItemsWeeklyBasket = weeklyBasket & frequentItemSets
    if frequentItemsWeeklyBasket and len(frequentItemsWeeklyBasket) >= 2:
        print(frequentItemsWeeklyBasket)
# Out:
# {'Avery White Multi-Purpose Labels', 'Avery 491'}
# {'White GlueTop Scratch Pads', 'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"'}
# {'Newell 312', 'Bretford CR8500 Series Meeting Room Furniture'}
# {'Imation Neon Mac Format Diskettes, 10/Pack', 'Newell 310'}
# {'Durable Pressboard Binders', 'Park Ridge™ Embossed Executive Business Envelopes'}
# {'Rediform S.O.S. Phone Message Books', 'GBC Standard Therm-A-Bind Covers'}
# {'Avery Poly Binder Pockets', 'Aluminum Document Frame'}
# {'Newell 312', 'Accessory35'}
# {'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac', 'Avery 510'}
# {'Global Adaptabilities™ Conference Tables', 'Accessory35'}
# {'1726 Digital Answering Machine', 'Avery Flip-Chart Easel Binder, Black'}
# {"O'Sullivan Elevations Bookcase, Cherry Finish", 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'}
# {'Master Giant Foot® Doorstop, Safety Yellow', 'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"'}
# {'*Staples* Highlighting Markers', 'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'}
# {'Xerox 212', 'Memorex 4.7GB DVD+RW, 3/Pack'}
# {'Xerox 1881', 'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black'}
# {'Computer Printout Paper with Letter-Trim Perforations', 'Carina Double Wide Media Storage Towers in Natural & Black'}
# {'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags', 'Eldon® Gobal File Keepers'}
# {'Bagged Rubber Bands', 'Carina Double Wide Media Storage Towers in Natural & Black'}
# {'Fellowes Super Stor/Drawer® Files', 'Angle-D Binders with Locking Rings, Label Holders'}
# {'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms', 'Bretford CR8500 Series Meeting Room Furniture'}
# {'Staples 6 Outlet Surge', 'Xerox 217'}
# {'Prang Drawing Pencil Set', 'Memorex 4.7GB DVD-RAM, 3/Pack'}
# {'Avery 508', 'Boston 16801 Nautilus™ Battery Pencil Sharpener'}
# {'Angle-D Binders with Locking Rings, Label Holders', 'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'}
# {'Array® Parchment Paper, Assorted Colors', 'OIC Thumb-Tacks'}
# {'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags', 'Master Giant Foot® Doorstop, Safety Yellow'}
# {'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables', 'Sauder Forest Hills Library, Woodland Oak Finish'}
# {'Space Solutions Commercial Steel Shelving', 'Xerox 23'}
# {'Cardinal Poly Pocket Divider Pockets for Ring Binders', 'Global High-Back Leather Tilter, Burgundy'}
# {'Large Capacity Hanging Post Binders', 'EcoTones® Memo Sheets'}
# {'Accessory34', 'Avery 508'}
# {'Avery Hanging File Binders', 'Acme® Box Cutter Scissors'}
# {'Memorex 4.7GB DVD-RAM, 3/Pack', 'Xerox 1949', 'Belkin 6 Outlet Metallic Surge Strip'}
# {'Staples 6 Outlet Surge', 'Angle-D Binders with Locking Rings, Label Holders'}
# {'Avery 493', '80 Minute CD-R Spindle, 100/Pack - Staples'}
# {'Prang Drawing Pencil Set', 'Staples Metal Binder Clips'}
# {'Xerox 188', 'US Robotics 56K V.92 External Faxmodem'}
# {'StarTAC 7760', 'Xerox 1939'}
# {'Avery 506', '1726 Digital Answering Machine'}
# {'80 Minute CD-R Spindle, 100/Pack - Staples', 'Executive Impressions 12" Wall Clock', 'Global Adaptabilities™ Conference Tables'}
# {'Xerox 1894', 'Xerox 210'}
# {'Staples® General Use 3-Ring Binders', 'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'}
# {'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'Binder Posts'}
# {'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black', 'Bevis Round Conference Table Top, X-Base'}
# {'Xerox 1881', 'Avery 510'}
# {'Avery Poly Binder Pockets', 'Bevis 36 x 72 Conference Tables'}
# {'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags', 'Eldon® Gobal File Keepers'}
# {'T60', 'Bush Mission Pointe Library', 'Staples 6 Outlet Surge'}
# {'Storex DuraTech Recycled Plastic Frosted Binders', 'Avery 481'}
# {'Hoover Portapower™ Portable Vacuum', 'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum'}
# {'Fiskars® Softgrip Scissors', 'Xerox 1939'}
# {'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black', 'Avery 491'}
# {'2180', 'Wilson Jones Impact Binders'}
# {'Newell 312', 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'}
# {'Filing/Storage Totes and Swivel Casters', 'Canon MP41DH Printing Calculator'}
# {'Imation Neon Mac Format Diskettes, 10/Pack', 'Xerox 227'}
# {'Computer Printout Paper with Letter-Trim Perforations', 'Wilson Jones Hanging View Binder, White, 1"'}
# {'Eldon Expressions Mahogany Wood Desk Collection', 'Staples Copy Paper (20Lb. and 84 Bright)'}
# {'Angle-D Binders with Locking Rings, Label Holders', 'DAX Solid Wood Frames'}
# {'Space Solutions Commercial Steel Shelving', 'Newell 340'}
# {'Hoover Portapower™ Portable Vacuum', 'Executive Impressions 12" Wall Clock'}
# {'Sauder Forest Hills Library, Woodland Oak Finish', 'Global High-Back Leather Tilter, Burgundy'}
# {'Accessory34', '*Staples* Highlighting Markers', 'Xerox 21'}
# {'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry', 'Staples Plastic Wall Frames', 'Belkin 6 Outlet Metallic Surge Strip'}
# {'Bagged Rubber Bands', 'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac'}
# {'Advantus Push Pins, Aluminum Head', 'Mead 1st Gear 2" Zipper Binder, Asst. Colors'}
# {'Euro Pro Shark Stick Mini Vacuum', 'M3682'}
# {'Computer Printout Paper with Letter-Trim Perforations', '#10- 4 1/8" x 9 1/2" Recycled Envelopes'}
# {'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables', 'Newell 323'}
# {'Accessory34', 'Avery 508'}
# {'Durable Pressboard Binders', 'Global Leather and Oak Executive Chair, Black'}
# {'Bretford CR4500 Series Slim Rectangular Table', 'Xerox 197'}
# {'Boston 1730 StandUp Electric Pencil Sharpener', 'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter'}
# {'Microsoft Internet Keyboard', 'Avery 508'}
# {'Avery 491', 'Global Stack Chair without Arms, Black'}
# {'Xerox 1922', 'Xerox 210'}
# {'Avery 506', 'Bretford CR8500 Series Meeting Room Furniture'}
# {'Staples Brown Kraft Recycled Clasp Envelopes', 'Array® Parchment Paper, Assorted Colors'}
# {'Xerox 188', 'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'}
# {'3M Organizer Strips', 'Newell 309'}
# {'Acme® 8" Straight Scissors', 'EcoTones® Memo Sheets'}
# {'Global Adaptabilities™ Conference Tables', 'Accessory35'}
# {'GBC Standard Plastic Binding Systems Combs', 'Staples 6 Outlet Surge', 'Angle-D Binders with Locking Rings, Label Holders'}
# {'Computer Printout Paper with Letter-Trim Perforations', 'Carina Double Wide Media Storage Towers in Natural & Black'}
# {'White GlueTop Scratch Pads', 'KI Conference Tables'}
# {'Xerox 1949', 'SANFORD Major Accent™ Highlighters'}
# {'Canon PC940 Copier', 'GBC Standard Plastic Binding Systems Combs'}
# {'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac', 'Avery 510'}
# {'Staples Standard Envelopes', 'Wilson Jones Hanging View Binder, White, 1"'}
# {'Newell 337', 'Hon 94000 Series Round Tables'}
# {'Sauder Forest Hills Library, Woodland Oak Finish', 'Avery 491'}
# {'Space Solutions Commercial Steel Shelving', 'Executive Impressions 12" Wall Clock'}
# {'Newell 323', 'SANFORD Major Accent™ Highlighters'}
# {'Imation Printable White 80 Minute CD-R Spindle, 50/Pack', 'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'}
# {'1726 Digital Answering Machine', 'Xerox 217'}
# {'Park Ridge™ Embossed Executive Business Envelopes', "O'Sullivan 3-Shelf Heavy-Duty Bookcases"}
# {'Acme® 8" Straight Scissors', 'Tenex Personal Project File with Scoop Front Design, Black'}
# {'Euro Pro Shark Stick Mini Vacuum', 'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'}
# {'Xerox 1894', 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'}
# {'Microsoft Internet Keyboard', 'Bretford CR4500 Series Slim Rectangular Table'}
# {'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags', 'Xerox 1939'}
# {'Xerox 23', 'Acme® Box Cutter Scissors'}
# {'Wilson Jones DublLock® D-Ring Binders', 'Eldon® Wave Desk Accessories'}
# {'Computer Printout Paper with Letter-Trim Perforations', 'Filing/Storage Totes and Swivel Casters', 'Canon MP41DH Printing Calculator'}
# {'T60', 'Bush Mission Pointe Library'}
# {'Newell 337', 'Hon 94000 Series Round Tables'}
# {'Imation Printable White 80 Minute CD-R Spindle, 50/Pack', 'Eldon® Wave Desk Accessories'}
# {'Bretford Rectangular Conference Table Tops', 'Tenex Personal Self-Stacking Standard File Box, Black/Gray'}
# {'Canon PC940 Copier', 'Boston 1730 StandUp Electric Pencil Sharpener'}
# {'GBC Standard Plastic Binding Systems Combs', 'Staples Plastic Wall Frames'}
# {'Staples Brown Kraft Recycled Clasp Envelopes', 'Belkin 6 Outlet Metallic Surge Strip'}
# {'Hon iLevel™ Computer Training Table', 'Xerox 1949'}
# {'Boston 1730 StandUp Electric Pencil Sharpener', 'Wilson Jones 1" Hanging DublLock® Ring Binders'}
# {'80 Minute CD-R Spindle, 100/Pack - Staples', 'Avery 479'}
# {'StarTAC 7760', 'Belkin ErgoBoard™ Keyboard'}
# {'Avery 508', 'Mead 1st Gear 2" Zipper Binder, Asst. Colors'}
# {'Memorex 4.7GB DVD+RW, 3/Pack', 'Belkin 6 Outlet Metallic Surge Strip'}
# {'Xerox 23', 'Acme® Box Cutter Scissors'}
# {'GBC Standard Plastic Binding Systems Combs', 'Avery 479', 'Staples Copy Paper (20Lb. and 84 Bright)'}
# {'GBC Standard Therm-A-Bind Covers', 'Fiskars® Softgrip Scissors'}
# {'Canon PC940 Copier', "O'Sullivan 3-Shelf Heavy-Duty Bookcases"}
# {'Hon 4070 Series Pagoda™ Round Back Stacking Chairs', 'Newell 337'}
# {'GBC Standard Plastic Binding Systems Combs', 'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac'}
# {'Iceberg OfficeWorks 42" Round Tables', 'Maxell Pro 80 Minute CD-R, 10/Pack'}
# {'Euro Pro Shark Stick Mini Vacuum', 'M3682'}
# {'Microsoft Internet Keyboard', 'Xerox 210'}
# {'Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"', 'Wilson Jones Hanging View Binder, White, 1"'}
# {'Xerox 1894', 'Kleencut® Forged Office Shears by Acme United Corporation'}
# {'Avery 493', 'Array® Parchment Paper, Assorted Colors'}
# {'Advantus Push Pins, Aluminum Head', 'Staples Plastic Wall Frames'}
# {'Cardinal Poly Pocket Divider Pockets for Ring Binders', 'Global High-Back Leather Tilter, Burgundy'}
# {'Rediform S.O.S. Phone Message Books', 'Avery 51'}
# {'Aluminum Document Frame', 'Ibico Presentation Index for Binding Systems'}
# {'Newell 312', 'GBC Laser Imprintable Binding System Covers, Desert Sand', 'Bretford CR8500 Series Meeting Room Furniture'}
# {'Ibico Presentation Index for Binding Systems', 'Avery 510'}
# {"O'Sullivan 3-Shelf Heavy-Duty Bookcases", 'Eldon Simplefile® Box Office®'}
# {'Canon PC940 Copier', 'Accessory21'}
# {'Avery 493', 'EcoTones® Memo Sheets'}
# {'Rediform S.O.S. Phone Message Books', 'GBC Standard Therm-A-Bind Covers'}
# {'Bush Advantage Collection® Round Conference Table', 'Accessory36'}
# {'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry', 'Staples Plastic Wall Frames'}
# {'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"', 'Fellowes Basic 104-Key Keyboard, Platinum'}
# {'Panasonic KX-P1150 Dot Matrix Printer', 'Belkin 6 Outlet Metallic Surge Strip'}
# {'Hoover Portapower™ Portable Vacuum', 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'}
# {'Newell 343', 'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'}
# {'Accessory21', 'Xerox 1922', 'Acme® Box Cutter Scissors'}
# {'Hon 94000 Series Round Tables', 'Logitech Access Keyboard'}
# {'Cardinal Poly Pocket Divider Pockets for Ring Binders', 'Aluminum Document Frame'}
# {'Staples Standard Envelopes', 'Bretford CR4500 Series Slim Rectangular Table'}
# {'Xerox 1922', 'Eldon Expressions™ Desk Accessory, Wood Pencil Holder, Oak'}
# {'Space Solutions Commercial Steel Shelving', 'Anderson Hickey Conga Table Tops & Accessories'}
# {'Timeport L7089', 'Canon P1-DHIII Palm Printing Calculator', 'Holmes Odor Grabber'}
# {'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'}
# {'Hoover Portapower™ Portable Vacuum', 'Avery 479'}
# {'2160i', 'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate'}
# {'Avery 506', 'Xerox 197'}
# {'Global Leather and Oak Executive Chair, Black', 'Newell 343'}
# {'Canon PC940 Copier', 'Global Stack Chair without Arms, Black'}
# {'Xerox 1983', 'Eldon Simplefile® Box Office®'}
# {'Binder Posts', 'Storex DuraTech Recycled Plastic Frosted Binders'}
# {'Prang Drawing Pencil Set', 'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry'}
# {'Avery 493', 'Fellowes Twister Kit, Gray/Clear, 3/pkg', 'Newell 309'}
# {'Timeport L7089', 'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'}
# {'Microsoft Internet Keyboard', 'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'}
# {'Southworth 25% Cotton Premium Laser Paper and Envelopes', 'SANFORD Major Accent™ Highlighters'}
# {'Bush Advantage Collection® Round Conference Table', 'Accessory36'}
# {'Avery Poly Binder Pockets', 'Acco® Hot Clips™ Clips to Go', 'Dixon My First Ticonderoga Pencil, #2'}
# {'Imation Neon Mac Format Diskettes, 10/Pack', '2180'}
# {'Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl', 'Accessory21', 'Belkin 6 Outlet Metallic Surge Strip'}
# {'Accessory21', 'Microsoft Internet Keyboard'}
# {'Avery 493', 'Hon 94000 Series Round Tables'}
# {'Avery 498', 'Xerox 210'}
# {'Recycled Eldon Regeneration Jumbo File', 'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'}
# {'Avery 506', 'Bush Westfield Collection Bookcases, Fully Assembled'}
# {'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'Bevis 36 x 72 Conference Tables'}
# {'Imation Printable White 80 Minute CD-R Spindle, 50/Pack', 'Eldon® Gobal File Keepers'}
# {'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'Xerox 1952'}
# {'Space Solutions Commercial Steel Shelving', 'Executive Impressions 12" Wall Clock'}
# {'Durable Pressboard Binders', 'Newell 310'}
# {'Newell 337', 'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'}
# {'12 Colored Short Pencils', 'Staples Plastic Wall Frames'}
# {'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs', 'Xerox 1922'}
# {"O'Sullivan Elevations Bookcase, Cherry Finish", 'Eldon® Gobal File Keepers'}
# {'Staples Standard Envelopes', '12-1/2 Diameter Round Wall Clock'}
# {'Eldon Expressions Mahogany Wood Desk Collection', 'Xerox 1893'}
# {'#10 White Business Envelopes,4 1/8 x 9 1/2', 'OIC Thumb-Tacks'}
# {'Staples Copy Paper (20Lb. and 84 Bright)', 'Accessory36'}
# {'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac', 'Peel & Seel® Recycled Catalog Envelopes, Brown'}
# {'Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs', 'Fiskars® Softgrip Scissors'}
# {'Tennsco Lockers, Gray', 'Canon MP41DH Printing Calculator'}
# {'Bush Westfield Collection Bookcases, Fully Assembled', 'Xerox 1952'}
# {'Array® Memo Cubes', 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'}
# {'Carina Double Wide Media Storage Towers in Natural & Black', "O'Sullivan 3-Shelf Heavy-Duty Bookcases"}
# {'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate', 'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'}
# {'Avery 493', 'EcoTones® Memo Sheets'}
# {'Imation Neon Mac Format Diskettes, 10/Pack', 'Newell 310'}
# {'Hon 4070 Series Pagoda™ Round Back Stacking Chairs', 'Newell 336'}
# {'Xerox 1920', 'Xerox 227'}
# {'Avery 487', 'Serrated Blade or Curved Handle Hand Letter Openers'}
# {'Xerox 1927', 'Dixon My First Ticonderoga Pencil, #2'}
# {'Avery 506', 'Peel & Seel® Recycled Catalog Envelopes, Brown'}
# {'Bush Westfield Collection Bookcases, Fully Assembled', 'Canon MP41DH Printing Calculator'}
# {'Tennsco Lockers, Gray', "O'Sullivan Elevations Bookcase, Cherry Finish"}
# {'Boston 1730 StandUp Electric Pencil Sharpener', 'Bretford CR4500 Series Slim Rectangular Table'}
# {'Hoover Portapower™ Portable Vacuum', 'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum'}
# {'Xerox 1905', 'Eldon® Wave Desk Accessories'}
# {'Boston 1730 StandUp Electric Pencil Sharpener', 'Staples® General Use 3-Ring Binders'}
# {'Binder Posts', 'Staples 6 Outlet Surge'}
# {'Hon iLevel™ Computer Training Table', 'Holmes Odor Grabber'}
# {'Global Leather Task Chair, Black', 'Serrated Blade or Curved Handle Hand Letter Openers'}
# {'Wilson Jones Hanging View Binder, White, 1"', 'Fellowes Basic 104-Key Keyboard, Platinum'}
# {'Park Ridge™ Embossed Executive Business Envelopes', 'Newell 310'}
# {'Canon PC940 Copier', 'Newell 312'}
# {'*Staples* Highlighting Markers', 'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'}
# {'Global Adaptabilities™ Conference Tables', 'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'}
# {'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black', 'Avery 491'}
# {'12-1/2 Diameter Round Wall Clock', 'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'}
# {'Xerox 212', 'Fiskars® Softgrip Scissors', 'Fellowes Basic 104-Key Keyboard, Platinum'}
# {'Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders', 'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'}
# {'Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"', 'Bell Sonecor JB700 Caller ID', 'KI Conference Tables'}
# {'Cardinal Poly Pocket Divider Pockets for Ring Binders', 'Accessory35'}
# {'Sauder Forest Hills Library, Woodland Oak Finish', 'Talkabout T8367'}
# {'Global Leather Task Chair, Black', 'Serrated Blade or Curved Handle Hand Letter Openers'}
# {'#10 White Business Envelopes,4 1/8 x 9 1/2', 'Newell 340'}
# {'Space Solutions Commercial Steel Shelving', 'Anderson Hickey Conga Table Tops & Accessories'}
# {'Panasonic KX-P1150 Dot Matrix Printer', 'Avery Poly Binder Pockets'}
# {'Southworth 25% Cotton Premium Laser Paper and Envelopes', 'Timeport L7089'}
# {'GBC Standard Therm-A-Bind Covers', 'Wilson Jones Hanging View Binder, White, 1"'}
# {'2160i', 'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum'}
# {'Canon MP41DH Printing Calculator', 'Newell 310'}
# {'Avery 498', '12-1/2 Diameter Round Wall Clock'}
# {'Bush Advantage Collection® Round Conference Table', 'Sauder Forest Hills Library, Woodland Oak Finish'}
# {'Hon 4070 Series Pagoda™ Round Back Stacking Chairs', 'Newell 336'}
# {'Portfile® Personal File Boxes', 'Xerox 210'}
# {'Belkin 6 Outlet Metallic Surge Strip', 'Xerox 21'}
# {'Avery Self-Adhesive Photo Pockets for Polaroid Photos', 'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'}
# {'Xerox 1881', 'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'}
# {'Xerox 1894', 'Xerox 210'}
# {'Staples® General Use 3-Ring Binders', 'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'}
# {'Avery Poly Binder Pockets', 'Bevis 36 x 72 Conference Tables'}
# {'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms', 'Bretford CR8500 Series Meeting Room Furniture'}

# %%
exampleFrequentItemsWeeklyBasket = {'80 Minute CD-R Spindle, 100/Pack - Staples', 'Executive Impressions 12" Wall Clock', 'Global Adaptabilities™ Conference Tables'}
exampleFrequentItemsWeeklyBasket
# Out:
# {'80 Minute CD-R Spindle, 100/Pack - Staples',
#  'Executive Impressions 12" Wall Clock',
#  'Global Adaptabilities™ Conference Tables'}

# %%
# we want to create all pairwise combinations if items in this example basket

# %%
pairCombinations = combinations(exampleFrequentItemsWeeklyBasket, 2)
list(pairCombinations)
# Out:
# [('Global Adaptabilities™ Conference Tables',
#   'Executive Impressions 12" Wall Clock'),
#  ('Global Adaptabilities™ Conference Tables',
#   '80 Minute CD-R Spindle, 100/Pack - Staples'),
#  ('Executive Impressions 12" Wall Clock',
#   '80 Minute CD-R Spindle, 100/Pack - Staples')]

# %%
# take note of all pairwise combinations and store them into a list called basketCombinations
basketCombinations = []
for weeklyBasket in weeklySalesGroupProductSets.values:
    frequentItemsWeeklyBasket = weeklyBasket & frequentItemSets
    if frequentItemsWeeklyBasket and len(frequentItemsWeeklyBasket) >= 2: 
        frequentItemsWeeklyBasketCombinations = combinations(frequentItemsWeeklyBasket, 2)
        for aCombination in frequentItemsWeeklyBasketCombinations:
            basketCombinations += [aCombination]

# %%
# we use the frequency counter on these combinations to see how often they appear
Counter(basketCombinations).most_common()
# Out:
# [(('Xerox 23',
#    'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection'),
#   2),
#  (('T60', 'Bush Mission Pointe Library'), 2),
#  (('Wirebound Message Books, 2 7/8" x 5", 3 Forms per Page',
#    'Tenex 46" x 60" Computer Anti-Static Chairmat, Rectangular Shaped'),
#   2),
#  (('Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#    'Recycled Premium Regency Composition Covers'),
#   2),
#  (('Document Clip Frames', 'Newell 337'), 2),
#  (('Computer Printout Paper with Letter-Trim Perforations',
#    'Carina Double Wide Media Storage Towers in Natural & Black'),
#   2),
#  (('Avery Hi-Liter Pen Style Six-Color Fluorescent Set', 'Avery 501'), 2),
#  (('Newell 337', 'Hon 94000 Series Round Tables'), 2),
#  (('Hoover Portapower™ Portable Vacuum',
#    'Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum'),
#   2),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'Holmes Replacement Filter for HEPA Air Cleaner, Medium Room'),
#   2),
#  (('Xerox 1894', 'Xerox 210'), 2),
#  (('Master Giant Foot® Doorstop, Safety Yellow',
#    'Cardinal Holdit Business Card Pockets'),
#   2),
#  (('Hon 4070 Series Pagoda™ Round Back Stacking Chairs',
#    'Quartet Alpha® White Chalk, 12/Pack'),
#   2),
#  (('Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#    'Eldon® Gobal File Keepers'),
#   2),
#  (('Stockwell Push Pins', 'Cardinal Holdit Business Card Pockets'), 2),
#  (('Xerox 1936', 'Xerox 214'), 2),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'Document Clip Frames'),
#   2),
#  (('Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags',
#    'DAX Copper Panel Document Frame, 5 x 7 Size'),
#   2),
#  (('Avery Poly Binder Pockets', 'Bevis 36 x 72 Conference Tables'), 2),
#  (('Wirebound Message Books, 2 7/8" x 5", 3 Forms per Page',
#    "O'Sullivan 2-Shelf Heavy-Duty Bookcases"),
#   2),
#  (('Hon 4070 Series Pagoda™ Round Back Stacking Chairs', 'Newell 336'), 2),
#  (('Xerox 1930', 'Tennsco Lockers, Gray'), 2),
#  (('GBC Wire Binding Strips', 'Talkabout T8367'), 2),
#  (('Memorex 4.7GB DVD-RAM, 3/Pack',
#    'Imation 3.5" Unformatted DS/HD Diskettes, 10/Box'),
#   2),
#  (('BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#    'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection'),
#   2),
#  (('Premium Transparent Presentation Covers by GBC',
#    'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages'),
#   2),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'Multimedia Mailers'),
#   2),
#  (('Staples® General Use 3-Ring Binders',
#    'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'),
#   2),
#  (('Avery 493', 'EcoTones® Memo Sheets'), 2),
#  (('U.S. Robotics 56K Internet Call Modem', 'Novimex Fabric Task Chair'), 2),
#  (('Imation 3.5 IBM Formatted Diskettes, 10/Box',
#    'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'),
#   2),
#  (('Fellowes Personal Hanging Folder Files, Navy', 'StarTAC 7760'), 2),
#  (('Novimex Fabric Task Chair', 'Avery Flip-Chart Easel Binder, Black'), 2),
#  (("O'Sullivan 2-Shelf Heavy-Duty Bookcases",
#    'Tenex 46" x 60" Computer Anti-Static Chairmat, Rectangular Shaped'),
#   2),
#  (('Accessory8', 'Boston 1730 StandUp Electric Pencil Sharpener'), 2),
#  (('Filing/Storage Totes and Swivel Casters',
#    'Canon MP41DH Printing Calculator'),
#   2),
#  (('Portfile® Personal File Boxes', 'Xerox 1923'), 2),
#  (('Belkin 8 Outlet Surge Protector', 'Avery 481'), 2),
#  (('Eldon Executive Woodline II Cherry Finish Desk Accessories',
#    'Staples Brown Kraft Recycled Clasp Envelopes'),
#   2),
#  (('Global Leather Task Chair, Black',
#    'Serrated Blade or Curved Handle Hand Letter Openers'),
#   2),
#  (('Wirebound Voice Message Log Book',
#    'Hon 4070 Series Pagoda™ Round Back Stacking Chairs'),
#   2),
#  (('Hon Non-Folding Utility Tables', 'Staples SlimLine Pencil Sharpener'), 2),
#  (('Micro Innovations Micro 3000 Keyboard, Black', 'Staples 6 Outlet Surge'),
#   2),
#  (('Space Solutions Commercial Steel Shelving',
#    'Anderson Hickey Conga Table Tops & Accessories'),
#   2),
#  (('Euro Pro Shark Stick Mini Vacuum', 'StarTAC 6500'), 2),
#  (('Rediform S.O.S. Phone Message Books', 'GBC Standard Therm-A-Bind Covers'),
#   2),
#  (('Xerox 1996', 'Boston KS Multi-Size Manual Pencil Sharpener'), 2),
#  (('Eldon Pizzaz™ Desk Accessories', 'Bevis 36 x 72 Conference Tables'), 2),
#  (('Hon Non-Folding Utility Tables',
#    'Ames Color-File® Green Diamond Border X-ray Mailers'),
#   2),
#  (('Tenex Personal Self-Stacking Standard File Box, Black/Gray', 'CF 688'), 2),
#  (('Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#    'Avery 510'),
#   2),
#  (('Xerox 216', 'Avery 487'), 2),
#  (('Avery Flip-Chart Easel Binder, Black', 'Newell 335'), 2),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'Global High-Back Leather Tilter, Burgundy'),
#   2),
#  (('Xerox 1932', '4009® Highlighters by Sanford'), 2),
#  (('Avery Poly Binder Pockets', 'Eldon Pizzaz™ Desk Accessories'), 2),
#  (('G.E. Halogen Desk Lamp Bulbs', 'Avery Flip-Chart Easel Binder, Black'), 2),
#  (('Staples Brown Kraft Recycled Clasp Envelopes',
#    'IBM Active Response Keyboard, Black'),
#   2),
#  (('Avery 506', 'Smead Adjustable Mobile File Trolley with Lockable Top'), 2),
#  (('Novimex Fabric Task Chair', 'Newell 335'), 2),
#  (('M3682', 'StarTAC 6500'), 2),
#  (('M70', 'Newell 342'), 2),
#  (('Xerox 23', 'Acme® Box Cutter Scissors'), 2),
#  (('Hewlett-Packard 2600DN Business Color Inkjet Printer', 'Accessory27'), 2),
#  (('Bevis Rectangular Conference Tables',
#    'Howard Miller 12-3/4 Diameter Accuwave DS ™ Wall Clock'),
#   2),
#  (('Newell 315', 'Avery 494'), 2),
#  (('Imation Neon Mac Format Diskettes, 10/Pack', 'Newell 310'), 2),
#  (('Xerox 1928', '6190'), 2),
#  (('Accessory34', 'Avery 508'), 2),
#  (('Xerox 1977', 'Avery 487'), 2),
#  (('Avery Hi-Liter Pen Style Six-Color Fluorescent Set', '5170'), 2),
#  (('Tuff Stuff™ Recycled Round Ring Binders', 'Xerox 1994'), 2),
#  (('Xerox 1881', 'Belkin 105-Key Black Keyboard'), 2),
#  (('Boston KS Multi-Size Manual Pencil Sharpener',
#    'Bush Advantage Collection® Round Conference Table'),
#   2),
#  (('Canon PC1080F Personal Copier', 'Xerox 1927'), 2),
#  (('Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer',
#    'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)'),
#   2),
#  (('Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#    'Avery 491'),
#   2),
#  (('Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer',
#    'Xerox 214'),
#   2),
#  (('*Staples* vLetter Openers, 2/Pack',
#    'Filing/Storage Totes and Swivel Casters'),
#   2),
#  (('Hoover Portapower™ Portable Vacuum',
#    'Global Leather & Oak Executive Chair, Burgundy'),
#   2),
#  (('Self-Adhesive Address Labels for Typewriters by Universal', 'Accessory37'),
#   2),
#  (('Holmes Replacement Filter for HEPA Air Cleaner, Medium Room',
#    'GE 4 Foot Flourescent Tube, 40 Watt'),
#   2),
#  (('Xerox 1989', 'TOPS Money Receipt Book, Consecutively Numbered in Red,'),
#   2),
#  (('Super Decoflex Portable Personal File',
#    'Eldon® 300 Class™ Desk Accessories, Black'),
#   2),
#  (('Assorted Color Push Pins',
#    'Letter/Legal File Tote with Clear Snap-On Lid, Black Granite'),
#   2),
#  (('Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry',
#    'Staples Plastic Wall Frames'),
#   2),
#  (('Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms',
#    'Bretford CR8500 Series Meeting Room Furniture'),
#   2),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'GE 4 Foot Flourescent Tube, 40 Watt'),
#   2),
#  (('GE 48" Fluorescent Tube, Cool White Energy Saver, 34 Watts, 30/Box',
#    'SANFORD Major Accent™ Highlighters'),
#   2),
#  (('Xerox 190', 'Newell 342'), 2),
#  (('Okidata ML184 Turbo Dot Matrix Printers', 'Nu-Dell Executive Frame'), 2),
#  (('Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black',
#    '8860'),
#   2),
#  (('Xerox 1922', 'Tyvek ® Top-Opening Peel & Seel ® Envelopes, Gray'), 2),
#  (('Global High-Back Leather Tilter, Burgundy',
#    'GE 4 Foot Flourescent Tube, 40 Watt'),
#   2),
#  (('Belkin 8 Outlet Surge Protector',
#    'Tensor "Hersey Kiss" Styled Floor Lamp'),
#   2),
#  (('Euro Pro Shark Stick Mini Vacuum', 'M3682'), 2),
#  (('Belkin F9M820V08 8 Outlet Surge', 'Belkin 6 Outlet Metallic Surge Strip'),
#   2),
#  (('Hon 4070 Series Pagoda™ Armless Upholstered Stacking Chairs',
#    'Hon Valutask™ Swivel Chairs'),
#   2),
#  (('Global Adaptabilities™ Conference Tables', 'Accessory35'), 2),
#  (('SAFCO Mobile Desk Side File, Wire Frame',
#    'Angle-D Binders with Locking Rings, Label Holders'),
#   2),
#  (('Bush Advantage Collection® Round Conference Table', 'Accessory36'), 2),
#  (('Lexmark Z54se Color Inkjet Printer',
#    'Bevis Round Conference Table Top, X-Base'),
#   2),
#  (('Xerox 1899', 'Hon 94000 Series Round Tables'), 2),
#  (('Canon P1-DHIII Palm Printing Calculator', 'Xerox 1896'), 2),
#  (('Avery 48', 'Avery 501'), 2),
#  (('Staples 6 Outlet Surge',
#    'Angle-D Binders with Locking Rings, Label Holders'),
#   2),
#  (('*Staples* Highlighting Markers',
#    'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'),
#   2),
#  (('Document Clip Frames', 'LX 677'), 2),
#  (('US Robotics 56K V.92 Internal PCI Faxmodem',
#    'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'),
#   2),
#  (('Boston 16765 Mini Stand Up Battery Pencil Sharpener',
#    'Acco® Hot Clips™ Clips to Go'),
#   2),
#  (('Telescoping Adjustable Floor Lamp',
#    'Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms'),
#   2),
#  (('Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black',
#    'Deflect-o DuraMat Antistatic Studded Beveled Mat for Medium Pile Carpeting'),
#   2),
#  (('Acco Perma® 2700 Stacking Storage Drawers', 'Staples 6 Outlet Surge'), 2),
#  (('Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad',
#    'Wilson Jones 1" Hanging DublLock® Ring Binders'),
#   2),
#  (('Gyration Ultra Professional Cordless Optical Suite',
#    'Eldon® 300 Class™ Desk Accessories, Black'),
#   2),
#  (('US Robotics 56K V.92 Internal PCI Faxmodem',
#    'Imation 3.5 IBM Formatted Diskettes, 10/Box'),
#   2),
#  (('Space Solutions Commercial Steel Shelving',
#    'Executive Impressions 12" Wall Clock'),
#   2),
#  (('Carina Double Wide Media Storage Towers in Natural & Black',
#    'Tennsco Snap-Together Open Shelving Units, Starter Sets and Add-On Units'),
#   2),
#  (('Master Giant Foot® Doorstop, Safety Yellow', 'Stockwell Push Pins'), 2),
#  (('Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers',
#    'Xerox 1893'),
#   2),
#  (('80 Minute CD-R Spindle, 100/Pack - Staples',
#    "O'Sullivan 2-Shelf Heavy-Duty Bookcases"),
#   2),
#  (('Barrel Sharpener', 'Newell 342'), 2),
#  (('Document Clip Frames', 'Multimedia Mailers'), 2),
#  (('Avery 493', 'Boston Model 1800 Electric Pencil Sharpener, Gray'), 2),
#  (('Fellowes Internet Keyboard, Platinum',
#    'Blue String-Tie & Button Interoffice Envelopes, 10 x 13'),
#   2),
#  (('Newell 312', 'Bretford CR8500 Series Meeting Room Furniture'), 2),
#  (('Hon Valutask™ Swivel Chairs', 'Avery 510'), 2),
#  (('Global Commerce™ Series High-Back Swivel/Tilt Chairs',
#    'Wilson Jones Hanging View Binder, White, 1"'),
#   2),
#  (('Xerox 1899', 'Newell 337'), 2),
#  (('Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#    'Eureka Recycled Copy Paper 8 1/2" x 11", Ream'),
#   2),
#  (('Avery 474',
#    'Hewlett-Packard Business Color Inkjet 3000 [N, DTN] Series Printers'),
#   2),
#  (('Global High-Back Leather Tilter, Burgundy',
#    'Holmes Replacement Filter for HEPA Air Cleaner, Medium Room'),
#   2),
#  (('Wirebound Voice Message Log Book', 'Newell 336'), 2),
#  (('Peel & Seel® Recycled Catalog Envelopes, Brown',
#    'Eldon Jumbo ProFile™ Portable File Boxes Graphite/Black'),
#   2),
#  (('Xerox 190', 'Barrel Sharpener'), 2),
#  (('Office Star Flex Back Scooter Chair with White Frame', 'Avery 485'), 2),
#  (('Sharp AL-1530CS Digital Copier',
#    'Panasonic KP-310 Heavy-Duty Electric Pencil Sharpener'),
#   2),
#  (('Ibico Covers for Plastic or Wire Binding Elements',
#    'Premium Writing Pencils, Soft, #2 by Central Association for the Blind'),
#   2),
#  (('Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut',
#    'Timeport L7089'),
#   1),
#  (('Avery 508', 'Mead 1st Gear 2" Zipper Binder, Asst. Colors'), 1),
#  (('Xerox 1983', 'Eldon Simplefile® Box Office®'), 1),
#  (("O'Sullivan Elevations Bookcase, Cherry Finish",
#    'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'),
#   1),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    '"While you Were Out" Message Book, One Form per Page'),
#   1),
#  (('Tenex Personal Project File with Scoop Front Design, Black', '8890'), 1),
#  (('GBC Poly Designer Binding Covers',
#    'GBC Recycled Regency Composition Covers'),
#   1),
#  (('Accessory8', 'Bell Sonecor JB700 Caller ID'), 1),
#  (('It\'s Hot Message Books with Stickers, 2 3/4" x 5"',
#    'Dixon Prang® Watercolor Pencils, 10-Color Set with Brush'),
#   1),
#  (('Hon Olson Stacker Stools', 'Accessory2'), 1),
#  (('Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags',
#    'Xerox 1939'),
#   1),
#  (('Prismacolor Color Pencil Set', 'Xerox 21'), 1),
#  (('Dixon Ticonderoga Core-Lock Colored Pencils, 48-Color Set',
#    'Avery White Multi-Purpose Labels'),
#   1),
#  (('Xerox 1937', 'Bretford CR8500 Series Meeting Room Furniture'), 1),
#  (('Carina Double Wide Media Storage Towers in Natural & Black',
#    "O'Sullivan 3-Shelf Heavy-Duty Bookcases"),
#   1),
#  (('Acme® 8" Straight Scissors', 'Tensor "Hersey Kiss" Styled Floor Lamp'), 1),
#  (('Avery 49', 'Staples 4 Outlet Surge Protector'), 1),
#  (('Accessory41', 'GBC DocuBind 200 Manual Binding Machine'), 1),
#  (('Imation Printable White 80 Minute CD-R Spindle, 50/Pack',
#    'Eldon® Wave Desk Accessories'),
#   1),
#  (('"While you Were Out" Message Book, One Form per Page',
#    'Eureka Recycled Copy Paper 8 1/2" x 11", Ream'),
#   1),
#  (('Blue String-Tie & Button Interoffice Envelopes, 10 x 13', 'i2000'), 1),
#  (('Career Cubicle Clock, 8 1/4", Black', 'i1000'), 1),
#  (('DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#    'Logitech Access Keyboard'),
#   1),
#  (('Electrix Halogen Magnifier Lamp',
#    'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base'),
#   1),
#  (('Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#    'Fiskars® Softgrip Scissors'),
#   1),
#  (('Gyration Ultra Professional Cordless Optical Suite',
#    'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'),
#   1),
#  (('Tennsco Commercial Shelving', 'Logitech Internet Navigator Keyboard'), 1),
#  (('Accessory21', 'Acme® Box Cutter Scissors'), 1),
#  (('AT&T 2230 Dual Handset Phone With Caller ID/Call Waiting',
#    'Peel & Seel® Recycled Catalog Envelopes, Brown'),
#   1),
#  (('Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'Xerox 1952'),
#   1),
#  (('Bionaire Personal Warm Mist Humidifier/Vaporizer',
#    'Bush Advantage Collection® Round Conference Table'),
#   1),
#  (('80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#    'Sharp AL-1530CS Digital Copier'),
#   1),
#  (('Xerox 1905', 'Eldon® Wave Desk Accessories'), 1),
#  (('Economy Binders', 'Nu-Form 106-Key Ergonomic Keyboard w/ Touchpad'), 1),
#  (('Computer Printout Paper with Letter-Trim Perforations',
#    'Wilson Jones Hanging View Binder, White, 1"'),
#   1),
#  (('Hoover Portapower™ Portable Vacuum',
#    'Executive Impressions 12" Wall Clock'),
#   1),
#  (('Hon Every-Day® Chair Series Swivel Task Chairs', 'Artistic Insta-Plaque'),
#   1),
#  (('Fellowes Binding Cases', 'Eldon Shelf Savers™ Cubes and Bins'), 1),
#  (('3285', 'Acme® Preferred Stainless Steel Scissors'), 1),
#  (('Large Capacity Hanging Post Binders',
#    'GE 4 Foot Flourescent Tube, 40 Watt'),
#   1),
#  (('Martin-Yale Premier Letter Opener', 'Xerox 1896'), 1),
#  (('Avery 506', 'IBM 80 Minute CD-R Spindle, 50/Pack'), 1),
#  (('Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#    'Bevis Round Conference Table Top, X-Base'),
#   1),
#  (('3M Organizer Strips', 'Newell 309'), 1),
#  (('Xerox 1881', 'Avery 510'), 1),
#  (('Binder Clips by OIC',
#    '3M Polarizing Task Lamp with Clamp Arm, Light Gray'),
#   1),
#  (('Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate',
#    'Micro Innovations Micro Digital Wireless Keyboard and Mouse, Gray'),
#   1),
#  (('Xerox Blank Computer Paper',
#    'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'),
#   1),
#  (('Canon P1-DHIII Palm Printing Calculator', 'Holmes Odor Grabber'), 1),
#  (('Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#    'Xerox 1932'),
#   1),
#  (('Accessory34', 'Xerox 21'), 1),
#  (('Hon 4070 Series Pagoda™ Armless Upholstered Stacking Chairs',
#    'Fellowes Internet Keyboard, Platinum'),
#   1),
#  (('Binder Posts', 'Storex DuraTech Recycled Plastic Frosted Binders'), 1),
#  (('GBC Standard Plastic Binding Systems Combs', 'Staples 6 Outlet Surge'), 1),
#  (('GBC VeloBinder Strips', 'Staples Plastic Wall Frames'), 1),
#  (('Avery 506', 'Peel & Seel® Recycled Catalog Envelopes, Brown'), 1),
#  (('Fellowes 17-key keypad for PS/2 interface', 'StarTAC ST7762'), 1),
#  (('Deflect-o DuraMat Antistatic Studded Beveled Mat for Medium Pile Carpeting',
#    'XtraLife® ClearVue™ Slant-D® Ring Binders by Cardinal'),
#   1),
#  (('Xerox 1971', '5165'), 1),
#  (('Master Caster Door Stop, Gray', 'Xerox 1927'), 1),
#  (('Belkin F9M820V08 8 Outlet Surge',
#    'Fellowes Twister Kit, Gray/Clear, 3/pkg'),
#   1),
#  (('Imation Printable White 80 Minute CD-R Spindle, 50/Pack',
#    'Dana Halogen Swing-Arm Architect Lamp'),
#   1),
#  (('Bell Sonecor JB700 Caller ID', 'KI Conference Tables'), 1),
#  (('80 Minute CD-R Spindle, 100/Pack - Staples',
#    'GBC DocuBind P100 Manual Binding Machine'),
#   1),
#  (('Xerox 1922', 'Xerox 1984'), 1),
#  (('Xerox 1996', 'Westinghouse Clip-On Gooseneck Lamps'), 1),
#  (('Belkin Premiere Surge Master II 8-outlet surge protector',
#    'Fellowes Basic 104-Key Keyboard, Platinum'),
#   1),
#  (('Iceberg OfficeWorks 42" Round Tables',
#    'Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack'),
#   1),
#  (('Southworth 25% Cotton Premium Laser Paper and Envelopes',
#    'Timeport L7089'),
#   1),
#  (('Xerox 1905', 'Decoflex Hanging Personal Folder File, Blue'), 1),
#  (('Eldon Expressions Mahogany Wood Desk Collection', 'Xerox 1893'), 1),
#  (('Newell 337', 'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'), 1),
#  (('Bevis Rectangular Conference Tables',
#    'Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box'),
#   1),
#  (('Computer Printout Paper with Letter-Trim Perforations',
#    'DAX Contemporary Wood Frame with Silver Metal Mat, Desktop, 11 x 14 Size'),
#   1),
#  (('Belkin F9M820V08 8 Outlet Surge', 'Staples SlimLine Pencil Sharpener'), 1),
#  (('Panasonic KX-P1150 Dot Matrix Printer', 'Avery Poly Binder Pockets'), 1),
#  (('Xerox Blank Computer Paper', 'Fellowes 17-key keypad for PS/2 interface'),
#   1),
#  (('Portfile® Personal File Boxes', 'Xerox 1996'), 1),
#  (('Memorex 4.7GB DVD-RAM, 3/Pack',
#    'Hon 2111 Invitation™ Series Corner Table'),
#   1),
#  (('Portfile® Personal File Boxes', 'Xerox 210'), 1),
#  (('Accessory41', 'Sauder Forest Hills Library, Woodland Oak Finish'), 1),
#  (('Hewlett Packard LaserJet 3310 Copier',
#    'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish'),
#   1),
#  (('Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"',
#    'Wilson Jones Hanging View Binder, White, 1"'),
#   1),
#  (('Talkabout T8367',
#    'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"'),
#   1),
#  (('Global Deluxe High-Back Office Chair in Storm',
#    'Canon MP41DH Printing Calculator'),
#   1),
#  (('Executive Impressions 14" Contract Wall Clock',
#    'Memorex 4.7GB DVD+RW, 3/Pack'),
#   1),
#  (('Bell Sonecor JB700 Caller ID',
#    'Eldon Jumbo ProFile™ Portable File Boxes Graphite/Black'),
#   1),
#  (('Eldon Econocleat® Chair Mats for Low Pile Carpets', 'T39m'), 1),
#  (('Accessory4', 'Canon MP41DH Printing Calculator'), 1),
#  (('8260', 'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins'),
#   1),
#  (('Avery 506',
#    'Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables'),
#   1),
#  (('Catalog Binders with Expanding Posts',
#    "O'Sullivan Elevations Bookcase, Cherry Finish"),
#   1),
#  (('BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#    'Sauder Forest Hills Library, Woodland Oak Finish'),
#   1),
#  (('Bush Westfield Collection Bookcases, Fully Assembled', 'Xerox 196'), 1),
#  (('Okidata ML320 Series Turbo Dot Matrix Printers', 'Xerox 1952'), 1),
#  (('Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers',
#    'Fiskars® Softgrip Scissors'),
#   1),
#  (('Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter',
#    'Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad'),
#   1),
#  (('Space Solutions Commercial Steel Shelving',
#    'Acme® Elite Stainless Steel Scissors'),
#   1),
#  (('Staples Copy Paper (20Lb. and 84 Bright)', 'Accessory36'), 1),
#  (('Fellowes Binding Cases', 'Xerox 1922'), 1),
#  (('Durable Pressboard Binders',
#    'Park Ridge™ Embossed Executive Business Envelopes'),
#   1),
#  (('Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate',
#    'GBC Wire Binding Strips'),
#   1),
#  (('Xerox 1949', 'Belkin 6 Outlet Metallic Surge Strip'), 1),
#  (('Staples Bulldog Clip',
#    'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins'),
#   1),
#  (('Xerox 1929', 'Logitech Access Keyboard'), 1),
#  (('Bush Westfield Collection Bookcases, Dark Cherry Finish, Fully Assembled',
#    '12-1/2 Diameter Round Wall Clock'),
#   1),
#  (('Computer Printout Paper with Letter-Trim Perforations', 'Xerox 1933'), 1),
#  (('Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'KF 788'), 1),
#  (('Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”',
#    'Binney & Smith inkTank™ Erasable Desk Highlighter, Chisel Tip, Yellow, 12/Box'),
#   1),
#  (('Fellowes Staxonsteel® Drawer Files', 'Newell 310'), 1),
#  (('#10- 4 1/8" x 9 1/2" Security-Tint Envelopes',
#    'Hewlett-Packard Deskjet 1220Cse Color Inkjet Printer'),
#   1),
#  (('Avery Poly Binder Pockets', 'Dixon My First Ticonderoga Pencil, #2'), 1),
#  (('Imation 3.5", RTS 247544 3M 3.5 DSDD, 10/Pack',
#    'Logitech Internet Navigator Keyboard'),
#   1),
#  (('Eldon Cleatmat® Chair Mats for Medium Pile Carpets',
#    'Okidata ML390 Turbo Dot Matrix Printers'),
#   1),
#  (('Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack',
#    'Riverleaf Stik-Withit® Designer Note Cubes®'),
#   1),
#  (('BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#    'Hon 2111 Invitation™ Series Corner Table'),
#   1),
#  (('GBC Laser Imprintable Binding System Covers, Desert Sand',
#    'Bretford CR8500 Series Meeting Room Furniture'),
#   1),
#  (('Belkin 105-Key Black Keyboard', 'Xerox 196'), 1),
#  (('Accessory36',
#    'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins'),
#   1),
#  (('Computer Printout Paper with Letter-Trim Perforations',
#    'Quartet Omega® Colored Chalk, 12/Pack'),
#   1),
#  (('Memorex Slim 80 Minute CD-R, 10/Pack', 'Xerox 1880'), 1),
#  (('Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue',
#    'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'),
#   1),
#  (('Angle-D Binders with Locking Rings, Label Holders',
#    'DAX Solid Wood Frames'),
#   1),
#  (('Fiskars® Softgrip Scissors', 'Xerox 1939'), 1),
#  (('StarTAC 7760', 'Avery Durable Binders'), 1),
#  (('Imation Neon Mac Format Diskettes, 10/Pack',
#    'TI 36X Solar Scientific Calculator'),
#   1),
#  (('GBC VeloBinder Electric Binding Machine',
#    'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'),
#   1),
#  (('Xerox 1927', 'Dixon My First Ticonderoga Pencil, #2'), 1),
#  (('Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad', 'Avery 520'), 1),
#  (('Acco Perma® 2700 Stacking Storage Drawers', 'Portable Personal File Box'),
#   1),
#  (('Avery Poly Binder Pockets', 'Hon Multipurpose Stacking Arm Chairs'), 1),
#  (('Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#    'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'),
#   1),
#  (('GE 48" Fluorescent Tube, Cool White Energy Saver, 34 Watts, 30/Box',
#    'Binder Posts'),
#   1),
#  (('Hewlett Packard LaserJet 3310 Copier',
#    'Ibico Covers for Plastic or Wire Binding Elements'),
#   1),
#  (('Security-Tint Envelopes', 'Newell 309'), 1),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'Canon PC1060 Personal Laser Copier'),
#   1),
#  (('Eldon® Expressions™ Wood Desk Accessories, Oak', 'Xerox 193'), 1),
#  (('Portfile® Personal File Boxes', 'Memorex Slim 80 Minute CD-R, 10/Pack'),
#   1),
#  (('Imation 3.5", DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack',
#    'Wilson Jones Hanging View Binder, White, 1"'),
#   1),
#  (('Xerox 1947',
#    'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection'),
#   1),
#  (('Xerox 199', 'StarTAC 6500'), 1),
#  (('Hon iLevel™ Computer Training Table', 'Holmes Odor Grabber'), 1),
#  (('Imation 3.5", DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack',
#    'PC Concepts 116 Key Quantum 3000 Keyboard'),
#   1),
#  (('Hewlett-Packard 4.7GB DVD+R Discs',
#    'Recycled Eldon Regeneration Jumbo File'),
#   1),
#  (('Acco® Hot Clips™ Clips to Go',
#    'Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables'),
#   1),
#  (('Barrel Sharpener', 'Bevis 36 x 72 Conference Tables'), 1),
#  (('Avery 493', 'Hon 94000 Series Round Tables'), 1),
#  (('Hoover Portapower™ Portable Vacuum', 'Accessory2'), 1),
#  (('Computer Printout Paper with Letter-Trim Perforations', 'Newell 335'), 1),
#  (('Acco® Hot Clips™ Clips to Go', 'Dixon My First Ticonderoga Pencil, #2'),
#   1),
#  (('GBC DocuBind 200 Manual Binding Machine',
#    'Staples SlimLine Pencil Sharpener'),
#   1),
#  (('Accessory35', 'Wausau Papers Astrobrights® Colored Envelopes'), 1),
#  (('Xerox 188', 'Xerox 1932'), 1),
#  (('Tenex Personal Project File with Scoop Front Design, Black', 'Xerox 1966'),
#   1),
#  (('Array® Memo Cubes',
#    'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'),
#   1),
#  (('Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)',
#    'Xerox 1939'),
#   1),
#  (('GBC Recycled Regency Composition Covers',
#    'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'),
#   1),
#  (('Southworth 25% Cotton Premium Laser Paper and Envelopes',
#    'SANFORD Major Accent™ Highlighters'),
#   1),
#  (('Xerox 1894',
#    'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'),
#   1),
#  (('Assorted Color Push Pins', 'Fellowes Black Plastic Comb Bindings'), 1),
#  (('Southworth 25% Cotton Premium Laser Paper and Envelopes',
#    'Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms'),
#   1),
#  (('Micro Innovations Micro Digital Wireless Keyboard and Mouse, Gray',
#    'Bevis 36 x 72 Conference Tables'),
#   1),
#  (('Gyration Ultra Professional Cordless Optical Suite',
#    'KI Conference Tables'),
#   1),
#  (('Staples® General Use 3-Ring Binders',
#    'SANFORD Liquid Accent™ Tank-Style Highlighters'),
#   1),
#  (('Sharp EL500L Fraction Calculator', 'White GlueTop Scratch Pads'), 1),
#  (('Bagged Rubber Bands',
#    'Carina Double Wide Media Storage Towers in Natural & Black'),
#   1),
#  (('Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum',
#    'Sanford Liquid Accent Highlighters'),
#   1),
#  (("O'Sullivan Elevations Bookcase, Cherry Finish",
#    'ACCOHIDE® Binder by Acco'),
#   1),
#  (('Avery Self-Adhesive Photo Pockets for Polaroid Photos',
#    'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'),
#   1),
#  (('Conquest™ 14 Commercial Heavy-Duty Upright Vacuum, Collection System, Accessory Kit',
#    'Westinghouse Clip-On Gooseneck Lamps'),
#   1),
#  (('Fellowes Binding Cases', 'AT&T Black Trimline Phone, Model 210'), 1),
#  (('Avery 506', 'Bretford CR8500 Series Meeting Room Furniture'), 1),
#  (('Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate',
#    'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'),
#   1),
#  (('Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting',
#    'Xerox 1927'),
#   1),
#  (('Acme® 8" Straight Scissors',
#    'Bionaire Personal Warm Mist Humidifier/Vaporizer'),
#   1),
#  (('ACCOHIDE® Binder by Acco',
#    'Serrated Blade or Curved Handle Hand Letter Openers'),
#   1),
#  (('Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)',
#    'Keytronic 105-Key Spanish Keyboard'),
#   1),
#  (('Advantus Map Pennant Flags and Round Head Tacks',
#    'Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle'),
#   1),
#  (('Global Adaptabilities™ Conference Tables',
#    'Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms'),
#   1),
#  (('LX 677', 'Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box'),
#   1),
#  (('Conquest™ 14 Commercial Heavy-Duty Upright Vacuum, Collection System, Accessory Kit',
#    'Okidata ML390 Turbo Dot Matrix Printers'),
#   1),
#  (('Deflect-O® Glasstique™ Clear Desk Accessories', 'Xerox 197'), 1),
#  (('Electrix Halogen Magnifier Lamp', 'Eldon Shelf Savers™ Cubes and Bins'),
#   1),
#  (('Catalog Binders with Expanding Posts',
#    'Micro Innovations Micro 3000 Keyboard, Black'),
#   1),
#  (('Acme® 8" Straight Scissors',
#    'Tenex Personal Project File with Scoop Front Design, Black'),
#   1),
#  (('Prang Drawing Pencil Set', 'Eldon Shelf Savers™ Cubes and Bins'), 1),
#  (('Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags',
#    'Verbatim DVD-RAM, 9.4GB, Rewritable, Type 1, DS, DataLife Plus'),
#   1),
#  (('Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4', 'Binder Posts'),
#   1),
#  (('Hewlett-Packard Deskjet 1220Cse Color Inkjet Printer',
#    'TI 36X Solar Scientific Calculator'),
#   1),
#  (('Hon Olson Stacker Stools', '6340'), 1),
#  (('GBC VeloBinder Strips',
#    'G.E. Longer-Life Indoor Recessed Floodlight Bulbs'),
#   1),
#  (('LX 788', 'Canon P1-DHIII Palm Printing Calculator'), 1),
#  (('Boston 1730 StandUp Electric Pencil Sharpener',
#    'Bretford CR4500 Series Slim Rectangular Table'),
#   1),
#  (('Southworth 25% Cotton Antique Laid Paper & Envelopes',
#    'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'),
#   1),
#  (('Xerox 1961',
#    'Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle'),
#   1),
#  (('Stockwell Push Pins', 'Bevis Round Conference Table Top, X-Base'), 1),
#  (('Staples Bulldog Clip',
#    'Avery Self-Adhesive Photo Pockets for Polaroid Photos'),
#   1),
#  (('Hon Every-Day® Chair Series Swivel Task Chairs',
#    'IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case'),
#   1),
#  (('Boston 1730 StandUp Electric Pencil Sharpener',
#    'Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box'),
#   1),
#  (('Avery Flip-Chart Easel Binder, Black',
#    'Bevis Boat-Shaped Conference Table'),
#   1),
#  (('Timeport L7089',
#    'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'),
#   1),
#  (('Hoover Portapower™ Portable Vacuum',
#    'Letter/Legal File Tote with Clear Snap-On Lid, Black Granite'),
#   1),
#  (('Artistic Insta-Plaque', 'GE 4 Foot Flourescent Tube, 40 Watt'), 1),
#  (('Hon Every-Day® Chair Series Swivel Task Chairs', 'Avery Binder Labels'),
#   1),
#  (('Canon PC1080F Personal Copier', 'Newell 318'), 1),
#  (('Avery Flip-Chart Easel Binder, Black',
#    'Perma STOR-ALL™ Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H'),
#   1),
#  (('Hon iLevel™ Computer Training Table', 'Xerox 220'), 1),
#  (('Prang Drawing Pencil Set', 'Staples Metal Binder Clips'), 1),
#  (('Eldon Pizzaz™ Desk Accessories',
#    'Fellowes Twister Kit, Gray/Clear, 3/pkg'),
#   1),
#  (('GBC Standard Plastic Binding Systems Combs',
#    'Office Star Flex Back Scooter Chair with White Frame'),
#   1),
#  (('Eldon Portable Mobile Manager', 'Accessory6'), 1),
#  (('Newell 312',
#    'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables'),
#   1),
#  (('Nu-Form 106-Key Ergonomic Keyboard w/ Touchpad', 'Xerox 1989'), 1),
#  (('Newell 35',
#    'Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting'),
#   1),
#  (('DAX Copper Panel Document Frame, 5 x 7 Size',
#    'Nu-Dell Leatherette Frames'),
#   1),
#  (('Portfile® Personal File Boxes', 'Xerox 1880'), 1),
#  (('Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers',
#    'Cardinal Holdit Business Card Pockets'),
#   1),
#  (('Xerox 1971', 'Eldon Portable Mobile Manager'), 1),
#  (('Hoover Replacement Belts For Soft Guard™ & Commercial Ltweight Upright Vacs, 2/Pk',
#    'T28 WORLD'),
#   1),
#  (('Belkin 8 Outlet Surge Protector',
#    'Executive Impressions 14" Contract Wall Clock'),
#   1),
#  (('Xerox 1961', 'Xerox 1982'), 1),
#  (('Fellowes Recycled Storage Drawers',
#    "O'Sullivan Elevations Bookcase, Cherry Finish"),
#   1),
#  (('Hon Every-Day® Chair Series Swivel Task Chairs',
#    'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base'),
#   1),
#  (('Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators',
#    'Holmes Odor Grabber'),
#   1),
#  (('2160i', 'Multimedia Mailers'), 1),
#  (('Imation Neon Mac Format Diskettes, 10/Pack',
#    'Bevis Boat-Shaped Conference Table'),
#   1),
#  (('Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs', 'Xerox 1922'),
#   1),
#  (('*Staples* vLetter Openers, 2/Pack', 'Avery 481'), 1),
#  (('Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#    'Peel & Seel® Recycled Catalog Envelopes, Brown'),
#   1),
#  (('Bevis Steel Folding Chairs', 'Bevis 36 x 72 Conference Tables'), 1),
#  (('12-1/2 Diameter Round Wall Clock',
#    'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'),
#   1),
#  (('Peel & Stick Add-On Corner Pockets', 'BPI Conference Tables'), 1),
#  (('Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators',
#    'Recycled Eldon Regeneration Jumbo File'),
#   1),
#  (('Xerox 190', 'TDK 4.7GB DVD+RW'), 1),
#  (('*Staples* Highlighting Markers', 'Master Caster Door Stop, Brown'), 1),
#  (('Imation DVD-RAM discs', 'SAFCO Mobile Desk Side File, Wire Frame'), 1),
#  (('Adesso Programmable 142-Key Keyboard', 'T193'), 1),
#  (('Xerox 1992', 'DAX Solid Wood Frames'), 1),
#  (('Hon iLevel™ Computer Training Table', 'Xerox 1949'), 1),
#  (('Avery 491', 'Gyration Ultra Cordless Optical Suite'), 1),
#  (('Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#    'Eldon Shelf Savers™ Cubes and Bins'),
#   1),
#  (('Eldon Econocleat® Chair Mats for Low Pile Carpets', 'Xerox 210'), 1),
#  (('Newell 312', 'Wausau Papers Astrobrights® Colored Envelopes'), 1),
#  (('Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack',
#    'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'),
#   1),
#  (('AT&T 2230 Dual Handset Phone With Caller ID/Call Waiting',
#    'Ibico Covers for Plastic or Wire Binding Elements'),
#   1),
#  (('Memorex 4.7GB DVD+RW, 3/Pack', 'Belkin 6 Outlet Metallic Surge Strip'), 1),
#  (('White Dual Perf Computer Printout Paper, 2700 Sheets, 1 Part, Heavyweight, 20 lbs., 14 7/8 x 11',
#    'Belkin ErgoBoard™ Keyboard'),
#   1),
#  (('Bretford CR4500 Series Slim Rectangular Table', 'Xerox 197'), 1),
#  (('Array® Memo Cubes', 'Bevis Round Bullnose 29" High Table Top'), 1),
#  (('Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut',
#    'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter'),
#   1),
#  (('Avery Poly Binder Pockets', 'Acco® Hot Clips™ Clips to Go'), 1),
#  (('Fellowes Internet Keyboard, Platinum',
#    'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate'),
#   1),
#  (('Tuff Stuff™ Recycled Round Ring Binders',
#    'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4'),
#   1),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'GBC Recycled Regency Composition Covers'),
#   1),
#  (('Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags',
#    'Cardinal Holdit Business Card Pockets'),
#   1),
#  (('12-1/2 Diameter Round Wall Clock', 'Regeneration Desk Collection'), 1),
#  (('Wilson Jones Hanging View Binder, White, 1"',
#    'Fellowes Basic 104-Key Keyboard, Platinum'),
#   1),
#  (('Xerox Blank Computer Paper',
#    'Micro Innovations Micro Digital Wireless Keyboard and Mouse, Gray'),
#   1),
#  (('Avery 52', 'Plymouth Boxed Rubber Bands by Plymouth'), 1),
#  (('Xerox 1947', 'Premium Transparent Presentation Covers by GBC'), 1),
#  (('Hoover Portapower™ Portable Vacuum',
#    'SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black'),
#   1),
#  (('5165', 'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"'), 1),
#  (('Canon MP41DH Printing Calculator',
#    'Deluxe Rollaway Locking File with Drawer'),
#   1),
#  (('9-3/4 Diameter Round Wall Clock', 'Multimedia Mailers'), 1),
#  (('Bevis Round Bullnose 29" High Table Top', 'Xerox 1993'), 1),
#  (('Bagged Rubber Bands',
#    'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac'),
#   1),
#  (('Eldon Radial Chair Mat for Low to Medium Pile Carpets',
#    'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back'),
#   1),
#  (('Hunt BOSTON® Vista® Battery-Operated Pencil Sharpener, Black',
#    'Avery 494'),
#   1),
#  (('Prang Drawing Pencil Set', 'Memorex 4.7GB DVD-RAM, 3/Pack'), 1),
#  (('Fellowes Binding Cases', 'Presstex Flexible Ring Binders'), 1),
#  (('Binder Posts', 'Staples 6 Outlet Surge'), 1),
#  (('DAX Contemporary Wood Frame with Silver Metal Mat, Desktop, 11 x 14 Size',
#    'Stockwell Push Pins'),
#   1),
#  (('80 Minute CD-R Spindle, 100/Pack - Staples',
#    'Tennsco Commercial Shelving'),
#   1),
#  (('T193', 'Avery 510'), 1),
#  (('Hon Olson Stacker Stools', '688'), 1),
#  (('Xerox 1908', 'Talkabout T8367'), 1),
#  (('Avery Hi-Liter Pen Style Six-Color Fluorescent Set',
#    'Avery Durable Poly Binders'),
#   1),
#  (('Fellowes Binding Cases', 'Prang Drawing Pencil Set'), 1),
#  (('Fellowes Binding Cases',
#    'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”'),
#   1),
#  (('Sauder Forest Hills Library, Woodland Oak Finish', 'Avery 520'), 1),
#  (('2180', 'Wilson Jones Impact Binders'), 1),
#  (('Bush Westfield Collection Bookcases, Fully Assembled',
#    'Hon Metal Bookcases, Black'),
#   1),
#  (('Okidata ML320 Series Turbo Dot Matrix Printers', 'Xerox 1994'), 1),
#  (('DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#    'Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box'),
#   1),
#  (('White GlueTop Scratch Pads', 'KI Conference Tables'), 1),
#  (('Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders', 'i470'), 1),
#  (('Howard Miller 13" Diameter Goldtone Round Wall Clock',
#    'Fellowes Super Stor/Drawer® Files'),
#   1),
#  (('Boston 1730 StandUp Electric Pencil Sharpener',
#    'Executive Impressions 13" Chairman Wall Clock'),
#   1),
#  (('Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table',
#    'Global Commerce™ Series High-Back Swivel/Tilt Chairs'),
#   1),
#  (('Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)',
#    'Hon 94000 Series Round Tables'),
#   1),
#  (('Avery Hi-Liter Pen Style Six-Color Fluorescent Set',
#    'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book'),
#   1),
#  (('Staples Plastic Wall Frames', 'KF 788'), 1),
#  (('Presstex Flexible Ring Binders', 'Staples® General Use 3-Ring Binders'),
#   1),
#  (('Staples Standard Envelopes',
#    'Imation 3.5", DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack'),
#   1),
#  (('Xerox 212',
#    'Binney & Smith inkTank™ Erasable Desk Highlighter, Chisel Tip, Yellow, 12/Box'),
#   1),
#  (('Accessory4',
#    'Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting'),
#   1),
#  (('Avery 485', 'i270'), 1),
#  (('Hewlett-Packard 2600DN Business Color Inkjet Printer',
#    'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'),
#   1),
#  (('Memorex 80 Minute CD-R, 30/Pack',
#    'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins'),
#   1),
#  (('Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#    'Executive Impressions 13" Chairman Wall Clock'),
#   1),
#  (('Barrel Sharpener', 'Keytronic 105-Key Spanish Keyboard'), 1),
#  (('Rediform S.O.S. Phone Message Books', 'Avery 51'), 1),
#  (('AT&T 2230 Dual Handset Phone With Caller ID/Call Waiting',
#    'Gyration Ultra Cordless Optical Suite'),
#   1),
#  (('Ibico Covers for Plastic or Wire Binding Elements',
#    'Hanging Personal Folder File'),
#   1),
#  (('Boston 1645 Deluxe Heavier-Duty Electric Pencil Sharpener',
#    'OIC Thumb-Tacks'),
#   1),
#  (('StarTAC 7760', 'Belkin ErgoBoard™ Keyboard'), 1),
#  (('Fellowes Stor/Drawer® Steel Plus™ Storage Drawers',
#    'Hewlett-Packard 4.7GB DVD+R Discs'),
#   1),
#  (('Xerox Blank Computer Paper',
#    'Smead Adjustable Mobile File Trolley with Lockable Top'),
#   1),
#  (('Rediform S.O.S. Phone Message Books',
#    'Maxell 3.5" DS/HD IBM-Formatted Diskettes, 10/Pack'),
#   1),
#  (('Hewlett Packard LaserJet 3310 Copier', 'Unpadded Memo Slips'), 1),
#  (('Xerox 1966', '8890'), 1),
#  (('Newell 343', 'Tripp Lite Isotel 8 Ultra 8 Outlet Metal Surge'), 1),
#  (('Executive Impressions 14" Two-Color Numerals Wall Clock', 'Avery 491'), 1),
#  (('Fellowes Bankers Box™ Staxonsteel® Drawer File/Stacking System',
#    'Advantus Map Pennant Flags and Round Head Tacks'),
#   1),
#  (('Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl', 'Accessory21'), 1),
#  (('Howard Miller 13" Diameter Goldtone Round Wall Clock',
#    'Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers'),
#   1),
#  (('5125', 'Xerox 1905'), 1),
#  (('Okidata ML320 Series Turbo Dot Matrix Printers',
#    '3M Polarizing Task Lamp with Clamp Arm, Light Gray'),
#   1),
#  (('Cardinal Poly Pocket Divider Pockets for Ring Binders',
#    'Aluminum Document Frame'),
#   1),
#  (('Xerox 1908', '688'), 1),
#  (('Sanford EarthWrite® Recycled Pencils, Medium Soft, #2',
#    'Keytronic French Keyboard'),
#   1),
#  (('Space Solutions Commercial Steel Shelving', 'Newell 340'), 1),
#  (('Avery 493', 'HP Office Paper (20Lb. and 87 Bright)'), 1),
#  (('Accessory31', 'GBC White Gloss Covers, Plain Front'), 1),
#  (('80 Minute Slim Jewel Case CD-R , 10/Pack - Staples',
#    'Fellowes Recycled Storage Drawers'),
#   1),
#  (('Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#    'Bevis 36 x 72 Conference Tables'),
#   1),
#  (('Imation Neon Mac Format Diskettes, 10/Pack', '2180'), 1),
#  (('Staples® General Use 3-Ring Binders', 'Xerox 1978'), 1),
#  (('U.S. Robotics 56K Internet Call Modem', 'TDK 4.7GB DVD+RW'), 1),
#  (('DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#    'Fellowes Staxonsteel® Drawer Files'),
#   1),
#  (('Xerox 190', 'Canon PC-428 Personal Copier'), 1),
#  (('Stockwell Push Pins', 'M3682'), 1),
#  (('Rogers® Profile Extra Capacity Storage Tub', 'Imation DVD-RAM discs'), 1),
#  (('5170', 'Barrel Sharpener'), 1),
#  (('Deflect-o DuraMat Antistatic Studded Beveled Mat for Medium Pile Carpeting',
#    'Xerox 193'),
#   1),
#  (('Sanford Liquid Accent Highlighters',
#    'Executive Impressions 14" Contract Wall Clock'),
#   1),
#  (('Staples Battery-Operated Desktop Pencil Sharpener',
#    'Boston 16765 Mini Stand Up Battery Pencil Sharpener'),
#   1),
#  (('Imation Neon Mac Format Diskettes, 10/Pack', 'Xerox 227'), 1),
#  (('BPI Conference Tables', '252'), 1),
#  (('Newell 342', 'Eldon Shelf Savers™ Cubes and Bins'), 1),
#  (('Avery 506',
#    'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base'),
#   1),
#  (('3390', 'Belkin 8 Outlet SurgeMaster II Gold Surge Protector'), 1),
#  (('Belkin 105-Key Black Keyboard', 'Avery Durable Binders'), 1),
#  (('Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”',
#    'Micro Innovations 104 Keyboard'),
#   1),
#  (('Wilson Jones DublLock® D-Ring Binders',
#    'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back'),
#   1),
#  (('Avery 474', 'Staples Wirebound Steno Books, 6" x 9", 12/Pack'), 1),
#  (('5180', 'Executive Impressions 14" Two-Color Numerals Wall Clock'), 1),
#  (('Xerox 1922', 'Acme® Box Cutter Scissors'), 1),
#  (('Hammermill CopyPlus Copy Paper (20Lb. and 84 Bright)',
#    'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"'),
#   1),
#  (('Sauder Facets Collection Locker/File Cabinet, Sky Alder Finish',
#    'Eldon® Wave Desk Accessories'),
#   1),
#  (('Fellowes Staxonsteel® Drawer Files', 'CF 688'), 1),
#  (('Fellowes Staxonsteel® Drawer Files', 'Xerox 1932'), 1),
#  (('Telescoping Adjustable Floor Lamp',
#    'Iceberg OfficeWorks 42" Round Tables'),
#   1),
#  (('Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders',
#    'Eldon Econocleat® Chair Mats for Low Pile Carpets'),
#   1),
#  (('Riverside Furniture Stanwyck Manor Table Series',
#    'Global Deluxe Office Fabric Chairs'),
#   1),
#  (('Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book',
#    'R280'),
#   1),
#  (('Global Commerce™ Series High-Back Swivel/Tilt Chairs',
#    'GBC Plastic Binding Combs'),
#   1),
#  (('Belkin ErgoBoard™ Keyboard', 'Imation DVD-RAM discs'), 1),
#  (('Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table',
#    'Artistic Insta-Plaque'),
#   1),
#  (('Xerox 1930', 'Newell 339'), 1),
#  (('Fellowes Strictly Business® Drawer File, Letter/Legal Size',
#    'Binder Posts'),
#   1),
#  (('Master Caster Door Stop, Gray', 'Newell 337'), 1),
#  (('Staples Brown Kraft Recycled Clasp Envelopes',
#    'Array® Parchment Paper, Assorted Colors'),
#   1),
#  (('Accessory21', 'Xerox 1922'), 1),
#  (('Canon PC940 Copier', 'Boston 1730 StandUp Electric Pencil Sharpener'), 1),
#  (('Staples Standard Envelopes', 'Portable Personal File Box'), 1),
#  (('Wirebound Message Book, 4 per Page',
#    'Master Giant Foot® Doorstop, Safety Yellow'),
#   1),
#  (('Accessory4', 'Xerox 1897'), 1),
#  (('Staples 6 Outlet Surge', 'Xerox 217'), 1),
#  (('Unpadded Memo Slips', 'Gyration Ultra Cordless Optical Suite'), 1),
#  (('Panasonic KX-P1150 Dot Matrix Printer',
#    'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base'),
#   1),
#  (('Global Commerce™ Series High-Back Swivel/Tilt Chairs',
#    'Tensor "Hersey Kiss" Styled Floor Lamp'),
#   1),
#  (('Global Leather and Oak Executive Chair, Black', 'Newell 343'), 1),
#  (('1726 Digital Answering Machine', 'ACCOHIDE® Binder by Acco'), 1),
#  (('Bevis Rectangular Conference Tables',
#    'SANFORD Major Accent™ Highlighters'),
#   1),
#  (('Tyvek® Side-Opening Peel & Seel® Expanding Envelopes',
#    'Hunt Boston® Vacuum Mount KS Pencil Sharpener'),
#   1),
#  (('Avery 479', 'Tennsco Commercial Shelving'), 1),
#  (('Avery 506', 'GBC Recycled Regency Composition Covers'), 1),
#  (('Eureka Sanitaire ® Multi-Pro Heavy-Duty Upright, Disposable Bags',
#    'Prismacolor Color Pencil Set'),
#   1),
#  (('Xerox 1932', 'Newell 310'), 1),
#  (('Staples 6 Outlet Surge', 'Eldon® 300 Class™ Desk Accessories, Black'), 1),
#  (('US Robotics 56K V.92 External Faxmodem',
#    'Wausau Papers Astrobrights® Colored Envelopes'),
#   1),
#  (('Hewlett Packard LaserJet 3310 Copier', 'Staples Metal Binder Clips'), 1),
#  (('Computer Printout Paper with Letter-Trim Perforations',
#    'Filing/Storage Totes and Swivel Casters'),
#   1),
#  (('Eldon® Image Series Desk Accessories, Burgundy',
#    'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'),
#   1),
#  (("Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#    'Verbatim DVD-RAM, 9.4GB, Rewritable, Type 1, DS, DataLife Plus'),
#   1),
#  (('GBC Standard Plastic Binding Systems Combs', 'Avery 520'), 1),
#  (('Canon PC940 Copier', 'GBC Standard Plastic Binding Systems Combs'), 1),
#  (('Belkin 8 Outlet SurgeMaster II Gold Surge Protector',
#    'Memorex 4.7GB DVD+RW, 3/Pack'),
#   1),
#  (('Xerox 1891', 'Tennsco Regal Shelving Units'), 1),
#  (('Xerox 1937', '12 Colored Short Pencils'), 1),
#  (('Tripp Lite Isotel 6 Outlet Surge Protector with Fax/Modem Protection',
#    'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection'),
#   1),
#  (('Holmes Odor Grabber', 'GBC DocuBind 200 Manual Binding Machine'), 1),
#  (('Avery Hanging File Binders', 'Acme® Box Cutter Scissors'), 1),
#  (('Xerox 212', 'Project Tote Personal File'), 1),
#  (('Prang Drawing Pencil Set', 'T39m'), 1),
#  (('Microsoft Internet Keyboard',
#    'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'),
#   1),
#  (('Portable Personal File Box',
#    'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'),
#   1),
#  (('Accessory21', '8260'), 1),
#  (('Southworth 25% Cotton Premium Laser Paper and Envelopes',
#    'IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case'),
#   1),
#  (('Hunt Boston® Vacuum Mount KS Pencil Sharpener', 'Xerox 1933'), 1),
#  (('688', 'Staples SlimLine Pencil Sharpener'), 1),
#  (('Newell 318', 'Boston Model 1800 Electric Pencil Sharpener, Gray'), 1),
#  (('Eldon® Expressions™ Wood and Plastic Desk Accessories, Oak', 'Xerox 1905'),
#   1),
#  (('5125', 'Array® Parchment Paper, Assorted Colors'), 1),
#  (('3285', 'Memorex 4.7GB DVD+RW, 3/Pack'), 1),
#  (('Xerox 1940', 'Staples SlimLine Pencil Sharpener'), 1),
#  (('Binder Posts', 'Memorex 80 Minute CD-R Spindle, 100/Pack'), 1),
#  (('Tennsco Industrial Shelving',
# ...
#  (('Hewlett Packard LaserJet 3310 Copier', 'Prismacolor Color Pencil Set'), 1),
#  (('GBC VeloBinder Electric Binding Machine',
#    'Wilson Jones 1" Hanging DublLock® Ring Binders'),
#   1),
#  (('DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7', 'LX 677'), 1),
#  (('Hunt Boston® Vacuum Mount KS Pencil Sharpener', 'DAX Solid Wood Frames'),
#   1),
#  (('2160i',
#    'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate'),
#   1),
#  (('Avery Poly Binder Pockets', 'Aluminum Document Frame'), 1),
#  (('Prang Colored Pencils', 'Xerox 1949'), 1),
#  (('Storex DuraTech Recycled Plastic Frosted Binders', 'Avery 481'), 1),
#  (('Ibico Presentation Index for Binding Systems', 'Avery 510'), 1),
#  (('Avery 493', '80 Minute CD-R Spindle, 100/Pack - Staples'), 1),
#  (('Xerox 1992', 'Holmes Replacement Filter for HEPA Air Cleaner, Large Room'),
#   1),
#  (('Bretford Rectangular Conference Table Tops',
#    'Tenex Personal Self-Stacking Standard File Box, Black/Gray'),
#   1),
#  (('DAX Contemporary Wood Frame with Silver Metal Mat, Desktop, 11 x 14 Size',
#    'Holmes Replacement Filter for HEPA Air Cleaner, Large Room'),
#   1),
#  (('Canon PC940 Copier', 'Executive Impressions 13" Clairmont Wall Clock'), 1),
#  (('Newell 318', "O'Sullivan Elevations Bookcase, Cherry Finish"), 1),
#  (('Aluminum Document Frame', 'GBC Recycled Regency Composition Covers'), 1),
#  (('Kleencut® Forged Office Shears by Acme United Corporation',
#    'Micro Innovations 104 Keyboard'),
#   1),
#  (('Career Cubicle Clock, 8 1/4", Black', 'Accessory6'), 1),
#  (('8860', 'Carina Double Wide Media Storage Towers in Natural & Black'), 1),
#  (('Global Adaptabilities™ Conference Tables',
#    'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'),
#   1),
#  (('Durable Pressboard Binders', 'Fellowes 17-key keypad for PS/2 interface'),
#   1),
#  (('Xerox 1959', 'i2000'), 1),
#  (('GBC Poly Designer Binding Covers',
#    'Global High-Back Leather Tilter, Burgundy'),
#   1),
#  (('Wilson Jones DublLock® D-Ring Binders', 'Eldon® Wave Desk Accessories'),
#   1),
#  (('IBM 80 Minute CD-R Spindle, 50/Pack', 'Accessory31'), 1),
#  (('252', 'Xerox 1920'), 1),
#  (('T60', 'Newell 338'), 1),
#  (('Accessory9',
#    'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'),
#   1),
#  (('688', 'M3682'), 1),
#  (('Hon iLevel™ Computer Training Table',
#    'SANFORD Liquid Accent™ Tank-Style Highlighters'),
#   1),
#  (('Fellowes Staxonsteel® Drawer Files', '4009® Highlighters by Sanford'), 1),
#  (('Avery 508', 'CF 688'), 1),
#  (('Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms',
#    'Imation 3.5", RTS 247544 3M 3.5 DSDD, 10/Pack'),
#   1),
#  (('Economy Binders', 'Global Stack Chair without Arms, Black'), 1),
#  (('Acme® 8" Straight Scissors',
#    'Hunt BOSTON® Vista® Battery-Operated Pencil Sharpener, Black'),
#   1),
#  (('Avery 493', 'Newell 309'), 1),
#  (('Staples Battery-Operated Desktop Pencil Sharpener',
#    'Vinyl Sectional Post Binders'),
#   1),
#  (('Staples Standard Envelopes',
#    'Wilson Jones Hanging View Binder, White, 1"'),
#   1),
#  (('ACCOHIDE® Binder by Acco', 'Global Ergonomic Managers Chair'), 1),
#  (('5125', 'Staples #10 Laser & Inkjet Envelopes, 4 1/8" x 9 1/2", 100/Box'),
#   1),
#  (('Hewlett Packard LaserJet 3310 Copier',
#    'Dana Halogen Swing-Arm Architect Lamp'),
#   1),
#  (('Staples Brown Kraft Recycled Clasp Envelopes',
#    '4009® Highlighters by Sanford'),
#   1),
#  (('Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"',
#    'Fellowes Basic 104-Key Keyboard, Platinum'),
#   1),
#  (('Xerox 1996', 'Xerox 1880'), 1),
#  (('Recycled Eldon Regeneration Jumbo File', 'Stockwell Push Pins'), 1),
#  (('Avery 498', 'Accessory6'), 1),
#  (("Jet-Pak Recycled Peel 'N' Seal Padded Mailers",
#    'Dixon My First Ticonderoga Pencil, #2'),
#   1),
#  (('"While you Were Out" Message Book, One Form per Page',
#    'Iceberg OfficeWorks 42" Round Tables'),
#   1),
#  (('Tyvek® Side-Opening Peel & Seel® Expanding Envelopes',
#    'DAX Solid Wood Frames'),
#   1),
#  (('Durable Pressboard Binders', 'Avery 52'), 1),
#  (('Master Giant Foot® Doorstop, Safety Yellow', 'Xerox 1978'), 1),
#  (('Aluminum Document Frame', 'Ibico Presentation Index for Binding Systems'),
#   1),
#  (('Advantus Push Pins, Aluminum Head', 'GBC VeloBinder Strips'), 1),
#  (('Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish',
#    'SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black'),
#   1),
#  (('Hoover Portapower™ Portable Vacuum', 'Avery 479'), 1),
#  (('Hon 94000 Series Round Tables', 'Logitech Access Keyboard'), 1),
#  (('Fellowes Recycled Storage Drawers',
#    'Snap-A-Way® Black Print Carbonless Ruled Speed Letter, Triplicate'),
#   1),
#  (('Boston 1730 StandUp Electric Pencil Sharpener',
#    'Staples® General Use 3-Ring Binders'),
#   1),
#  (('Timeport L7089', 'Canon P1-DHIII Palm Printing Calculator'), 1),
#  (('Xerox 1928', 'Xerox 1939'), 1),
#  (('Canon PC-428 Personal Copier', 'Xerox 210'), 1),
#  (('Eldon Expressions Mahogany Wood Desk Collection',
#    'Staples Copy Paper (20Lb. and 84 Bright)'),
#   1),
#  (('Catalog Binders with Expanding Posts', 'Economy Binders'), 1),
#  (('Xerox Blank Computer Paper', 'SAFCO Mobile Desk Side File, Wire Frame'),
#   1),
#  (('Accessory34',
#    'Bush Westfield Collection Bookcases, Dark Cherry Finish, Fully Assembled'),
#   1),
#  (('Holmes Replacement Filter for HEPA Air Cleaner, Large Room',
#    'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"'),
#   1),
#  (('Lexmark Z54se Color Inkjet Printer', 'StarTAC 7760'), 1),
#  (('Fellowes Bankers Box™ Staxonsteel® Drawer File/Stacking System',
#    'Bretford CR4500 Series Slim Rectangular Table'),
#   1),
#  (('Xerox 1923',
#    'Bush Westfield Collection Bookcases, Dark Cherry Finish, Fully Assembled'),
#   1),
#  (('Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut',
#    'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book'),
#   1),
#  (('Avery White Multi-Purpose Labels', 'Avery 491'), 1),
#  (('Xerox 1961', 'Acme® Elite Stainless Steel Scissors'), 1),
#  (('Project Tote Personal File', 'Fiskars® Softgrip Scissors'), 1),
#  (('White GlueTop Scratch Pads',
#    'Black Print Carbonless Snap-Off® Rapid Letter, 8 1/2" x 7"'),
#   1),
#  (('Avery 508', 'Boston 16801 Nautilus™ Battery Pencil Sharpener'), 1),
#  (('Master Giant Foot® Doorstop, Safety Yellow',
#    'Premium Writing Pencils, Soft, #2 by Central Association for the Blind'),
#   1),
#  (('"While you Were Out" Message Book, One Form per Page',
#    'GBC Plastic Binding Combs'),
#   1),
#  (('Xerox 1966', 'Xerox 213'), 1),
#  (('Bevis Steel Folding Chairs', 'Fellowes Super Stor/Drawer® Files'), 1),
#  (('GBC Standard Therm-A-Bind Covers',
#    'Wilson Jones Hanging View Binder, White, 1"'),
#   1),
#  (('Hon 2111 Invitation™ Series Corner Table', 'Xerox 1989'), 1),
#  (('DAX Natural Wood-Tone Poster Frame',
#    'GBC DocuBind 200 Manual Binding Machine'),
#   1),
#  (('Premium Transparent Presentation Covers by GBC',
#    'Staples Plastic Wall Frames'),
#   1),
#  (('Microsoft Natural Multimedia Keyboard', '3M Office Air Cleaner'), 1),
#  (('Space Solutions Commercial Steel Shelving',
#    "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room"),
#   1),
#  (('Xerox 1997',
#    'Hewlett-Packard Deskjet 940 REFURBISHED Color Inkjet Printer'),
#   1),
#  (('Acme® Preferred Stainless Steel Scissors', 'Avery 494'), 1),
#  (('Master Caster Door Stop, Brown', 'StarTAC ST7762'), 1),
#  (('Bretford Rectangular Conference Table Tops',
#    'Tenex Carpeted, Granite-Look or Clear Contemporary Contour Shape Chair Mats'),
#   1),
#  (('Wilson Jones DublLock® D-Ring Binders', 'Avery 485'), 1),
#  (('Hanging Personal Folder File',
#    'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop'),
#   1),
#  (('Assorted Color Push Pins', 'Newell 343'), 1),
#  (('i2000', 'Global Stack Chair without Arms, Black'), 1),
#  (('252', 'Riverleaf Stik-Withit® Designer Note Cubes®'), 1),
#  (('Recycled Eldon Regeneration Jumbo File',
#    'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb'),
#   1),
#  (('Tennsco Lockers, Gray', "O'Sullivan Elevations Bookcase, Cherry Finish"),
#   1),
#  (('Eldon Pizzaz™ Desk Accessories',
#    'Storex DuraTech Recycled Plastic Frosted Binders'),
#   1),
#  (('StarTAC 7760', 'Xerox 1939'), 1),
#  (('T60', 'Staples 6 Outlet Surge'), 1),
#  (('Ibico Covers for Plastic or Wire Binding Elements',
#    'Wirebound Service Call Books, 5 1/2" x 4"'),
#   1),
#  (('9-3/4 Diameter Round Wall Clock', 'Metal Folding Chairs, Beige, 4/Carton'),
#   1),
#  (('*Staples* Highlighting Markers', 'StarTAC ST7762'), 1),
#  (('Blue String-Tie & Button Interoffice Envelopes, 10 x 13',
#    'Mead 1st Gear 2" Zipper Binder, Asst. Colors'),
#   1),
#  (('Avery 498', '12-1/2 Diameter Round Wall Clock'), 1),
#  (('Self-Adhesive Address Labels for Typewriters by Universal',
#    'Riverleaf Stik-Withit® Designer Note Cubes®'),
#   1),
#  (('Belkin 105-Key Black Keyboard', 'Avery Flip-Chart Easel Binder, Black'),
#   1),
#  (('Newell 312', 'GBC Laser Imprintable Binding System Covers, Desert Sand'),
#   1),
#  (('Avery 49', 'Wausau Papers Astrobrights® Colored Envelopes'), 1),
#  (('Xerox 199',
#    'SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black'),
#   1),
#  (('Avery 491', 'Global Stack Chair without Arms, Black'), 1),
#  (('Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl',
#    'Belkin 6 Outlet Metallic Surge Strip'),
#   1),
#  (('Avery 491', 'Xerox 194'), 1),
#  (('Durable Pressboard Binders',
#    'Global Leather and Oak Executive Chair, Black'),
#   1),
#  (('80 Minute CD-R Spindle, 100/Pack - Staples',
#    '"While you Were Out" Message Book, One Form per Page'),
#   1),
#  (('Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac',
#    'Avery 520'),
#   1),
#  (('#10 White Business Envelopes,4 1/8 x 9 1/2', 'Newell 340'), 1),
#  (('Xerox 1952', 'Keytronic 105-Key Spanish Keyboard'), 1),
#  (('Adesso Programmable 142-Key Keyboard', 'Avery 494'), 1),
#  (('Imation 3.5 IBM Formatted Diskettes, 10/Box', 'Newell 343'), 1),
#  (('Angle-D Binders with Locking Rings, Label Holders',
#    'Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS'),
#   1),
#  (('8260', 'Accessory36'), 1),
#  (('Logitech Cordless Access Keyboard',
#    "O'Sullivan 3-Shelf Heavy-Duty Bookcases"),
#   1),
#  (('Bretford CR8500 Series Meeting Room Furniture',
#    'Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers'),
#   1),
#  (('Sauder Forest Hills Library, Woodland Oak Finish',
#    'GBC DocuBind 200 Manual Binding Machine'),
#   1),
#  (('Avery 485', 'Dixon My First Ticonderoga Pencil, #2'), 1),
#  (('Xerox 1930',
#    'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book'),
#   1),
#  (('Park Ridge™ Embossed Executive Business Envelopes',
#    'GBC Wire Binding Strips'),
#   1),
#  (('Acme® Preferred Stainless Steel Scissors', 'V70'), 1),
#  (('Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators',
#    'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms'),
#   1),
#  (('Micro Innovations Micro 3000 Keyboard, Black',
#    'Regeneration Desk Collection'),
#   1),
#  (('Hon Comfortask® Task/Swivel Chairs', '6120'), 1),
#  (('5125', 'Accessory6'), 1),
#  (('Chromcraft Bull-Nose Wood Round Conference Table Top, Wood Base',
#    'Hon 2111 Invitation™ Series Corner Table'),
#   1),
#  (('Xerox 1881', 'LX 788'), 1),
#  (('Accessory27',
#    'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'),
#   1),
#  (('Prang Colored Pencils', 'Xerox 1895'), 1),
#  (('Memorex 4.7GB DVD-RAM, 3/Pack', 'Xerox 1949'), 1),
#  (('Large Capacity Hanging Post Binders', 'EcoTones® Memo Sheets'), 1),
#  (('Avery 491', 'Accessory13'), 1),
#  (('Xerox 1952', 'KF 788'), 1),
#  (('Peel & Stick Add-On Corner Pockets',
#    'Filing/Storage Totes and Swivel Casters'),
#   1),
#  (('Newell 318',
#    'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"'),
#   1),
#  (('9-3/4 Diameter Round Wall Clock', 'Logitech Internet Navigator Keyboard'),
#   1),
#  (('Telescoping Adjustable Floor Lamp',
#    'Tenex Personal Self-Stacking Standard File Box, Black/Gray'),
#   1),
#  (('Panasonic KX-P1150 Dot Matrix Printer', 'Electrix Halogen Magnifier Lamp'),
#   1),
#  (('Peel & Seel® Recycled Catalog Envelopes, Brown',
#    'IBM 80 Minute CD-R Spindle, 50/Pack'),
#   1),
#  (('Staples Brown Kraft Recycled Clasp Envelopes',
#    'Belkin 6 Outlet Metallic Surge Strip'),
#   1),
#  (('Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms',
#    'Iceberg OfficeWorks 42" Round Tables'),
#   1),
#  (('Bretford Rectangular Conference Table Tops', 'T28 WORLD'), 1),
#  (('Aluminum Document Frame', 'Xerox 226'), 1),
#  (('Hon 4700 Series Mobuis™ Mid-Back Task Chairs with Adjustable Arms',
#    'Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms'),
#   1),
#  (('3M Polarizing Task Lamp with Clamp Arm, Light Gray',
#    'Verbatim DVD-RAM, 9.4GB, Rewritable, Type 1, DS, DataLife Plus'),
#   1),
#  (('Economy Binders', 'Xerox 1989'), 1),
#  (('Avery Trapezoid Extra Heavy Duty 4" Binders', 'Xerox 1927'), 1),
#  (('Staples Standard Envelopes', '12-1/2 Diameter Round Wall Clock'), 1),
#  (('Microsoft Internet Keyboard', 'Xerox 210'), 1),
#  (('Avery 493', 'Xerox 1989'), 1),
#  (('Panasonic KX-P1150 Dot Matrix Printer',
#    'Belkin 6 Outlet Metallic Surge Strip'),
#   1),
#  (('Hon 2090 “Pillow Soft” Series Mid Back Swivel/Tilt Chairs',
#    'Project Tote Personal File'),
#   1),
#  (('Microsoft Internet Keyboard',
#    'Bretford CR4500 Series Slim Rectangular Table'),
#   1),
#  (('Microsoft Natural Multimedia Keyboard', 'Xerox 23'), 1),
#  (('Newell 318', 'Avery 481'), 1),
#  (('Newell 31', 'Belkin ErgoBoard™ Keyboard'), 1),
#  (('Belkin F9M820V08 8 Outlet Surge', 'Holmes HEPA Air Purifier'), 1),
#  (('Accessory21', 'Avery Durable Binders'), 1),
#  (('Canon PC940 Copier', "O'Sullivan 3-Shelf Heavy-Duty Bookcases"), 1),
#  (('Iceberg OfficeWorks 42" Round Tables', 'GBC Plastic Binding Combs'), 1),
#  (('Verbatim DVD-R, 3.95GB, SR, Mitsubishi Branded, Jewel',
#    'Fellowes Personal Hanging Folder Files, Navy'),
#   1),
#  (('Avery 508', 'Xerox 1898'), 1),
#  (('Xerox 1928', 'StarTAC 7760'), 1),
#  (('GBC Standard Plastic Binding Systems Combs', 'Avery 479'), 1),
#  (('Fellowes Super Stor/Drawer® Files',
#    'Angle-D Binders with Locking Rings, Label Holders'),
#   1),
#  (('Global Deluxe High-Back Office Chair in Storm',
#    'Bevis Round Conference Table Top, X-Base'),
#   1),
#  (('Staples Plastic Wall Frames',
#    'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages'),
#   1),
#  (('2160', 'Avery Binder Labels'), 1),
#  (('Xerox 1922', 'Eldon Expressions™ Desk Accessory, Wood Pencil Holder, Oak'),
#   1),
#  (('DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#    'Staples 6 Outlet Surge'),
#   1),
#  (('Xerox 199', 'T28 WORLD'), 1),
#  (('Xerox 1881',
#    'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black'),
#   1),
#  (('Accessory35', 'Avery Reinforcements for Hole-Punch Pages'), 1),
#  (('Tennsco Lockers, Gray', 'Riverside Furniture Stanwyck Manor Table Series'),
#   1),
#  (('Panasonic KX-P1150 Dot Matrix Printer',
#    'G.E. Longer-Life Indoor Recessed Floodlight Bulbs'),
#   1),
#  (('Xerox 1984', 'EcoTones® Memo Sheets'), 1),
#  (('Xerox 1997', 'Avery Binder Labels'), 1),
#  (('Xerox 1971', 'Accessory6'), 1),
#  (('Array® Parchment Paper, Assorted Colors',
#    'HP Office Paper (20Lb. and 87 Bright)'),
#   1),
#  (('Xerox 212', 'Memorex 4.7GB DVD+RW, 3/Pack'), 1),
#  (('Tyvek® Side-Opening Peel & Seel® Expanding Envelopes', 'Xerox 1991'), 1),
#  (('Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle',
#    'Boston 16801 Nautilus™ Battery Pencil Sharpener'),
#   1),
#  (('GBC Standard Plastic Binding Systems Combs',
#    'Eureka Disposable Bags for Sanitaire® Vibra Groomer I® Upright Vac'),
#   1),
#  (('Accessory8', 'Xerox 1993'), 1),
#  (('US Robotics 56K V.92 External Faxmodem',
#    'Boston School Pro Electric Pencil Sharpener, 1670'),
#   1),
#  (('LX 788', 'Eldon® Expressions™ Wood and Plastic Desk Accessories, Oak'), 1),
#  (('Canon MP41DH Printing Calculator', 'Newell 310'), 1),
#  (('Telescoping Adjustable Floor Lamp',
#    'Imation 3.5", RTS 247544 3M 3.5 DSDD, 10/Pack'),
#   1),
#  ...]

# %% [markdown]
# This is the final proof that affinity analysis is not suitable for this dataset and we do not need to go further.<br>
#
# # Additional Exercises:
# 1. Discussion Exercise: Should we keep "bad" results?
# 2. What other ways could we bin or basket the data?
#
# Extra References:<br>
# http://pbpython.com/market-basket-analysis.html <br>
# A more complicated implementation of market basket analysis but it uses the apriori algorithm to extract the frequent item dataset; what we have used in this workbook is a simple filter.
